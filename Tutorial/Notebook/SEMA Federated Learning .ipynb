# %% [markdown]
# ## SEMA FL Demo

# %%
import os
os.chdir('../../src')
os.getcwd()
# !python ToolChainFL.py -h
# Out:
# INFO    | 2022-05-14 20:34:21,327 | CustomSimProcedure | Windows lib path = /media/kdam/Data/UCL/Federated-Learning/tool/SEMA/dam/SEMA-ToolChain/src/ToolChainSCDG/procedures/windows
# INFO    | 2022-05-14 20:34:21,376 | CustomSimProcedure | Linux lib path = /media/kdam/Data/UCL/Federated-Learning/tool/SEMA/dam/SEMA-ToolChain/src/ToolChainSCDG/procedures/linux
# usage: ToolChainFL.py [--method METHOD] [--n_args N_ARGS] [--timeout TIMEOUT]
#                       [--symb_loop SYMB_LOOP] [--conc_loop CONC_LOOP]
#                       [--simul_state SIMUL_STATE] [--limit_pause LIMIT_PAUSE]
#                       [--max_step MAX_STEP] [--max_deadend MAX_DEADEND]
#                       [--min_size MIN_SIZE] [--not_resolv_string]
#                       [--disjoint_union] [--not_comp_args] [--three_edges]
#                       [--not_ignore_zero] [--dir DIR] [--exp_dir EXP_DIR]
#                       [--discard_SCDG] [--eval_time] [--verbose_scdg]
# ...

# %% [markdown]
# ### Train the Deep Learning model via the SEMA FL ###
# We deploy SEMA-FL on two clients (client1 and client2) as follows.
# 1. First, we start the clients:
# **./run_worker.sh --hostname=client1**
#
# **./run_worker.sh --hostname=client2**
#
# 2. Then, we launch the training command with 5 training rounds.
# **python ToolChainFL.py --classifier dl --hostnames client1 client2 --nrounds 5 --no_scdg_create small_train ../Tutorial/DATA/CLASS_DATA/TRAIN**
#
# In the following, we show the training process of SEMA FL on two clients.

# %%
# !python ToolChainFL.py --classifier dl --hostnames client1 client2 --nrounds 5 --no_scdg_create small_train ../Tutorial/DATA/CLASS_DATA/TRAIN
# Out:
# INFO    | 2022-05-14 20:34:29,110 | CustomSimProcedure | Windows lib path = /media/kdam/Data/UCL/Federated-Learning/tool/SEMA/dam/SEMA-ToolChain/src/ToolChainSCDG/procedures/windows
# INFO    | 2022-05-14 20:34:29,159 | CustomSimProcedure | Linux lib path = /media/kdam/Data/UCL/Federated-Learning/tool/SEMA/dam/SEMA-ToolChain/src/ToolChainSCDG/procedures/linux
# Starting SEMA FL training
# -- Training phase in FL - round 1/5
# Return value for train step: {'train': [0.3124982625908322], 'val': [0.2639670208096504]}
# Return value for train step: {'train': [0.3070930197338263], 'val': [0.32919734477996826]}
# Decrypt key: [2.0999549972036, 2.1000086969252703, 2.1000307891550967]
# -- Update phase in FL - round 1/5
# Return value for update step: {'v': [2.0999838238773365, 2.099997081162405, 2.0999600906070466]}
# -- Testing phase in FL - round 1/5
# {'acc': 0.24, 'loss': 0.0}
# {'acc': 0.0, 'loss': 0.0}
# -- Training phase in FL - round 2/5
# ...

# %% [markdown]
# Then, the training model is used to classify malwares at each client as follows.

# %%
#At client1
# !python ToolChainFL.py --classification --classifier dl small_train ../Tutorial/DATA/CLASS_DATA/TEST
# Out:
# INFO    | 2022-05-14 20:46:24,764 | CustomSimProcedure | Windows lib path = /media/kdam/Data/UCL/Federated-Learning/tool/SEMA/dam/SEMA-ToolChain/src/ToolChainSCDG/procedures/windows
# INFO    | 2022-05-14 20:46:24,808 | CustomSimProcedure | Linux lib path = /media/kdam/Data/UCL/Federated-Learning/tool/SEMA/dam/SEMA-ToolChain/src/ToolChainSCDG/procedures/linux
# Loading data from ../Tutorial/DATA/CLASS_DATA/TEST
# 100% (50 of 50) |########################| Elapsed Time: 0:00:02 Time:  0:00:02
# (00433191a896734271556918917ecec6.gs, autoit) is predicted as autoit (prob 0.99)
# (004c9c07fea878f4d316f831ff1912ea.gs, autoit) is predicted as autoit (prob 0.99)
# (005cfe4b8d323cf1b50e06cc2b968323.gs, autoit) is predicted as autoit (prob 0.99)
# (00713d6ea858ecd08877a4ec5392be1d.gs, autoit) is predicted as autoit (prob 0.99)
# (0079237db0f09f55c7cf72b7e6c53594.gs, autoit) is predicted as autoit (prob 0.99)
# ...

# %% [markdown]
# ![FL_CM_worker1.png](attachment:FL_CM_worker1.png)

# %%
#At client2
# !python ToolChainFL.py --classification --classifier dl small_train ../Tutorial/DATA/CLASS_DATA/TEST
# Out:
# INFO    | 2022-05-14 20:48:31,509 | CustomSimProcedure | Windows lib path = /media/kdam/Data/UCL/Federated-Learning/tool/SEMA/dam/SEMA-ToolChain/src/ToolChainSCDG/procedures/windows
# INFO    | 2022-05-14 20:48:31,554 | CustomSimProcedure | Linux lib path = /media/kdam/Data/UCL/Federated-Learning/tool/SEMA/dam/SEMA-ToolChain/src/ToolChainSCDG/procedures/linux
# Loading data from ../Tutorial/DATA/CLASS_DATA/TEST
# 100% (50 of 50) |########################| Elapsed Time: 0:00:03 Time:  0:00:03
# (00433191a896734271556918917ecec6.gs, autoit) is predicted as autoit (prob 1.00)
# (004c9c07fea878f4d316f831ff1912ea.gs, autoit) is predicted as autoit (prob 1.00)
# (005cfe4b8d323cf1b50e06cc2b968323.gs, autoit) is predicted as autoit (prob 1.00)
# (00713d6ea858ecd08877a4ec5392be1d.gs, autoit) is predicted as autoit (prob 1.00)
# (0079237db0f09f55c7cf72b7e6c53594.gs, autoit) is predicted as autoit (prob 1.00)
# ...

# %% [markdown]
# ![FL_CM_worker2.png](attachment:FL_CM_worker2.png)
