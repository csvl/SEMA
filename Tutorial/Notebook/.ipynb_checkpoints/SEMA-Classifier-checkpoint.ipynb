# %% [markdown]
# # **SEMA-Classifier**

# %% [markdown]
# ![SEMA_illustration.png](attachment:SEMA_illustration.png)

# %% [markdown]
# ## **Using SEMA-Classifier**

# %%
# %matplotlib inline
# %matplotlib notebook
import os
os.chdir('../../src')
os.getcwd()
# !python3 ToolChainClassifier/ToolChainClassifier.py -h
# Out:
# usage: ToolChainClassifier.py [-h] [--train] [--classifier CLASSIFIER]
#                               [--threshold THRESHOLD]
#                               [--biggest_subgraph BIGGEST_SUBGRAPH]
#                               [--support SUPPORT] [--nthread NTHREAD]
#                               [--verbose_classifier] [--ctimeout CTIMEOUT]
#                               [--families FAMILIES [FAMILIES ...]]
#                               [--mode MODE] [--epoch EPOCH]
#                               binaries
#
# Classification module arguments
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --biggest_subgraph BIGGEST_SUBGRAPH
#                         Biggest subgraph consider for Gspan (default: 5)
#
# Classification module arguments:
#   --train               Launch training process, else classify/detect new
#                         sample with previously computed model
#   --classifier CLASSIFIER
#                         Classifier used for the analysis among
#                         (gspan,inria,wl,dl) (default : wl)
#   --threshold THRESHOLD
#                         Threshold used for the classifier [0..1] (default :
#                         0.45)
#   --support SUPPORT     Support used for the gpsan classifier [0..1] (default
#                         : 0.75)
#   --nthread NTHREAD     Number of thread used (default: max)
#   --verbose_classifier  Verbose output during train/classification (default :
#                         False)
#   --ctimeout CTIMEOUT   Timeout for gspan classifier (default : 3sec)
#   --families FAMILIES [FAMILIES ...]
#                         Families considered (default : ['bancteian','delf','Fe
#                         akerStealer','gandcrab','ircbot','lamer','nitol','RedL
#                         ineStealer','sfone','sillyp2p','simbot','Sodinokibi','
#                         sytro','upatre','wabot','RemcosRAT'])
#   --mode MODE           detection = binary decision cleanware vs malware OR
#                         classification = malware family (default)
#   --epoch EPOCH         Only for deep learning model: number of epoch
#                         (default: 5) Always 1 for FL model
#   binaries              Name of the folder containing binary'signatures to
#                         analyze (Default: output/save-SCDG/, only that for
#                         ToolChain)

# %% [markdown]
# ### **Classify SCDG**
# We classify SCDGs extracted from different malware. We will first use SVM with Weisfeiler-Lehman kernel classifier and train our model :

# %%
# !python3 ToolChainClassifier/ToolChainClassifier.py --train --classifier=wl  ../Tutorial/DATA/CLASS_DATA/TRAIN/
# Out:
# INFO - 2022-05-12 10:03:32,111 - ToolChainClassifier - ['../Tutorial/DATA/CLASS_DATA/TRAIN/ircbot', '../Tutorial/DATA/CLASS_DATA/TRAIN/shiz', '../Tutorial/DATA/CLASS_DATA/TRAIN/bancteian', '../Tutorial/DATA/CLASS_DATA/TRAIN/sfone', '../Tutorial/DATA/CLASS_DATA/TRAIN/simbot', '../Tutorial/DATA/CLASS_DATA/TRAIN/delf', '../Tutorial/DATA/CLASS_DATA/TRAIN/sytro', '../Tutorial/DATA/CLASS_DATA/TRAIN/autoit', '../Tutorial/DATA/CLASS_DATA/TRAIN/sillyp2p', '../Tutorial/DATA/CLASS_DATA/TRAIN/wabot']
# INFO - 2022-05-12 10:03:32,111 - ToolChainClassifier - Namespace(biggest_subgraph=5, binaries='../Tutorial/DATA/CLASS_DATA/TRAIN/', classifier='wl', ctimeout=3, epoch=5, families=None, mode='classification', nthread=8, support=0.75, threshold=0.45, train=True, verbose_classifier=False)
# INFO - 2022-05-12 10:03:32,206 - SVMWLClassifier - Path: ../Tutorial/DATA/CLASS_DATA/TRAIN/
# N/A% (0 of 10) |                         | Elapsed Time: 0:00:00 ETA:  --:--:--INFO - 2022-05-12 10:03:32,209 - SVMWLClassifier - Subpath: /home/bertrandvano/Documents/SEMA-ToolChain/src/../Tutorial/DATA/CLASS_DATA/TRAIN/ircbot/
# INFO - 2022-05-12 10:03:32,223 - SVMWLClassifier - Subpath: /home/bertrandvano/Documents/SEMA-ToolChain/src/../Tutorial/DATA/CLASS_DATA/TRAIN/shiz/
# INFO - 2022-05-12 10:03:32,259 - SVMWLClassifier - Subpath: /home/bertrandvano/Documents/SEMA-ToolChain/src/../Tutorial/DATA/CLASS_DATA/TRAIN/bancteian/
# INFO - 2022-05-12 10:03:32,265 - SVMWLClassifier - Subpath: /home/bertrandvano/Documents/SEMA-ToolChain/src/../Tutorial/DATA/CLASS_DATA/TRAIN/sfone/
# INFO - 2022-05-12 10:03:32,273 - SVMWLClassifier - Subpath: /home/bertrandvano/Documents/SEMA-ToolChain/src/../Tutorial/DATA/CLASS_DATA/TRAIN/simbot/
# INFO - 2022-05-12 10:03:32,284 - SVMWLClassifier - Subpath: /home/bertrandvano/Documents/SEMA-ToolChain/src/../Tutorial/DATA/CLASS_DATA/TRAIN/delf/
# INFO - 2022-05-12 10:03:32,303 - SVMWLClassifier - Subpath: /home/bertrandvano/Documents/SEMA-ToolChain/src/../Tutorial/DATA/CLASS_DATA/TRAIN/sytro/
# INFO - 2022-05-12 10:03:32,311 - SVMWLClassifier - Subpath: /home/bertrandvano/Documents/SEMA-ToolChain/src/../Tutorial/DATA/CLASS_DATA/TRAIN/autoit/
# INFO - 2022-05-12 10:03:32,417 - SVMWLClassifier - Subpath: /home/bertrandvano/Documents/SEMA-ToolChain/src/../Tutorial/DATA/CLASS_DATA/TRAIN/sillyp2p/
# INFO - 2022-05-12 10:03:32,425 - SVMWLClassifier - Subpath: /home/bertrandvano/Documents/SEMA-ToolChain/src/../Tutorial/DATA/CLASS_DATA/TRAIN/wabot/
# 100% (10 of 10) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# INFO - 2022-05-12 10:03:32,483 - SVMWLClassifier - Dataset len: 250
# INFO - 2022-05-12 10:03:33,459 - SVMWLClassifier - --------------------FIT OK----------------
# INFO - 2022-05-12 10:03:36,608 - ToolChainClassifier - Total training time: 4.497963905334473
# INFO - 2022-05-12 10:03:36,608 - ToolChainClassifier - Total classification time: 4.49813437461853

# %% [markdown]
# We now have a working model that we will use to classify new data :

# %%
# !python3 ToolChainClassifier/ToolChainClassifier.py --classifier=wl  ../Tutorial/DATA/CLASS_DATA/TEST/
# Out:
# INFO - 2022-05-12 10:03:42,962 - ToolChainClassifier - ['../Tutorial/DATA/CLASS_DATA/TEST/ircbot', '../Tutorial/DATA/CLASS_DATA/TEST/shiz', '../Tutorial/DATA/CLASS_DATA/TEST/bancteian', '../Tutorial/DATA/CLASS_DATA/TEST/sfone', '../Tutorial/DATA/CLASS_DATA/TEST/simbot', '../Tutorial/DATA/CLASS_DATA/TEST/delf', '../Tutorial/DATA/CLASS_DATA/TEST/sytro', '../Tutorial/DATA/CLASS_DATA/TEST/autoit', '../Tutorial/DATA/CLASS_DATA/TEST/sillyp2p', '../Tutorial/DATA/CLASS_DATA/TEST/wabot']
# INFO - 2022-05-12 10:03:42,962 - ToolChainClassifier - Namespace(biggest_subgraph=5, binaries='../Tutorial/DATA/CLASS_DATA/TEST/', classifier='wl', ctimeout=3, epoch=5, families=None, mode='classification', nthread=8, support=0.75, threshold=0.45, train=False, verbose_classifier=False)
# 100% (10 of 10) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# INFO:SVMWLClassifier:Accuracy 97.00 %
# INFO:SVMWLClassifier:Precision 97.31 %
# INFO:SVMWLClassifier:Recall 97.00 %
# INFO:SVMWLClassifier:F1-score 96.97 %
# Figure(1000x700)
# INFO - 2022-05-12 10:03:44,657 - ToolChainClassifier - Total classification time: 1.6957435607910156

# %% [markdown]
# We get the following confusion matrix :
# ![Conf_matrix.png](attachment:Conf_matrix.png)

# %% [markdown]
# In a similar way, we could train another model and then use it to classify data. Note: make sure the submodule SEMA-quickspan (/src/submodules/) is correctly installed and compiled (https://github.com/csvl/SEMA-quickspan).

# %%
# !python3 ToolChainClassifier/ToolChainClassifier.py --train --classifier=gspan  ../Tutorial/DATA/CLASS_DATA/TRAIN/
# Out:
# INFO - 2022-05-12 10:05:53,977 - ToolChainClassifier - ['../Tutorial/DATA/CLASS_DATA/TRAIN/ircbot', '../Tutorial/DATA/CLASS_DATA/TRAIN/shiz', '../Tutorial/DATA/CLASS_DATA/TRAIN/bancteian', '../Tutorial/DATA/CLASS_DATA/TRAIN/sfone', '../Tutorial/DATA/CLASS_DATA/TRAIN/simbot', '../Tutorial/DATA/CLASS_DATA/TRAIN/delf', '../Tutorial/DATA/CLASS_DATA/TRAIN/sytro', '../Tutorial/DATA/CLASS_DATA/TRAIN/autoit', '../Tutorial/DATA/CLASS_DATA/TRAIN/sillyp2p', '../Tutorial/DATA/CLASS_DATA/TRAIN/wabot']
# INFO - 2022-05-12 10:05:53,977 - ToolChainClassifier - Namespace(biggest_subgraph=5, binaries='../Tutorial/DATA/CLASS_DATA/TRAIN/', classifier='gspan', ctimeout=3, epoch=5, families=None, mode='classification', nthread=8, support=0.75, threshold=0.45, train=True, verbose_classifier=False)
# INFO - 2022-05-12 10:05:53,979 - GSpanClassifier - Input Path = ../Tutorial/DATA/CLASS_DATA/TRAIN/
# N/A% (0 of 10) |                         | Elapsed Time: 0:00:00 ETA:  --:--:--INFO - 2022-05-12 10:05:53,982 - GSpanClassifier - Family = ircbot
# INFO - 2022-05-12 10:05:53,994 - GSpanClassifier - Gspan_path = /home/bertrandvano/Documents/SEMA-ToolChain/src/submodules/SEMA-quickspan/build/gspan --input_file /home/bertrandvano/Documents/SEMA-ToolChain/src/ToolChainClassifier/sig/ircbot_merge.gs --output_file /home/bertrandvano/Documents/SEMA-ToolChain/src/ToolChainClassifier/sig/ircbot_sig.gs --pattern --biggest_subgraphs 5 --threads 8 --timeout  3 --support 0.75
# INFO - 2022-05-12 10:05:57,587 - GSpanClassifier - b''
# INFO - 2022-05-12 10:05:57,587 - GSpanClassifier - b'I0512 10:05:54.001137 346031 quickspan.cc:92] quickspan timeout: 3\nI0512 10:05:54.002379 346031 quickspan.cc:118] quickspan read input time: 0.001198\nI0512 10:05:54.004086 346031 quickspan_execute.cc:27] quickspan construct graph time: 0.001688\nI0512 10:05:54.004096 346031 quickspan_execute.cc:54] quickspan thread 0 create\nI0512 10:05:54.004104 346031 quickspan_execute.cc:54] quickspan thread 1 create\nI0512 10:05:54.004108 346031 quickspan_execute.cc:54] quickspan thread 2 create\nI0512 10:05:54.004117 346031 quickspan_execute.cc:54] quickspan thread 3 create\nI0512 10:05:54.004125 346031 quickspan_execute.cc:54] quickspan thread 4 create\nI0512 10:05:54.004132 346031 quickspan_execute.cc:54] quickspan thread 5 create\nI0512 10:05:54.004139 346031 quickspan_execute.cc:54] quickspan thread 6 create\nI0512 10:05:54.004148 346031 quickspan_execute.cc:54] quickspan thread 7 create\nI0512 10:05:57.001214 346031 quickspan.h:70] Signal received, halting mining and producing output...\nI0512 10:05:57.490367 346031 quickspan_execute.cc:36] quickspan mine graph time: 3.48626\nI0512 10:05:57.490619 346031 quickspan.cc:145] quickspan execute time: 3.48821\nI0512 10:05:57.490892 346031 quickspan.cc:155] quickspan save output time: 0.000244\n'
#  10% (1 of 10) |##                       | Elapsed Time: 0:00:03 ETA:   0:00:32INFO - 2022-05-12 10:05:57,588 - GSpanClassifier - Family = shiz
# INFO - 2022-05-12 10:05:57,609 - GSpanClassifier - Gspan_path = /home/bertrandvano/Documents/SEMA-ToolChain/src/submodules/SEMA-quickspan/build/gspan --input_file /home/bertrandvano/Documents/SEMA-ToolChain/src/ToolChainClassifier/sig/shiz_merge.gs --output_file /home/bertrandvano/Documents/SEMA-ToolChain/src/ToolChainClassifier/sig/shiz_sig.gs --pattern --biggest_subgraphs 5 --threads 8 --timeout  3 --support 0.75
# INFO - 2022-05-12 10:06:01,041 - GSpanClassifier - b''
# INFO - 2022-05-12 10:06:01,041 - GSpanClassifier - b'I0512 10:05:57.618100 346057 quickspan.cc:92] quickspan timeout: 3\nI0512 10:05:57.622833 346057 quickspan.cc:118] quickspan read input time: 0.004255\nI0512 10:05:57.629292 346057 quickspan_execute.cc:27] quickspan construct graph time: 0.006373\nI0512 10:05:57.629315 346057 quickspan_execute.cc:54] quickspan thread 0 create\nI0512 10:05:57.629325 346057 quickspan_execute.cc:54] quickspan thread 1 create\nI0512 10:05:57.629333 346057 quickspan_execute.cc:54] quickspan thread 2 create\nI0512 10:05:57.629344 346057 quickspan_execute.cc:54] quickspan thread 3 create\nI0512 10:05:57.629349 346057 quickspan_execute.cc:54] quickspan thread 4 create\nI0512 10:05:57.629355 346057 quickspan_execute.cc:54] quickspan thread 5 create\nI0512 10:05:57.629360 346057 quickspan_execute.cc:54] quickspan thread 6 create\nI0512 10:05:57.629369 346057 quickspan_execute.cc:54] quickspan thread 7 create\nI0512 10:06:00.618577 346057 quickspan.h:70] Signal received, halting mining and producing output...\nI0512 10:06:01.030580 346057 quickspan_execute.cc:36] quickspan mine graph time: 3.40125\nI0512 10:06:01.031159 346057 quickspan.cc:145] quickspan execute time: 3.40818\nI0512 10:06:01.031364 346057 quickspan.cc:155] quickspan save output time: 0.000178\n'
#  20% (2 of 10) |#####                    | Elapsed Time: 0:00:07 ETA:   0:00:27INFO - 2022-05-12 10:06:01,042 - GSpanClassifier - Family = bancteian
# INFO - 2022-05-12 10:06:01,056 - GSpanClassifier - Gspan_path = /home/bertrandvano/Documents/SEMA-ToolChain/src/submodules/SEMA-quickspan/build/gspan --input_file /home/bertrandvano/Documents/SEMA-ToolChain/src/ToolChainClassifier/sig/bancteian_merge.gs --output_file /home/bertrandvano/Documents/SEMA-ToolChain/src/ToolChainClassifier/sig/bancteian_sig.gs --pattern --biggest_subgraphs 5 --threads 8 --timeout  3 --support 0.75
# INFO - 2022-05-12 10:06:04,064 - GSpanClassifier - b''
# INFO - 2022-05-12 10:06:04,064 - GSpanClassifier - b'I0512 10:06:01.062963 346080 quickspan.cc:92] quickspan timeout: 3\nI0512 10:06:01.063657 346080 quickspan.cc:118] quickspan read input time: 0.000652\nI0512 10:06:01.064641 346080 quickspan_execute.cc:27] quickspan construct graph time: 0.000967\nI0512 10:06:01.064653 346080 quickspan_execute.cc:54] quickspan thread 0 create\nI0512 10:06:01.064658 346080 quickspan_execute.cc:54] quickspan thread 1 create\nI0512 10:06:01.064661 346080 quickspan_execute.cc:54] quickspan thread 2 create\nI0512 10:06:01.064664 346080 quickspan_execute.cc:54] quickspan thread 3 create\nI0512 10:06:01.064667 346080 quickspan_execute.cc:54] quickspan thread 4 create\nI0512 10:06:01.064671 346080 quickspan_execute.cc:54] quickspan thread 5 create\nI0512 10:06:01.064673 346080 quickspan_execute.cc:54] quickspan thread 6 create\nI0512 10:06:01.064677 346080 quickspan_execute.cc:54] quickspan thread 7 create\nI0512 10:06:04.063019 346080 quickspan.h:70] Signal received, halting mining and producing output...\nI0512 10:06:04.063201 346080 quickspan_execute.cc:36] quickspan mine graph time: 2.99854\nI0512 10:06:04.063299 346080 quickspan.cc:145] quickspan execute time: 2.99962\nI0512 10:06:04.063483 346080 quickspan.cc:155] quickspan save output time: 0.000166\n'
#  30% (3 of 10) |#######                  | Elapsed Time: 0:00:10 ETA:   0:00:21INFO - 2022-05-12 10:06:04,065 - GSpanClassifier - Family = sfone
# INFO - 2022-05-12 10:06:04,077 - GSpanClassifier - Gspan_path = /home/bertrandvano/Documents/SEMA-ToolChain/src/submodules/SEMA-quickspan/build/gspan --input_file /home/bertrandvano/Documents/SEMA-ToolChain/src/ToolChainClassifier/sig/sfone_merge.gs --output_file /home/bertrandvano/Documents/SEMA-ToolChain/src/ToolChainClassifier/sig/sfone_sig.gs --pattern --biggest_subgraphs 5 --threads 8 --timeout  3 --support 0.75
# INFO - 2022-05-12 10:06:07,088 - GSpanClassifier - b''
# INFO - 2022-05-12 10:06:07,088 - GSpanClassifier - b'I0512 10:06:04.085651 346106 quickspan.cc:92] quickspan timeout: 3\nI0512 10:06:04.086400 346106 quickspan.cc:118] quickspan read input time: 0.000684\nI0512 10:06:04.087352 346106 quickspan_execute.cc:27] quickspan construct graph time: 0.000936\nI0512 10:06:04.087358 346106 quickspan_execute.cc:54] quickspan thread 0 create\nI0512 10:06:04.087363 346106 quickspan_execute.cc:54] quickspan thread 1 create\nI0512 10:06:04.087365 346106 quickspan_execute.cc:54] quickspan thread 2 create\nI0512 10:06:04.087368 346106 quickspan_execute.cc:54] quickspan thread 3 create\nI0512 10:06:04.087371 346106 quickspan_execute.cc:54] quickspan thread 4 create\nI0512 10:06:04.087373 346106 quickspan_execute.cc:54] quickspan thread 5 create\nI0512 10:06:04.087376 346106 quickspan_execute.cc:54] quickspan thread 6 create\nI0512 10:06:04.087379 346106 quickspan_execute.cc:54] quickspan thread 7 create\nI0512 10:06:07.085723 346106 quickspan.h:70] Signal received, halting mining and producing output...\nI0512 10:06:07.087023 346106 quickspan_execute.cc:36] quickspan mine graph time: 2.99966\nI0512 10:06:07.087154 346106 quickspan.cc:145] quickspan execute time: 3.00074\nI0512 10:06:07.087314 346106 quickspan.cc:155] quickspan save output time: 0.000141\n'
#  40% (4 of 10) |##########               | Elapsed Time: 0:00:13 ETA:   0:00:18INFO - 2022-05-12 10:06:07,089 - GSpanClassifier - Family = simbot
# INFO - 2022-05-12 10:06:07,106 - GSpanClassifier - Gspan_path = /home/bertrandvano/Documents/SEMA-ToolChain/src/submodules/SEMA-quickspan/build/gspan --input_file /home/bertrandvano/Documents/SEMA-ToolChain/src/ToolChainClassifier/sig/simbot_merge.gs --output_file /home/bertrandvano/Documents/SEMA-ToolChain/src/ToolChainClassifier/sig/simbot_sig.gs --pattern --biggest_subgraphs 5 --threads 8 --timeout  3 --support 0.75
# INFO - 2022-05-12 10:06:10,136 - GSpanClassifier - b''
# INFO - 2022-05-12 10:06:10,136 - GSpanClassifier - b'I0512 10:06:07.119973 346129 quickspan.cc:92] quickspan timeout: 3\nI0512 10:06:07.121060 346129 quickspan.cc:118] quickspan read input time: 0.001018\nI0512 10:06:07.122628 346129 quickspan_execute.cc:27] quickspan construct graph time: 0.001545\nI0512 10:06:07.122658 346129 quickspan_execute.cc:54] quickspan thread 0 create\nI0512 10:06:07.122664 346129 quickspan_execute.cc:54] quickspan thread 1 create\nI0512 10:06:07.122668 346129 quickspan_execute.cc:54] quickspan thread 2 create\nI0512 10:06:07.122671 346129 quickspan_execute.cc:54] quickspan thread 3 create\nI0512 10:06:07.122676 346129 quickspan_execute.cc:54] quickspan thread 4 create\nI0512 10:06:07.122679 346129 quickspan_execute.cc:54] quickspan thread 5 create\nI0512 10:06:07.122684 346129 quickspan_execute.cc:54] quickspan thread 6 create\nI0512 10:06:07.122687 346129 quickspan_execute.cc:54] quickspan thread 7 create\nI0512 10:06:10.120049 346129 quickspan.h:70] Signal received, halting mining and producing output...\nI0512 10:06:10.126586 346129 quickspan_execute.cc:36] quickspan mine graph time: 3.00392\nI0512 10:06:10.126729 346129 quickspan.cc:145] quickspan execute time: 3.00564\nI0512 10:06:10.126909 346129 quickspan.cc:155] quickspan save output time: 0.000163\n'
#  50% (5 of 10) |############             | Elapsed Time: 0:00:16 ETA:   0:00:15INFO - 2022-05-12 10:06:10,137 - GSpanClassifier - Family = delf
# INFO - 2022-05-12 10:06:10,151 - GSpanClassifier - Gspan_path = /home/bertrandvano/Documents/SEMA-ToolChain/src/submodules/SEMA-quickspan/build/gspan --input_file /home/bertrandvano/Documents/SEMA-ToolChain/src/ToolChainClassifier/sig/delf_merge.gs --output_file /home/bertrandvano/Documents/SEMA-ToolChain/src/ToolChainClassifier/sig/delf_sig.gs --pattern --biggest_subgraphs 5 --threads 8 --timeout  3 --support 0.75
# INFO - 2022-05-12 10:06:13,190 - GSpanClassifier - b''
# INFO - 2022-05-12 10:06:13,190 - GSpanClassifier - b'I0512 10:06:10.159147 346152 quickspan.cc:92] quickspan timeout: 3\nI0512 10:06:10.162914 346152 quickspan.cc:118] quickspan read input time: 0.003719\nI0512 10:06:10.165980 346152 quickspan_execute.cc:27] quickspan construct graph time: 0.003036\nI0512 10:06:10.166004 346152 quickspan_execute.cc:54] quickspan thread 0 create\nI0512 10:06:10.166013 346152 quickspan_execute.cc:54] quickspan thread 1 create\nI0512 10:06:10.166015 346152 quickspan_execute.cc:54] quickspan thread 2 create\nI0512 10:06:10.166020 346152 quickspan_execute.cc:54] quickspan thread 3 create\nI0512 10:06:10.166059 346152 quickspan_execute.cc:54] quickspan thread 4 create\nI0512 10:06:10.166064 346152 quickspan_execute.cc:54] quickspan thread 5 create\nI0512 10:06:10.166066 346152 quickspan_execute.cc:54] quickspan thread 6 create\nI0512 10:06:10.166070 346152 quickspan_execute.cc:54] quickspan thread 7 create\nI0512 10:06:13.159217 346152 quickspan.h:70] Signal received, halting mining and producing output...\nI0512 10:06:13.177552 346152 quickspan_execute.cc:36] quickspan mine graph time: 3.01153\nI0512 10:06:13.177728 346152 quickspan.cc:145] quickspan execute time: 3.01479\nI0512 10:06:13.177908 346152 quickspan.cc:155] quickspan save output time: 0.00016\n'
#  60% (6 of 10) |###############          | Elapsed Time: 0:00:19 ETA:   0:00:12INFO - 2022-05-12 10:06:13,191 - GSpanClassifier - Family = sytro
# INFO - 2022-05-12 10:06:13,204 - GSpanClassifier - Gspan_path = /home/bertrandvano/Documents/SEMA-ToolChain/src/submodules/SEMA-quickspan/build/gspan --input_file /home/bertrandvano/Documents/SEMA-ToolChain/src/ToolChainClassifier/sig/sytro_merge.gs --output_file /home/bertrandvano/Documents/SEMA-ToolChain/src/ToolChainClassifier/sig/sytro_sig.gs --pattern --biggest_subgraphs 5 --threads 8 --timeout  3 --support 0.75
# INFO - 2022-05-12 10:06:16,815 - GSpanClassifier - b''
# INFO - 2022-05-12 10:06:16,815 - GSpanClassifier - b'I0512 10:06:13.211117 346176 quickspan.cc:92] quickspan timeout: 3\nI0512 10:06:13.212154 346176 quickspan.cc:118] quickspan read input time: 0.000987\nI0512 10:06:13.213624 346176 quickspan_execute.cc:27] quickspan construct graph time: 0.001446\nI0512 10:06:13.213640 346176 quickspan_execute.cc:54] quickspan thread 0 create\nI0512 10:06:13.213649 346176 quickspan_execute.cc:54] quickspan thread 1 create\nI0512 10:06:13.213652 346176 quickspan_execute.cc:54] quickspan thread 2 create\nI0512 10:06:13.213657 346176 quickspan_execute.cc:54] quickspan thread 3 create\nI0512 10:06:13.213662 346176 quickspan_execute.cc:54] quickspan thread 4 create\nI0512 10:06:13.213667 346176 quickspan_execute.cc:54] quickspan thread 5 create\nI0512 10:06:13.213675 346176 quickspan_execute.cc:54] quickspan thread 6 create\nI0512 10:06:13.213680 346176 quickspan_execute.cc:54] quickspan thread 7 create\nI0512 10:06:16.211201 346176 quickspan.h:70] Signal received, halting mining and producing output...\nI0512 10:06:16.710741 346176 quickspan_execute.cc:36] quickspan mine graph time: 3.49709\nI0512 10:06:16.710907 346176 quickspan.cc:145] quickspan execute time: 3.49872\nI0512 10:06:16.713841 346176 quickspan.cc:155] quickspan save output time: 0.002882\n'
#  70% (7 of 10) |#################        | Elapsed Time: 0:00:22 ETA:   0:00:10INFO - 2022-05-12 10:06:16,816 - GSpanClassifier - Family = autoit
# INFO - 2022-05-12 10:06:16,840 - GSpanClassifier - Gspan_path = /home/bertrandvano/Documents/SEMA-ToolChain/src/submodules/SEMA-quickspan/build/gspan --input_file /home/bertrandvano/Documents/SEMA-ToolChain/src/ToolChainClassifier/sig/autoit_merge.gs --output_file /home/bertrandvano/Documents/SEMA-ToolChain/src/ToolChainClassifier/sig/autoit_sig.gs --pattern --biggest_subgraphs 5 --threads 8 --timeout  3 --support 0.75
# INFO - 2022-05-12 10:06:20,681 - GSpanClassifier - b''
# INFO - 2022-05-12 10:06:20,681 - GSpanClassifier - b'I0512 10:06:16.848141 346200 quickspan.cc:92] quickspan timeout: 3\nI0512 10:06:16.860980 346200 quickspan.cc:118] quickspan read input time: 0.012791\nI0512 10:06:16.876134 346200 quickspan_execute.cc:27] quickspan construct graph time: 0.015108\nI0512 10:06:16.876152 346200 quickspan_execute.cc:54] quickspan thread 0 create\nI0512 10:06:16.876159 346200 quickspan_execute.cc:54] quickspan thread 1 create\nI0512 10:06:16.876163 346200 quickspan_execute.cc:54] quickspan thread 2 create\nI0512 10:06:16.876165 346200 quickspan_execute.cc:54] quickspan thread 3 create\nI0512 10:06:16.876170 346200 quickspan_execute.cc:54] quickspan thread 4 create\nI0512 10:06:16.876174 346200 quickspan_execute.cc:54] quickspan thread 5 create\nI0512 10:06:16.876179 346200 quickspan_execute.cc:54] quickspan thread 6 create\nI0512 10:06:16.876184 346200 quickspan_execute.cc:54] quickspan thread 7 create\nI0512 10:06:19.848203 346200 quickspan.h:70] Signal received, halting mining and producing output...\nI0512 10:06:20.613353 346200 quickspan_execute.cc:36] quickspan mine graph time: 3.73719\nI0512 10:06:20.614096 346200 quickspan.cc:145] quickspan execute time: 3.75307\nI0512 10:06:20.615417 346200 quickspan.cc:155] quickspan save output time: 0.001286\n'
#  80% (8 of 10) |####################     | Elapsed Time: 0:00:26 ETA:   0:00:07INFO - 2022-05-12 10:06:20,682 - GSpanClassifier - Family = sillyp2p
# INFO - 2022-05-12 10:06:20,708 - GSpanClassifier - Gspan_path = /home/bertrandvano/Documents/SEMA-ToolChain/src/submodules/SEMA-quickspan/build/gspan --input_file /home/bertrandvano/Documents/SEMA-ToolChain/src/ToolChainClassifier/sig/sillyp2p_merge.gs --output_file /home/bertrandvano/Documents/SEMA-ToolChain/src/ToolChainClassifier/sig/sillyp2p_sig.gs --pattern --biggest_subgraphs 5 --threads 8 --timeout  3 --support 0.75
# INFO - 2022-05-12 10:06:23,723 - GSpanClassifier - b''
# INFO - 2022-05-12 10:06:23,723 - GSpanClassifier - b'I0512 10:06:20.720382 346238 quickspan.cc:92] quickspan timeout: 3\nI0512 10:06:20.721755 346238 quickspan.cc:118] quickspan read input time: 0.001309\nI0512 10:06:20.723613 346238 quickspan_execute.cc:27] quickspan construct graph time: 0.001815\nI0512 10:06:20.723630 346238 quickspan_execute.cc:54] quickspan thread 0 create\nI0512 10:06:20.723639 346238 quickspan_execute.cc:54] quickspan thread 1 create\nI0512 10:06:20.723641 346238 quickspan_execute.cc:54] quickspan thread 2 create\nI0512 10:06:20.723646 346238 quickspan_execute.cc:54] quickspan thread 3 create\nI0512 10:06:20.723649 346238 quickspan_execute.cc:54] quickspan thread 4 create\nI0512 10:06:20.723654 346238 quickspan_execute.cc:54] quickspan thread 5 create\nI0512 10:06:20.723657 346238 quickspan_execute.cc:54] quickspan thread 6 create\nI0512 10:06:20.723660 346238 quickspan_execute.cc:54] quickspan thread 7 create\nI0512 10:06:23.720443 346238 quickspan.h:70] Signal received, halting mining and producing output...\nI0512 10:06:23.721813 346238 quickspan_execute.cc:36] quickspan mine graph time: 2.99818\nI0512 10:06:23.721983 346238 quickspan.cc:145] quickspan execute time: 3.00017\nI0512 10:06:23.722225 346238 quickspan.cc:155] quickspan save output time: 0.000214\n'
#  90% (9 of 10) |######################   | Elapsed Time: 0:00:29 ETA:   0:00:03INFO - 2022-05-12 10:06:23,724 - GSpanClassifier - Family = wabot
# INFO - 2022-05-12 10:06:23,747 - GSpanClassifier - Gspan_path = /home/bertrandvano/Documents/SEMA-ToolChain/src/submodules/SEMA-quickspan/build/gspan --input_file /home/bertrandvano/Documents/SEMA-ToolChain/src/ToolChainClassifier/sig/wabot_merge.gs --output_file /home/bertrandvano/Documents/SEMA-ToolChain/src/ToolChainClassifier/sig/wabot_sig.gs --pattern --biggest_subgraphs 5 --threads 8 --timeout  3 --support 0.75
# INFO - 2022-05-12 10:06:27,576 - GSpanClassifier - b''
# INFO - 2022-05-12 10:06:27,576 - GSpanClassifier - b'I0512 10:06:23.754863 346278 quickspan.cc:92] quickspan timeout: 3\nI0512 10:06:23.764564 346278 quickspan.cc:118] quickspan read input time: 0.009644\nI0512 10:06:23.775964 346278 quickspan_execute.cc:27] quickspan construct graph time: 0.011357\nI0512 10:06:23.775992 346278 quickspan_execute.cc:54] quickspan thread 0 create\nI0512 10:06:23.776001 346278 quickspan_execute.cc:54] quickspan thread 1 create\nI0512 10:06:23.776006 346278 quickspan_execute.cc:54] quickspan thread 2 create\nI0512 10:06:23.776012 346278 quickspan_execute.cc:54] quickspan thread 3 create\nI0512 10:06:23.776018 346278 quickspan_execute.cc:54] quickspan thread 4 create\nI0512 10:06:23.776023 346278 quickspan_execute.cc:54] quickspan thread 5 create\nI0512 10:06:23.776036 346278 quickspan_execute.cc:54] quickspan thread 6 create\nI0512 10:06:23.776041 346278 quickspan_execute.cc:54] quickspan thread 7 create\nI0512 10:06:26.756018 346278 quickspan.h:70] Signal received, halting mining and producing output...\nI0512 10:06:27.561856 346278 quickspan_execute.cc:36] quickspan mine graph time: 3.78586\nI0512 10:06:27.562144 346278 quickspan.cc:145] quickspan execute time: 3.79755\nI0512 10:06:27.562393 346278 quickspan.cc:155] quickspan save output time: 0.000217\n'
# 100% (10 of 10) |########################| Elapsed Time: 0:00:33 Time:  0:00:33
# INFO - 2022-05-12 10:06:27,581 - ToolChainClassifier - Total training time: 33.604363679885864
# INFO - 2022-05-12 10:06:27,581 - ToolChainClassifier - Total classification time: 33.604517459869385

# %%
# !python3 ToolChainClassifier/ToolChainClassifier.py --classifier=gspan  ../Tutorial/DATA/CLASS_DATA/TEST/
# Out:
# INFO - 2022-05-12 10:06:29,843 - ToolChainClassifier - ['../Tutorial/DATA/CLASS_DATA/TEST/ircbot', '../Tutorial/DATA/CLASS_DATA/TEST/shiz', '../Tutorial/DATA/CLASS_DATA/TEST/bancteian', '../Tutorial/DATA/CLASS_DATA/TEST/sfone', '../Tutorial/DATA/CLASS_DATA/TEST/simbot', '../Tutorial/DATA/CLASS_DATA/TEST/delf', '../Tutorial/DATA/CLASS_DATA/TEST/sytro', '../Tutorial/DATA/CLASS_DATA/TEST/autoit', '../Tutorial/DATA/CLASS_DATA/TEST/sillyp2p', '../Tutorial/DATA/CLASS_DATA/TEST/wabot']
# INFO - 2022-05-12 10:06:29,843 - ToolChainClassifier - Namespace(biggest_subgraph=5, binaries='../Tutorial/DATA/CLASS_DATA/TEST/', classifier='gspan', ctimeout=3, epoch=5, families=None, mode='classification', nthread=8, support=0.75, threshold=0.45, train=False, verbose_classifier=False)
# 100% (10 of 10) |########################| Elapsed Time: 0:04:41 Time:  0:04:41
# INFO:GSpanClassifier:Precision obtained : 0.8976190476190476
# INFO:GSpanClassifier:Recall obtained : 0.8599999999999999
# INFO:GSpanClassifier:Fscore obtained : 0.8784069357897588
# Figure(1000x700)
# INFO - 2022-05-12 10:11:11,936 - ToolChainClassifier - Total classification time: 282.0946915149689

# %% [markdown]
# This leads to this confusion matrix :
# ![Conf_matrix_gspan.png](attachment:Conf_matrix_gspan.png)

# %% [markdown]
# ### **Detect malware from cleanware**
# Finally, we could also train and use a classifier to distinguish malware from cleanware.

# %%
# !python3 ToolChainClassifier/ToolChainClassifier.py --mode=detection --train --classifier=wl  ../Tutorial/DATA/BIN_DATA/TRAIN/
# Out:
# INFO - 2022-05-12 10:11:13,212 - ToolChainClassifier - ['../Tutorial/DATA/BIN_DATA/TRAIN/malware', '../Tutorial/DATA/BIN_DATA/TRAIN/cleanware']
# INFO - 2022-05-12 10:11:13,212 - ToolChainClassifier - Namespace(biggest_subgraph=5, binaries='../Tutorial/DATA/BIN_DATA/TRAIN/', classifier='wl', ctimeout=3, epoch=5, families=None, mode='detection', nthread=8, support=0.75, threshold=0.45, train=True, verbose_classifier=False)
# INFO - 2022-05-12 10:11:13,307 - SVMWLClassifier - Path: ../Tutorial/DATA/BIN_DATA/TRAIN/
# N/A% (0 of 2) |                          | Elapsed Time: 0:00:00 ETA:  --:--:--INFO - 2022-05-12 10:11:13,309 - SVMWLClassifier - Subpath: /home/bertrandvano/Documents/SEMA-ToolChain/src/../Tutorial/DATA/BIN_DATA/TRAIN/malware/
# INFO - 2022-05-12 10:11:13,392 - SVMWLClassifier - Subpath: /home/bertrandvano/Documents/SEMA-ToolChain/src/../Tutorial/DATA/BIN_DATA/TRAIN/cleanware/
# 100% (2 of 2) |##########################| Elapsed Time: 0:00:00 Time:  0:00:00
# INFO - 2022-05-12 10:11:13,682 - SVMWLClassifier - Dataset len: 200
# INFO - 2022-05-12 10:11:14,452 - SVMWLClassifier - --------------------FIT OK----------------
# INFO - 2022-05-12 10:11:18,481 - ToolChainClassifier - Total training time: 5.2716028690338135
# INFO - 2022-05-12 10:11:18,481 - ToolChainClassifier - Total detection time: 5.27184271812439

# %%
# !python3 ToolChainClassifier/ToolChainClassifier.py --mode=detection --classifier=wl  ../Tutorial/DATA/BIN_DATA/TEST/
# Out:
# INFO - 2022-05-12 10:11:19,895 - ToolChainClassifier - ['../Tutorial/DATA/BIN_DATA/TEST/malware', '../Tutorial/DATA/BIN_DATA/TEST/cleanware']
# INFO - 2022-05-12 10:11:19,895 - ToolChainClassifier - Namespace(biggest_subgraph=5, binaries='../Tutorial/DATA/BIN_DATA/TEST/', classifier='wl', ctimeout=3, epoch=5, families=None, mode='detection', nthread=8, support=0.75, threshold=0.45, train=False, verbose_classifier=False)
# 100% (2 of 2) |##########################| Elapsed Time: 0:00:00 Time:  0:00:00
# INFO - 2022-05-12 10:11:21,003 - ToolChainClassifier - Total detection time: 1.1106009483337402

# %% [markdown]
# We could observe that our demo dataset is perfectly classifier for this task and with this classifier:
# ![Conf_matrix_detection.png](attachment:Conf_matrix_detection.png)
