# %% [markdown]
# # **SEMA-Classifier**

# %% [markdown]
# ![SEMA_illustration.png](attachment:SEMA_illustration.png)

# %% [markdown]
# ## **Using SEMA-Classifier**

# %%
# %matplotlib inline
# %matplotlib notebook
import os
os.chdir('../../src')
os.getcwd()
# !python3 ToolChainClassifier/ToolChainClassifier.py -h
# Out:
# usage: ToolChainClassifier.py [-h] [--train] [--classifier CLASSIFIER]
#                               [--threshold THRESHOLD]
#                               [--biggest_subgraph BIGGEST_SUBGRAPH]
#                               [--support SUPPORT] [--nthread NTHREAD]
#                               [--verbose_classifier] [--ctimeout CTIMEOUT]
#                               [--families FAMILIES [FAMILIES ...]]
#                               [--mode MODE] [--epoch EPOCH]
#                               binaries
#
# Classification module arguments
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --biggest_subgraph BIGGEST_SUBGRAPH
#                         Biggest subgraph consider for Gspan (default: 5)
#
# Classification module arguments:
#   --train               Launch training process, else classify/detect new
#                         sample with previously computed model
#   --classifier CLASSIFIER
#                         Classifier used for the analysis among
#                         (gspan,inria,wl,dl) (default : wl)
#   --threshold THRESHOLD
#                         Threshold used for the classifier [0..1] (default :
#                         0.45)
#   --support SUPPORT     Support used for the gpsan classifier [0..1] (default
#                         : 0.75)
#   --nthread NTHREAD     Number of thread used (default: max)
#   --verbose_classifier  Verbose output during train/classification (default :
#                         False)
#   --ctimeout CTIMEOUT   Timeout for gspan classifier (default : 3sec)
#   --families FAMILIES [FAMILIES ...]
#                         Families considered (default : ['bancteian','delf','Fe
#                         akerStealer','gandcrab','ircbot','lamer','nitol','RedL
#                         ineStealer','sfone','sillyp2p','simbot','Sodinokibi','
#                         sytro','upatre','wabot','RemcosRAT'])
#   --mode MODE           detection = binary decision cleanware vs malware OR
#                         classification = malware family (default)
#   --epoch EPOCH         Only for deep learning model: number of epoch
#                         (default: 5) Always 1 for FL model
#   binaries              Name of the folder containing binary'signatures to
#                         analyze (Default: output/save-SCDG/, only that for
#                         ToolChain)

# %% [markdown]
# ### **Classify SCDG**
# We classify SCDGs extracted from different malware. We will first use SVM with Weisfeiler-Lehman kernel classifier and train our model :

# %%
# !python3 ToolChainClassifier/ToolChainClassifier.py --train --classifier=wl  ../Tutorial/DATA/CLASS_DATA/TRAIN/
# Out:
# INFO - 2022-05-16 11:15:24,710 - ToolChainClassifier - ['../Tutorial/DATA/CLASS_DATA/TRAIN/ircbot', '../Tutorial/DATA/CLASS_DATA/TRAIN/shiz', '../Tutorial/DATA/CLASS_DATA/TRAIN/bancteian', '../Tutorial/DATA/CLASS_DATA/TRAIN/sfone', '../Tutorial/DATA/CLASS_DATA/TRAIN/simbot', '../Tutorial/DATA/CLASS_DATA/TRAIN/delf', '../Tutorial/DATA/CLASS_DATA/TRAIN/sytro', '../Tutorial/DATA/CLASS_DATA/TRAIN/autoit', '../Tutorial/DATA/CLASS_DATA/TRAIN/sillyp2p', '../Tutorial/DATA/CLASS_DATA/TRAIN/wabot']
# INFO - 2022-05-16 11:15:24,711 - ToolChainClassifier - Namespace(biggest_subgraph=5, binaries='../Tutorial/DATA/CLASS_DATA/TRAIN/', classifier='wl', ctimeout=3, epoch=5, families=None, mode='classification', nthread=8, support=0.75, threshold=0.45, train=True, verbose_classifier=False)
# INFO - 2022-05-16 11:15:24,801 - SVMWLClassifier - Path: ../Tutorial/DATA/CLASS_DATA/TRAIN/
# N/A% (0 of 10) |                         | Elapsed Time: 0:00:00 ETA:  --:--:--INFO - 2022-05-16 11:15:24,803 - SVMWLClassifier - Subpath: /home/bertrandvano/Documents/SEMA-ToolChain/src/../Tutorial/DATA/CLASS_DATA/TRAIN/ircbot/
# INFO - 2022-05-16 11:15:24,817 - SVMWLClassifier - Subpath: /home/bertrandvano/Documents/SEMA-ToolChain/src/../Tutorial/DATA/CLASS_DATA/TRAIN/shiz/
# INFO - 2022-05-16 11:15:24,855 - SVMWLClassifier - Subpath: /home/bertrandvano/Documents/SEMA-ToolChain/src/../Tutorial/DATA/CLASS_DATA/TRAIN/bancteian/
# INFO - 2022-05-16 11:15:24,863 - SVMWLClassifier - Subpath: /home/bertrandvano/Documents/SEMA-ToolChain/src/../Tutorial/DATA/CLASS_DATA/TRAIN/sfone/
# INFO - 2022-05-16 11:15:24,872 - SVMWLClassifier - Subpath: /home/bertrandvano/Documents/SEMA-ToolChain/src/../Tutorial/DATA/CLASS_DATA/TRAIN/simbot/
# INFO - 2022-05-16 11:15:24,881 - SVMWLClassifier - Subpath: /home/bertrandvano/Documents/SEMA-ToolChain/src/../Tutorial/DATA/CLASS_DATA/TRAIN/delf/
# INFO - 2022-05-16 11:15:24,903 - SVMWLClassifier - Subpath: /home/bertrandvano/Documents/SEMA-ToolChain/src/../Tutorial/DATA/CLASS_DATA/TRAIN/sytro/
# INFO - 2022-05-16 11:15:24,912 - SVMWLClassifier - Subpath: /home/bertrandvano/Documents/SEMA-ToolChain/src/../Tutorial/DATA/CLASS_DATA/TRAIN/autoit/
# INFO - 2022-05-16 11:15:25,024 - SVMWLClassifier - Subpath: /home/bertrandvano/Documents/SEMA-ToolChain/src/../Tutorial/DATA/CLASS_DATA/TRAIN/sillyp2p/
# INFO - 2022-05-16 11:15:25,034 - SVMWLClassifier - Subpath: /home/bertrandvano/Documents/SEMA-ToolChain/src/../Tutorial/DATA/CLASS_DATA/TRAIN/wabot/
# 100% (10 of 10) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# INFO - 2022-05-16 11:15:25,100 - SVMWLClassifier - Dataset len: 250
# INFO - 2022-05-16 11:15:26,248 - SVMWLClassifier - --------------------FIT OK----------------
# INFO - 2022-05-16 11:15:30,452 - ToolChainClassifier - Total training time: 5.7436017990112305
# INFO - 2022-05-16 11:15:30,452 - ToolChainClassifier - Total classification time: 5.743722677230835

# %% [markdown]
# We now have a working model that we will use to classify new data :

# %%
# !python3 ToolChainClassifier/ToolChainClassifier.py --classifier=wl  ../Tutorial/DATA/CLASS_DATA/TEST/
# Out:
# INFO - 2022-05-16 11:15:31,681 - ToolChainClassifier - ['../Tutorial/DATA/CLASS_DATA/TEST/ircbot', '../Tutorial/DATA/CLASS_DATA/TEST/shiz', '../Tutorial/DATA/CLASS_DATA/TEST/bancteian', '../Tutorial/DATA/CLASS_DATA/TEST/sfone', '../Tutorial/DATA/CLASS_DATA/TEST/simbot', '../Tutorial/DATA/CLASS_DATA/TEST/delf', '../Tutorial/DATA/CLASS_DATA/TEST/sytro', '../Tutorial/DATA/CLASS_DATA/TEST/autoit', '../Tutorial/DATA/CLASS_DATA/TEST/sillyp2p', '../Tutorial/DATA/CLASS_DATA/TEST/wabot']
# INFO - 2022-05-16 11:15:31,681 - ToolChainClassifier - Namespace(biggest_subgraph=5, binaries='../Tutorial/DATA/CLASS_DATA/TEST/', classifier='wl', ctimeout=3, epoch=5, families=None, mode='classification', nthread=8, support=0.75, threshold=0.45, train=False, verbose_classifier=False)
# 100% (10 of 10) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# INFO:SVMWLClassifier:Accuracy 98.00 %
# INFO:SVMWLClassifier:Precision 98.33 %
# INFO:SVMWLClassifier:Recall 98.00 %
# INFO:SVMWLClassifier:F1-score 97.98 %
# Figure(1000x700)
# INFO - 2022-05-16 11:15:32,296 - ToolChainClassifier - Total classification time: 0.6168262958526611

# %% [markdown]
# We get the following confusion matrix :
# ![Conf_matrix.png](attachment:Conf_matrix.png)

# %% [markdown]
# In a similar way, we could train another model and then use it to classify data. Note: make sure the submodule SEMA-quickspan (/src/submodules/) is correctly installed and compiled (https://github.com/csvl/SEMA-quickspan).

# %%
# !python3 ToolChainClassifier/ToolChainClassifier.py --train --classifier=gspan  ../Tutorial/DATA/CLASS_DATA/TRAIN/
# Out:
# INFO - 2022-05-16 11:15:33,505 - ToolChainClassifier - ['../Tutorial/DATA/CLASS_DATA/TRAIN/ircbot', '../Tutorial/DATA/CLASS_DATA/TRAIN/shiz', '../Tutorial/DATA/CLASS_DATA/TRAIN/bancteian', '../Tutorial/DATA/CLASS_DATA/TRAIN/sfone', '../Tutorial/DATA/CLASS_DATA/TRAIN/simbot', '../Tutorial/DATA/CLASS_DATA/TRAIN/delf', '../Tutorial/DATA/CLASS_DATA/TRAIN/sytro', '../Tutorial/DATA/CLASS_DATA/TRAIN/autoit', '../Tutorial/DATA/CLASS_DATA/TRAIN/sillyp2p', '../Tutorial/DATA/CLASS_DATA/TRAIN/wabot']
# INFO - 2022-05-16 11:15:33,505 - ToolChainClassifier - Namespace(biggest_subgraph=5, binaries='../Tutorial/DATA/CLASS_DATA/TRAIN/', classifier='gspan', ctimeout=3, epoch=5, families=None, mode='classification', nthread=8, support=0.75, threshold=0.45, train=True, verbose_classifier=False)
# INFO - 2022-05-16 11:15:33,507 - GSpanClassifier - Input Path = ../Tutorial/DATA/CLASS_DATA/TRAIN/
# N/A% (0 of 10) |                         | Elapsed Time: 0:00:00 ETA:  --:--:--INFO - 2022-05-16 11:15:33,510 - GSpanClassifier - Family = ircbot
# INFO - 2022-05-16 11:15:33,523 - GSpanClassifier - Gspan_path = /home/bertrandvano/Documents/SEMA-ToolChain/src/submodules/SEMA-quickspan/build/gspan --input_file /home/bertrandvano/Documents/SEMA-ToolChain/src/ToolChainClassifier/sig/ircbot_merge.gs --output_file /home/bertrandvano/Documents/SEMA-ToolChain/src/ToolChainClassifier/sig/ircbot_sig.gs --pattern --biggest_subgraphs 5 --threads 8 --timeout  3 --support 0.75
# INFO - 2022-05-16 11:15:37,000 - GSpanClassifier - b''
# INFO - 2022-05-16 11:15:37,002 - GSpanClassifier - b'I0516 11:15:33.533496 420468 quickspan.cc:92] quickspan timeout: 3\nI0516 11:15:33.534405 420468 quickspan.cc:118] quickspan read input time: 0.000874\nI0516 11:15:33.535647 420468 quickspan_execute.cc:27] quickspan construct graph time: 0.00123\nI0516 11:15:33.535655 420468 quickspan_execute.cc:54] quickspan thread 0 create\nI0516 11:15:33.535658 420468 quickspan_execute.cc:54] quickspan thread 1 create\nI0516 11:15:33.535661 420468 quickspan_execute.cc:54] quickspan thread 2 create\nI0516 11:15:33.535665 420468 quickspan_execute.cc:54] quickspan thread 3 create\nI0516 11:15:33.535666 420468 quickspan_execute.cc:54] quickspan thread 4 create\nI0516 11:15:33.535670 420468 quickspan_execute.cc:54] quickspan thread 5 create\nI0516 11:15:33.535671 420468 quickspan_execute.cc:54] quickspan thread 6 create\nI0516 11:15:33.535674 420468 quickspan_execute.cc:54] quickspan thread 7 create\nI0516 11:15:36.543426 420468 quickspan.h:70] Signal received, halting mining and producing output...\nI0516 11:15:36.920060 420468 quickspan_execute.cc:36] quickspan mine graph time: 3.3844\nI0516 11:15:36.922299 420468 quickspan.cc:145] quickspan execute time: 3.38788\nI0516 11:15:36.948494 420468 quickspan.cc:155] quickspan save output time: 0.026185\n'
#  10% (1 of 10) |##                       | Elapsed Time: 0:00:03 ETA:   0:00:31INFO - 2022-05-16 11:15:37,006 - GSpanClassifier - Family = shiz
# INFO - 2022-05-16 11:15:37,060 - GSpanClassifier - Gspan_path = /home/bertrandvano/Documents/SEMA-ToolChain/src/submodules/SEMA-quickspan/build/gspan --input_file /home/bertrandvano/Documents/SEMA-ToolChain/src/ToolChainClassifier/sig/shiz_merge.gs --output_file /home/bertrandvano/Documents/SEMA-ToolChain/src/ToolChainClassifier/sig/shiz_sig.gs --pattern --biggest_subgraphs 5 --threads 8 --timeout  3 --support 0.75
# INFO - 2022-05-16 11:15:40,823 - GSpanClassifier - b''
# INFO - 2022-05-16 11:15:40,823 - GSpanClassifier - b'I0516 11:15:37.078418 420495 quickspan.cc:92] quickspan timeout: 3\nI0516 11:15:37.086668 420495 quickspan.cc:118] quickspan read input time: 0.005513\nI0516 11:15:37.094341 420495 quickspan_execute.cc:27] quickspan construct graph time: 0.007637\nI0516 11:15:37.094364 420495 quickspan_execute.cc:54] quickspan thread 0 create\nI0516 11:15:37.094375 420495 quickspan_execute.cc:54] quickspan thread 1 create\nI0516 11:15:37.094383 420495 quickspan_execute.cc:54] quickspan thread 2 create\nI0516 11:15:37.094390 420495 quickspan_execute.cc:54] quickspan thread 3 create\nI0516 11:15:37.094396 420495 quickspan_execute.cc:54] quickspan thread 4 create\nI0516 11:15:37.094403 420495 quickspan_execute.cc:54] quickspan thread 5 create\nI0516 11:15:37.094408 420495 quickspan_execute.cc:54] quickspan thread 6 create\nI0516 11:15:37.094416 420495 quickspan_execute.cc:54] quickspan thread 7 create\nI0516 11:15:40.089365 420495 quickspan.h:70] Signal received, halting mining and producing output...\nI0516 11:15:40.788195 420495 quickspan_execute.cc:36] quickspan mine graph time: 3.69382\nI0516 11:15:40.788709 420495 quickspan.cc:145] quickspan execute time: 3.70192\nI0516 11:15:40.815676 420495 quickspan.cc:155] quickspan save output time: 0.02696\n'
#  20% (2 of 10) |#####                    | Elapsed Time: 0:00:07 ETA:   0:00:30INFO - 2022-05-16 11:15:40,824 - GSpanClassifier - Family = bancteian
# INFO - 2022-05-16 11:15:40,838 - GSpanClassifier - Gspan_path = /home/bertrandvano/Documents/SEMA-ToolChain/src/submodules/SEMA-quickspan/build/gspan --input_file /home/bertrandvano/Documents/SEMA-ToolChain/src/ToolChainClassifier/sig/bancteian_merge.gs --output_file /home/bertrandvano/Documents/SEMA-ToolChain/src/ToolChainClassifier/sig/bancteian_sig.gs --pattern --biggest_subgraphs 5 --threads 8 --timeout  3 --support 0.75
# INFO - 2022-05-16 11:15:43,864 - GSpanClassifier - b''
# INFO - 2022-05-16 11:15:43,864 - GSpanClassifier - b'I0516 11:15:40.845538 420518 quickspan.cc:92] quickspan timeout: 3\nI0516 11:15:40.846200 420518 quickspan.cc:118] quickspan read input time: 0.000623\nI0516 11:15:40.847074 420518 quickspan_execute.cc:27] quickspan construct graph time: 0.000858\nI0516 11:15:40.847085 420518 quickspan_execute.cc:54] quickspan thread 0 create\nI0516 11:15:40.847091 420518 quickspan_execute.cc:54] quickspan thread 1 create\nI0516 11:15:40.847095 420518 quickspan_execute.cc:54] quickspan thread 2 create\nI0516 11:15:40.847100 420518 quickspan_execute.cc:54] quickspan thread 3 create\nI0516 11:15:40.847106 420518 quickspan_execute.cc:54] quickspan thread 4 create\nI0516 11:15:40.847111 420518 quickspan_execute.cc:54] quickspan thread 5 create\nI0516 11:15:40.847116 420518 quickspan_execute.cc:54] quickspan thread 6 create\nI0516 11:15:40.847121 420518 quickspan_execute.cc:54] quickspan thread 7 create\nI0516 11:15:43.845592 420518 quickspan.h:70] Signal received, halting mining and producing output...\nI0516 11:15:43.859025 420518 quickspan_execute.cc:36] quickspan mine graph time: 3.01193\nI0516 11:15:43.859136 420518 quickspan.cc:145] quickspan execute time: 3.01292\nI0516 11:15:43.863436 420518 quickspan.cc:155] quickspan save output time: 0.004278\n'
#  30% (3 of 10) |#######                  | Elapsed Time: 0:00:10 ETA:   0:00:21INFO - 2022-05-16 11:15:43,865 - GSpanClassifier - Family = sfone
# INFO - 2022-05-16 11:15:43,878 - GSpanClassifier - Gspan_path = /home/bertrandvano/Documents/SEMA-ToolChain/src/submodules/SEMA-quickspan/build/gspan --input_file /home/bertrandvano/Documents/SEMA-ToolChain/src/ToolChainClassifier/sig/sfone_merge.gs --output_file /home/bertrandvano/Documents/SEMA-ToolChain/src/ToolChainClassifier/sig/sfone_sig.gs --pattern --biggest_subgraphs 5 --threads 8 --timeout  3 --support 0.75
# INFO - 2022-05-16 11:15:46,913 - GSpanClassifier - b''
# INFO - 2022-05-16 11:15:46,913 - GSpanClassifier - b'I0516 11:15:43.889751 420541 quickspan.cc:92] quickspan timeout: 3\nI0516 11:15:43.890461 420541 quickspan.cc:118] quickspan read input time: 0.00067\nI0516 11:15:43.891425 420541 quickspan_execute.cc:27] quickspan construct graph time: 0.000949\nI0516 11:15:43.891431 420541 quickspan_execute.cc:54] quickspan thread 0 create\nI0516 11:15:43.891435 420541 quickspan_execute.cc:54] quickspan thread 1 create\nI0516 11:15:43.891438 420541 quickspan_execute.cc:54] quickspan thread 2 create\nI0516 11:15:43.891440 420541 quickspan_execute.cc:54] quickspan thread 3 create\nI0516 11:15:43.891448 420541 quickspan_execute.cc:54] quickspan thread 4 create\nI0516 11:15:43.891451 420541 quickspan_execute.cc:54] quickspan thread 5 create\nI0516 11:15:43.891453 420541 quickspan_execute.cc:54] quickspan thread 6 create\nI0516 11:15:43.891455 420541 quickspan_execute.cc:54] quickspan thread 7 create\nI0516 11:15:46.893364 420541 quickspan.h:70] Signal received, halting mining and producing output...\nI0516 11:15:46.901716 420541 quickspan_execute.cc:36] quickspan mine graph time: 3.01028\nI0516 11:15:46.901841 420541 quickspan.cc:145] quickspan execute time: 3.01136\nI0516 11:15:46.911432 420541 quickspan.cc:155] quickspan save output time: 0.009572\n'
#  40% (4 of 10) |##########               | Elapsed Time: 0:00:13 ETA:   0:00:18INFO - 2022-05-16 11:15:46,914 - GSpanClassifier - Family = simbot
# INFO - 2022-05-16 11:15:46,933 - GSpanClassifier - Gspan_path = /home/bertrandvano/Documents/SEMA-ToolChain/src/submodules/SEMA-quickspan/build/gspan --input_file /home/bertrandvano/Documents/SEMA-ToolChain/src/ToolChainClassifier/sig/simbot_merge.gs --output_file /home/bertrandvano/Documents/SEMA-ToolChain/src/ToolChainClassifier/sig/simbot_sig.gs --pattern --biggest_subgraphs 5 --threads 8 --timeout  3 --support 0.75
# INFO - 2022-05-16 11:15:49,992 - GSpanClassifier - b''
# INFO - 2022-05-16 11:15:49,992 - GSpanClassifier - b'I0516 11:15:46.945909 420564 quickspan.cc:92] quickspan timeout: 3\nI0516 11:15:46.946831 420564 quickspan.cc:118] quickspan read input time: 0.000872\nI0516 11:15:46.948264 420564 quickspan_execute.cc:27] quickspan construct graph time: 0.001406\nI0516 11:15:46.948278 420564 quickspan_execute.cc:54] quickspan thread 0 create\nI0516 11:15:46.948285 420564 quickspan_execute.cc:54] quickspan thread 1 create\nI0516 11:15:46.948287 420564 quickspan_execute.cc:54] quickspan thread 2 create\nI0516 11:15:46.948292 420564 quickspan_execute.cc:54] quickspan thread 3 create\nI0516 11:15:46.948294 420564 quickspan_execute.cc:54] quickspan thread 4 create\nI0516 11:15:46.948297 420564 quickspan_execute.cc:54] quickspan thread 5 create\nI0516 11:15:46.948302 420564 quickspan_execute.cc:54] quickspan thread 6 create\nI0516 11:15:46.948305 420564 quickspan_execute.cc:54] quickspan thread 7 create\nI0516 11:15:49.946027 420564 quickspan.h:70] Signal received, halting mining and producing output...\nI0516 11:15:49.954042 420564 quickspan_execute.cc:36] quickspan mine graph time: 3.00574\nI0516 11:15:49.954295 420564 quickspan.cc:145] quickspan execute time: 3.00743\nI0516 11:15:49.972671 420564 quickspan.cc:155] quickspan save output time: 0.018351\n'
#  50% (5 of 10) |############             | Elapsed Time: 0:00:16 ETA:   0:00:15INFO - 2022-05-16 11:15:49,994 - GSpanClassifier - Family = delf
# INFO - 2022-05-16 11:15:50,024 - GSpanClassifier - Gspan_path = /home/bertrandvano/Documents/SEMA-ToolChain/src/submodules/SEMA-quickspan/build/gspan --input_file /home/bertrandvano/Documents/SEMA-ToolChain/src/ToolChainClassifier/sig/delf_merge.gs --output_file /home/bertrandvano/Documents/SEMA-ToolChain/src/ToolChainClassifier/sig/delf_sig.gs --pattern --biggest_subgraphs 5 --threads 8 --timeout  3 --support 0.75
# INFO - 2022-05-16 11:15:53,087 - GSpanClassifier - b''
# INFO - 2022-05-16 11:15:53,087 - GSpanClassifier - b'I0516 11:15:50.045099 420587 quickspan.cc:92] quickspan timeout: 3\nI0516 11:15:50.047864 420587 quickspan.cc:118] quickspan read input time: 0.002691\nI0516 11:15:50.050809 420587 quickspan_execute.cc:27] quickspan construct graph time: 0.002903\nI0516 11:15:50.050841 420587 quickspan_execute.cc:54] quickspan thread 0 create\nI0516 11:15:50.050850 420587 quickspan_execute.cc:54] quickspan thread 1 create\nI0516 11:15:50.050860 420587 quickspan_execute.cc:54] quickspan thread 2 create\nI0516 11:15:50.050879 420587 quickspan_execute.cc:54] quickspan thread 3 create\nI0516 11:15:50.050882 420587 quickspan_execute.cc:54] quickspan thread 4 create\nI0516 11:15:50.050887 420587 quickspan_execute.cc:54] quickspan thread 5 create\nI0516 11:15:50.050894 420587 quickspan_execute.cc:54] quickspan thread 6 create\nI0516 11:15:50.050899 420587 quickspan_execute.cc:54] quickspan thread 7 create\nI0516 11:15:53.045197 420587 quickspan.h:70] Signal received, halting mining and producing output...\nI0516 11:15:53.076407 420587 quickspan_execute.cc:36] quickspan mine graph time: 3.02556\nI0516 11:15:53.076654 420587 quickspan.cc:145] quickspan execute time: 3.02875\nI0516 11:15:53.078950 420587 quickspan.cc:155] quickspan save output time: 0.002268\n'
#  60% (6 of 10) |###############          | Elapsed Time: 0:00:19 ETA:   0:00:12INFO - 2022-05-16 11:15:53,089 - GSpanClassifier - Family = sytro
# INFO - 2022-05-16 11:15:53,112 - GSpanClassifier - Gspan_path = /home/bertrandvano/Documents/SEMA-ToolChain/src/submodules/SEMA-quickspan/build/gspan --input_file /home/bertrandvano/Documents/SEMA-ToolChain/src/ToolChainClassifier/sig/sytro_merge.gs --output_file /home/bertrandvano/Documents/SEMA-ToolChain/src/ToolChainClassifier/sig/sytro_sig.gs --pattern --biggest_subgraphs 5 --threads 8 --timeout  3 --support 0.75
# INFO - 2022-05-16 11:15:56,562 - GSpanClassifier - b''
# INFO - 2022-05-16 11:15:56,562 - GSpanClassifier - b'I0516 11:15:53.125797 420610 quickspan.cc:92] quickspan timeout: 3\nI0516 11:15:53.127900 420610 quickspan.cc:118] quickspan read input time: 0.002015\nI0516 11:15:53.130826 420610 quickspan_execute.cc:27] quickspan construct graph time: 0.002885\nI0516 11:15:53.130853 420610 quickspan_execute.cc:54] quickspan thread 0 create\nI0516 11:15:53.130877 420610 quickspan_execute.cc:54] quickspan thread 1 create\nI0516 11:15:53.130884 420610 quickspan_execute.cc:54] quickspan thread 2 create\nI0516 11:15:53.130892 420610 quickspan_execute.cc:54] quickspan thread 3 create\nI0516 11:15:53.130897 420610 quickspan_execute.cc:54] quickspan thread 4 create\nI0516 11:15:53.130904 420610 quickspan_execute.cc:54] quickspan thread 5 create\nI0516 11:15:53.130909 420610 quickspan_execute.cc:54] quickspan thread 6 create\nI0516 11:15:53.130916 420610 quickspan_execute.cc:54] quickspan thread 7 create\nI0516 11:15:56.125892 420610 quickspan.h:70] Signal received, halting mining and producing output...\nI0516 11:15:56.501379 420610 quickspan_execute.cc:36] quickspan mine graph time: 3.37052\nI0516 11:15:56.501549 420610 quickspan.cc:145] quickspan execute time: 3.37361\nI0516 11:15:56.518046 420610 quickspan.cc:155] quickspan save output time: 0.016467\n'
#  70% (7 of 10) |#################        | Elapsed Time: 0:00:23 ETA:   0:00:10INFO - 2022-05-16 11:15:56,563 - GSpanClassifier - Family = autoit
# INFO - 2022-05-16 11:15:56,585 - GSpanClassifier - Gspan_path = /home/bertrandvano/Documents/SEMA-ToolChain/src/submodules/SEMA-quickspan/build/gspan --input_file /home/bertrandvano/Documents/SEMA-ToolChain/src/ToolChainClassifier/sig/autoit_merge.gs --output_file /home/bertrandvano/Documents/SEMA-ToolChain/src/ToolChainClassifier/sig/autoit_sig.gs --pattern --biggest_subgraphs 5 --threads 8 --timeout  3 --support 0.75
# INFO - 2022-05-16 11:16:00,213 - GSpanClassifier - b''
# INFO - 2022-05-16 11:16:00,213 - GSpanClassifier - b'I0516 11:15:56.595010 420633 quickspan.cc:92] quickspan timeout: 3\nI0516 11:15:56.605295 420633 quickspan.cc:118] quickspan read input time: 0.010238\nI0516 11:15:56.624310 420633 quickspan_execute.cc:27] quickspan construct graph time: 0.018885\nI0516 11:15:56.624408 420633 quickspan_execute.cc:54] quickspan thread 0 create\nI0516 11:15:56.624430 420633 quickspan_execute.cc:54] quickspan thread 1 create\nI0516 11:15:56.624439 420633 quickspan_execute.cc:54] quickspan thread 2 create\nI0516 11:15:56.624473 420633 quickspan_execute.cc:54] quickspan thread 3 create\nI0516 11:15:56.624485 420633 quickspan_execute.cc:54] quickspan thread 4 create\nI0516 11:15:56.624497 420633 quickspan_execute.cc:54] quickspan thread 5 create\nI0516 11:15:56.624507 420633 quickspan_execute.cc:54] quickspan thread 6 create\nI0516 11:15:56.624521 420633 quickspan_execute.cc:54] quickspan thread 7 create\nI0516 11:15:59.598757 420633 quickspan.h:70] Signal received, halting mining and producing output...\nI0516 11:16:00.173830 420633 quickspan_execute.cc:36] quickspan mine graph time: 3.54941\nI0516 11:16:00.174459 420633 quickspan.cc:145] quickspan execute time: 3.56911\nI0516 11:16:00.179546 420633 quickspan.cc:155] quickspan save output time: 0.005073\n'
#  80% (8 of 10) |####################     | Elapsed Time: 0:00:26 ETA:   0:00:07INFO - 2022-05-16 11:16:00,214 - GSpanClassifier - Family = sillyp2p
# INFO - 2022-05-16 11:16:00,235 - GSpanClassifier - Gspan_path = /home/bertrandvano/Documents/SEMA-ToolChain/src/submodules/SEMA-quickspan/build/gspan --input_file /home/bertrandvano/Documents/SEMA-ToolChain/src/ToolChainClassifier/sig/sillyp2p_merge.gs --output_file /home/bertrandvano/Documents/SEMA-ToolChain/src/ToolChainClassifier/sig/sillyp2p_sig.gs --pattern --biggest_subgraphs 5 --threads 8 --timeout  3 --support 0.75
# INFO - 2022-05-16 11:16:03,279 - GSpanClassifier - b''
# INFO - 2022-05-16 11:16:03,279 - GSpanClassifier - b'I0516 11:16:00.249399 420663 quickspan.cc:92] quickspan timeout: 3\nI0516 11:16:00.251344 420663 quickspan.cc:118] quickspan read input time: 0.001778\nI0516 11:16:00.253849 420663 quickspan_execute.cc:27] quickspan construct graph time: 0.002464\nI0516 11:16:00.253873 420663 quickspan_execute.cc:54] quickspan thread 0 create\nI0516 11:16:00.253880 420663 quickspan_execute.cc:54] quickspan thread 1 create\nI0516 11:16:00.253883 420663 quickspan_execute.cc:54] quickspan thread 2 create\nI0516 11:16:00.253890 420663 quickspan_execute.cc:54] quickspan thread 3 create\nI0516 11:16:00.253892 420663 quickspan_execute.cc:54] quickspan thread 4 create\nI0516 11:16:00.253898 420663 quickspan_execute.cc:54] quickspan thread 5 create\nI0516 11:16:00.253904 420663 quickspan_execute.cc:54] quickspan thread 6 create\nI0516 11:16:00.253906 420663 quickspan_execute.cc:54] quickspan thread 7 create\nI0516 11:16:03.249569 420663 quickspan.h:70] Signal received, halting mining and producing output...\nI0516 11:16:03.252898 420663 quickspan_execute.cc:36] quickspan mine graph time: 2.99902\nI0516 11:16:03.253073 420663 quickspan.cc:145] quickspan execute time: 3.00168\nI0516 11:16:03.277449 420663 quickspan.cc:155] quickspan save output time: 0.024349\n'
#  90% (9 of 10) |######################   | Elapsed Time: 0:00:29 ETA:   0:00:03INFO - 2022-05-16 11:16:03,280 - GSpanClassifier - Family = wabot
# INFO - 2022-05-16 11:16:03,304 - GSpanClassifier - Gspan_path = /home/bertrandvano/Documents/SEMA-ToolChain/src/submodules/SEMA-quickspan/build/gspan --input_file /home/bertrandvano/Documents/SEMA-ToolChain/src/ToolChainClassifier/sig/wabot_merge.gs --output_file /home/bertrandvano/Documents/SEMA-ToolChain/src/ToolChainClassifier/sig/wabot_sig.gs --pattern --biggest_subgraphs 5 --threads 8 --timeout  3 --support 0.75
# INFO - 2022-05-16 11:16:06,834 - GSpanClassifier - b''
# INFO - 2022-05-16 11:16:06,835 - GSpanClassifier - b'I0516 11:16:03.316148 420690 quickspan.cc:92] quickspan timeout: 3\nI0516 11:16:03.333076 420690 quickspan.cc:118] quickspan read input time: 0.016854\nI0516 11:16:03.349874 420690 quickspan_execute.cc:27] quickspan construct graph time: 0.016753\nI0516 11:16:03.349903 420690 quickspan_execute.cc:54] quickspan thread 0 create\nI0516 11:16:03.349913 420690 quickspan_execute.cc:54] quickspan thread 1 create\nI0516 11:16:03.349934 420690 quickspan_execute.cc:54] quickspan thread 2 create\nI0516 11:16:03.349946 420690 quickspan_execute.cc:54] quickspan thread 3 create\nI0516 11:16:03.349951 420690 quickspan_execute.cc:54] quickspan thread 4 create\nI0516 11:16:03.349956 420690 quickspan_execute.cc:54] quickspan thread 5 create\nI0516 11:16:03.349962 420690 quickspan_execute.cc:54] quickspan thread 6 create\nI0516 11:16:03.349968 420690 quickspan_execute.cc:54] quickspan thread 7 create\nI0516 11:16:06.319398 420690 quickspan.h:70] Signal received, halting mining and producing output...\nI0516 11:16:06.805377 420690 quickspan_execute.cc:36] quickspan mine graph time: 3.45546\nI0516 11:16:06.805598 420690 quickspan.cc:145] quickspan execute time: 3.47248\nI0516 11:16:06.820797 420690 quickspan.cc:155] quickspan save output time: 0.015181\n'
# 100% (10 of 10) |########################| Elapsed Time: 0:00:33 Time:  0:00:33
# INFO - 2022-05-16 11:16:06,840 - ToolChainClassifier - Total training time: 33.335707902908325
# INFO - 2022-05-16 11:16:06,840 - ToolChainClassifier - Total classification time: 33.33578824996948

# %%
# !python3 ToolChainClassifier/ToolChainClassifier.py --classifier=gspan  ../Tutorial/DATA/CLASS_DATA/TEST/
# Out:
# INFO - 2022-05-16 11:16:09,167 - ToolChainClassifier - ['../Tutorial/DATA/CLASS_DATA/TEST/ircbot', '../Tutorial/DATA/CLASS_DATA/TEST/shiz', '../Tutorial/DATA/CLASS_DATA/TEST/bancteian', '../Tutorial/DATA/CLASS_DATA/TEST/sfone', '../Tutorial/DATA/CLASS_DATA/TEST/simbot', '../Tutorial/DATA/CLASS_DATA/TEST/delf', '../Tutorial/DATA/CLASS_DATA/TEST/sytro', '../Tutorial/DATA/CLASS_DATA/TEST/autoit', '../Tutorial/DATA/CLASS_DATA/TEST/sillyp2p', '../Tutorial/DATA/CLASS_DATA/TEST/wabot']
# INFO - 2022-05-16 11:16:09,167 - ToolChainClassifier - Namespace(biggest_subgraph=5, binaries='../Tutorial/DATA/CLASS_DATA/TEST/', classifier='gspan', ctimeout=3, epoch=5, families=None, mode='classification', nthread=8, support=0.75, threshold=0.45, train=False, verbose_classifier=False)
# 100% (10 of 10) |########################| Elapsed Time: 0:03:33 Time:  0:03:33
# INFO:GSpanClassifier:Precision obtained : 0.8833333333333333
# INFO:GSpanClassifier:Recall obtained : 0.88
# INFO:GSpanClassifier:Fscore obtained : 0.8816635160680529
# Figure(1000x700)
# INFO - 2022-05-16 11:19:42,736 - ToolChainClassifier - Total classification time: 213.57055568695068

# %% [markdown]
# This leads to this confusion matrix :
# ![Conf_matrix_gspan.png](attachment:Conf_matrix_gspan.png)

# %% [markdown]
# ### **Detect malware from cleanware**
# Finally, we could also train and use a classifier to distinguish malware from cleanware.

# %%
# !python3 ToolChainClassifier/ToolChainClassifier.py --mode=detection --train --classifier=wl  ../Tutorial/DATA/BIN_DATA/TRAIN/
# Out:
# INFO - 2022-05-16 11:19:45,061 - ToolChainClassifier - ['../Tutorial/DATA/BIN_DATA/TRAIN/malware', '../Tutorial/DATA/BIN_DATA/TRAIN/cleanware']
# INFO - 2022-05-16 11:19:45,061 - ToolChainClassifier - Namespace(biggest_subgraph=5, binaries='../Tutorial/DATA/BIN_DATA/TRAIN/', classifier='wl', ctimeout=3, epoch=5, families=None, mode='detection', nthread=8, support=0.75, threshold=0.45, train=True, verbose_classifier=False)
# INFO - 2022-05-16 11:19:45,230 - SVMWLClassifier - Path: ../Tutorial/DATA/BIN_DATA/TRAIN/
# N/A% (0 of 2) |                          | Elapsed Time: 0:00:00 ETA:  --:--:--INFO - 2022-05-16 11:19:45,236 - SVMWLClassifier - Subpath: /home/bertrandvano/Documents/SEMA-ToolChain/src/../Tutorial/DATA/BIN_DATA/TRAIN/malware/
# INFO - 2022-05-16 11:19:45,330 - SVMWLClassifier - Subpath: /home/bertrandvano/Documents/SEMA-ToolChain/src/../Tutorial/DATA/BIN_DATA/TRAIN/cleanware/
# 100% (2 of 2) |##########################| Elapsed Time: 0:00:00 Time:  0:00:00
# INFO - 2022-05-16 11:19:45,648 - SVMWLClassifier - Dataset len: 200
# INFO - 2022-05-16 11:19:46,615 - SVMWLClassifier - --------------------FIT OK----------------
# INFO - 2022-05-16 11:19:50,624 - ToolChainClassifier - Total training time: 5.564464330673218
# INFO - 2022-05-16 11:19:50,624 - ToolChainClassifier - Total detection time: 5.56459903717041

# %%
# !python3 ToolChainClassifier/ToolChainClassifier.py --mode=detection --classifier=wl  ../Tutorial/DATA/BIN_DATA/TEST/
# Out:
# INFO - 2022-05-16 11:19:52,134 - ToolChainClassifier - ['../Tutorial/DATA/BIN_DATA/TEST/malware', '../Tutorial/DATA/BIN_DATA/TEST/cleanware']
# INFO - 2022-05-16 11:19:52,134 - ToolChainClassifier - Namespace(biggest_subgraph=5, binaries='../Tutorial/DATA/BIN_DATA/TEST/', classifier='wl', ctimeout=3, epoch=5, families=None, mode='detection', nthread=8, support=0.75, threshold=0.45, train=False, verbose_classifier=False)
# 100% (2 of 2) |##########################| Elapsed Time: 0:00:00 Time:  0:00:00
# INFO - 2022-05-16 11:19:52,467 - ToolChainClassifier - Total detection time: 0.3332078456878662

# %% [markdown]
# We could observe that our demo dataset is perfectly classifier for this task and with this classifier:
# ![Conf_matrix_detection.png](attachment:Conf_matrix_detection.png)
