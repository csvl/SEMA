# %% [markdown]
# # **SEMA-SCDG**

# %% [markdown]
# ![SEMA_illustration.png](attachment:SEMA_illustration.png)

# %% [markdown]
# ## **Using SEMA toolchain**

# %%
import os
os.chdir('..')
# !python3 SemaSCDG.py -h
# Out:
# usage: SemaSCDG.py [-h] config_file
#
# SCDG module arguments
#
# positional arguments:
#   config_file  The relative path to the config file
#
# options:
#   -h, --help   show this help message and exit

# %% [markdown]
# ### **Extract SCDG**
# We extract SCDGs from binaries of example code. We use the config file at ./configs/config_tutorial.ini which specifies to use the CDFS exploration techniques, the json output type and the name of the output directory should be Tutorial_output. The analysed binary is set as Tutorial/DATA/Example_SEMA_code1.exe

# %%
# !python3 SemaSCDG.py Tutorial/config_tutorial.ini
# Out:
# INFO - 2024-05-20 10:53:44,800 - SemaSCDG - Results wil be saved into : database/SCDG/runs/Tutorial_output/
# INFO - 2024-05-20 10:53:44,800 - SemaSCDG - You decide to analyse a single binary: Tutorial/DATA/Example_SEMA_code1.exe
# INFO - 2024-05-20 10:53:44,803 - SemaSCDG -
# ------------------------------------------------------------
# --- Building SCDG of Binaryfamily/Example_SEMA_code1.exe ---
# ------------------------------------------------------------
# INFO    | 2024-05-20 10:53:44,803 | angr.project | Loading binary Tutorial/DATA/Example_SEMA_code1.exe
# WARNING | 2024-05-20 10:53:44,811 | angr.project | Disabling IRSB translation cache because support for self-modifying code is enabled.
# INFO    | 2024-05-20 10:53:46,386 | angr.project | Using builtin SimProcedure for unresolved DeleteCriticalSection from kernel32.dll
# INFO    | 2024-05-20 10:53:46,387 | angr.project | Using builtin SimProcedure for unresolved EnterCriticalSection from kernel32.dll
# INFO    | 2024-05-20 10:53:46,387 | angr.project | Using builtin SimProcedure for unresolved ExitProcess from kernel32.dll
# INFO    | 2024-05-20 10:53:46,387 | angr.project | Using builtin SimProcedure for unresolved FindClose from kernel32.dll
# INFO    | 2024-05-20 10:53:46,387 | angr.project | Using builtin SimProcedure for unresolved FindFirstFileA from kernel32.dll
# INFO    | 2024-05-20 10:53:46,387 | angr.project | Using builtin SimProcedure for unresolved FindNextFileA from kernel32.dll
# INFO    | 2024-05-20 10:53:46,388 | angr.project | Using builtin SimProcedure for unresolved FreeLibrary from kernel32.dll
# INFO    | 2024-05-20 10:53:46,388 | angr.project | Using builtin SimProcedure for unresolved GetCommandLineA from kernel32.dll
# INFO    | 2024-05-20 10:53:46,388 | angr.project | Using builtin SimProcedure for unresolved GetLastError from kernel32.dll
# INFO    | 2024-05-20 10:53:46,388 | angr.project | Using builtin SimProcedure for unresolved GetModuleHandleA from kernel32.dll
# INFO    | 2024-05-20 10:53:46,388 | angr.project | Using builtin SimProcedure for unresolved GetProcAddress from kernel32.dll
# INFO    | 2024-05-20 10:53:46,388 | angr.project | Using builtin SimProcedure for unresolved GetTickCount from kernel32.dll
# INFO    | 2024-05-20 10:53:46,389 | angr.project | Using builtin SimProcedure for unresolved InitializeCriticalSection from kernel32.dll
# INFO    | 2024-05-20 10:53:46,389 | angr.project | Using builtin SimProcedure for unresolved IsDebuggerPresent from kernel32.dll
# INFO    | 2024-05-20 10:53:46,389 | angr.project | Using builtin SimProcedure for unresolved LeaveCriticalSection from kernel32.dll
# INFO    | 2024-05-20 10:53:46,389 | angr.project | Using builtin SimProcedure for unresolved LoadLibraryA from kernel32.dll
# INFO    | 2024-05-20 10:53:46,389 | angr.project | Using builtin SimProcedure for unresolved SetUnhandledExceptionFilter from kernel32.dll
# INFO    | 2024-05-20 10:53:46,390 | angr.project | Using builtin SimProcedure for unresolved Sleep from kernel32.dll
# INFO    | 2024-05-20 10:53:46,390 | angr.project | Using builtin SimProcedure for unresolved TlsGetValue from kernel32.dll
# INFO    | 2024-05-20 10:53:46,390 | angr.project | Using builtin SimProcedure for unresolved VirtualProtect from kernel32.dll
# INFO    | 2024-05-20 10:53:46,390 | angr.project | Using builtin SimProcedure for unresolved VirtualQuery from kernel32.dll
# INFO    | 2024-05-20 10:53:46,391 | angr.project | Using builtin SimProcedure for unresolved _strdup from msvcrt.dll
# INFO    | 2024-05-20 10:53:46,391 | angr.project | Using builtin SimProcedure for unresolved _stricoll from msvcrt.dll
# INFO    | 2024-05-20 10:53:46,391 | angr.project | Using builtin SimProcedure for unresolved __getmainargs from msvcrt.dll
# INFO    | 2024-05-20 10:53:46,391 | angr.project | Using builtin SimProcedure for unresolved __mb_cur_max from msvcrt.dll
# INFO    | 2024-05-20 10:53:46,391 | angr.project | Using builtin SimProcedure for unresolved __p__environ from msvcrt.dll
# INFO    | 2024-05-20 10:53:46,391 | angr.project | Using builtin SimProcedure for unresolved __p__fmode from msvcrt.dll
# INFO    | 2024-05-20 10:53:46,391 | angr.project | Using builtin SimProcedure for unresolved __set_app_type from msvcrt.dll
# INFO    | 2024-05-20 10:53:46,391 | angr.project | Using builtin SimProcedure for unresolved _cexit from msvcrt.dll
# INFO    | 2024-05-20 10:53:46,392 | angr.project | Using builtin SimProcedure for unresolved _errno from msvcrt.dll
# INFO    | 2024-05-20 10:53:46,392 | angr.project | Using builtin SimProcedure for unresolved _fpreset from msvcrt.dll
# INFO    | 2024-05-20 10:53:46,392 | angr.project | Using builtin SimProcedure for unresolved _fullpath from msvcrt.dll
# INFO    | 2024-05-20 10:53:46,392 | angr.project | Using builtin SimProcedure for unresolved _iob from msvcrt.dll
# INFO    | 2024-05-20 10:53:46,392 | angr.project | Using builtin SimProcedure for unresolved _isctype from msvcrt.dll
# INFO    | 2024-05-20 10:53:46,392 | angr.project | Using builtin SimProcedure for unresolved _onexit from msvcrt.dll
# INFO    | 2024-05-20 10:53:46,392 | angr.project | Using builtin SimProcedure for unresolved _pctype from msvcrt.dll
# INFO    | 2024-05-20 10:53:46,392 | angr.project | Using builtin SimProcedure for unresolved _setmode from msvcrt.dll
# INFO    | 2024-05-20 10:53:46,393 | angr.project | Using builtin SimProcedure for unresolved abort from msvcrt.dll
# INFO    | 2024-05-20 10:53:46,393 | angr.project | Using builtin SimProcedure for unresolved atexit from msvcrt.dll
# INFO    | 2024-05-20 10:53:46,393 | angr.project | Using builtin SimProcedure for unresolved calloc from msvcrt.dll
# INFO    | 2024-05-20 10:53:46,393 | angr.project | Using builtin SimProcedure for unresolved exit from msvcrt.dll
# INFO    | 2024-05-20 10:53:46,393 | angr.project | Using builtin SimProcedure for unresolved free from msvcrt.dll
# INFO    | 2024-05-20 10:53:46,393 | angr.project | Using builtin SimProcedure for unresolved fwrite from msvcrt.dll
# INFO    | 2024-05-20 10:53:46,394 | angr.project | Using builtin SimProcedure for unresolved malloc from msvcrt.dll
# INFO    | 2024-05-20 10:53:46,394 | angr.project | Using builtin SimProcedure for unresolved mbstowcs from msvcrt.dll
# INFO    | 2024-05-20 10:53:46,394 | angr.project | Using builtin SimProcedure for unresolved memcpy from msvcrt.dll
# INFO    | 2024-05-20 10:53:46,394 | angr.project | Using builtin SimProcedure for unresolved realloc from msvcrt.dll
# INFO    | 2024-05-20 10:53:46,394 | angr.project | Using builtin SimProcedure for unresolved setlocale from msvcrt.dll
# INFO    | 2024-05-20 10:53:46,394 | angr.project | Using builtin SimProcedure for unresolved signal from msvcrt.dll
# INFO    | 2024-05-20 10:53:46,395 | angr.project | Using builtin SimProcedure for unresolved strcoll from msvcrt.dll
# INFO    | 2024-05-20 10:53:46,395 | angr.project | Using builtin SimProcedure for unresolved strlen from msvcrt.dll
# INFO    | 2024-05-20 10:53:46,395 | angr.project | Using builtin SimProcedure for unresolved tolower from msvcrt.dll
# INFO    | 2024-05-20 10:53:46,395 | angr.project | Using builtin SimProcedure for unresolved vfprintf from msvcrt.dll
# INFO    | 2024-05-20 10:53:46,395 | angr.project | Using builtin SimProcedure for unresolved wcstombs from msvcrt.dll
# INFO    | 2024-05-20 10:53:46,395 | angr.project | Using builtin SimProcedure for unresolved MessageBoxA from user32.dll
# INFO - 2024-05-20 10:53:46,396 - SemaSCDG - Libraries used are :
#  {'msvcrt.dll', 'user32.dll', 'kernel32.dll'}
# INFO - 2024-05-20 10:53:46,397 - SemaSCDG - OS recognized as : windows
# INFO - 2024-05-20 10:53:46,397 - SemaSCDG - CPU architecture recognized as : <Arch X86 (LE)>
# INFO - 2024-05-20 10:53:46,397 - SemaSCDG - Entry point of the binary recognized as : 0x4012e0
# INFO - 2024-05-20 10:53:46,397 - SemaSCDG - Min/Max addresses of the binary recognized as : <Loaded Example_SEMA_code1.exe, maps [0x400000:0x70141a]>
# INFO - 2024-05-20 10:53:46,397 - SemaSCDG - Stack executable ?  False
# INFO - 2024-05-20 10:53:46,397 - SemaSCDG - Binary position-independent ?  False
# INFO - 2024-05-20 10:53:46,397 - SemaSCDG - Exploration method:  CDFS
# INFO - 2024-05-20 10:53:46,434 - SemaSCDG - System call table loaded
# WARN: Relocs has not been applied. Please use `-e bin.relocs.apply=true` or `-e bin.cache=true` next time
# INFO - 2024-05-20 10:53:46,672 - SemaSCDG - Entry_state address = 4199520
# INFO - 2024-05-20 10:53:55,353 - WindowsSimProcedure - Was in angr :msvcrt.dll
# WARNING | 2024-05-20 10:53:55,400 | angr.project | Address is already hooked, during hook(0x500064, <SimProcedure __p__environ>). Not re-hooking.
# WARNING | 2024-05-20 10:53:55,401 | angr.project | Address is already hooked, during hook(0x500088, <SimProcedure _onexit>). Not re-hooking.
# WARNING | 2024-05-20 10:53:55,401 | angr.project | Address is already hooked, during hook(0x5000c4, <SimProcedure strcoll>). Not re-hooking.
# WARNING | 2024-05-20 10:53:55,401 | angr.project | Address is already hooked, during hook(0x500084, <SimProcedure _isctype>). Not re-hooking.
# WARNING | 2024-05-20 10:53:55,401 | angr.project | Address is already hooked, during hook(0x500074, <SimProcedure _errno>). Not re-hooking.
# WARNING | 2024-05-20 10:53:55,402 | angr.project | Address is already hooked, during hook(0x500098, <SimProcedure atexit>). Not re-hooking.
# WARNING | 2024-05-20 10:53:55,402 | angr.project | Address is already hooked, during hook(0x500058, <SimProcedure _stricoll>). Not re-hooking.
# WARNING | 2024-05-20 10:53:55,402 | angr.project | Address is already hooked, during hook(0x5000d4, <SimProcedure wcstombs>). Not re-hooking.
# WARNING | 2024-05-20 10:53:55,402 | angr.project | Address is already hooked, during hook(0x5000b0, <SimProcedure mbstowcs>). Not re-hooking.
# WARNING | 2024-05-20 10:53:55,402 | angr.project | Address is already hooked, during hook(0x5000d0, <SimProcedure vfprintf>). Not re-hooking.
# WARNING | 2024-05-20 10:53:55,403 | angr.project | Address is already hooked, during hook(0x50007c, <SimProcedure _fullpath>). Not re-hooking.
# INFO - 2024-05-20 10:53:55,432 - WindowsSimProcedure - Was in angr :user32.dll
# WARNING - 2024-05-20 10:53:55,435 - WindowsSimProcedure - Procedure wsprintfA in DLL user32.dll has 3 arguments in json and 2 arguments in angr prototype. Taking number of arguments from json.
# WARNING - 2024-05-20 10:53:55,435 - WindowsSimProcedure - Procedure wsprintfW in DLL user32.dll has 3 arguments in json and 2 arguments in angr prototype. Taking number of arguments from json.
# WARNING | 2024-05-20 10:53:55,488 | angr.project | Address is already hooked, during hook(0x5000d8, <SimProcedure MessageBoxA>). Not re-hooking.
# INFO - 2024-05-20 10:53:56,048 - WindowsSimProcedure - Was in angr :kernel32.dll
# WARNING | 2024-05-20 10:53:56,149 | angr.project | Address is already hooked, during hook(0x500038, <SimProcedure LeaveCriticalSection>). Not re-hooking.
# WARNING | 2024-05-20 10:53:56,149 | angr.project | Address is already hooked, during hook(0x500000, <SimProcedure DeleteCriticalSection>). Not re-hooking.
# WARNING | 2024-05-20 10:53:56,149 | angr.project | Address is already hooked, during hook(0x500004, <SimProcedure EnterCriticalSection>). Not re-hooking.
# WARNING | 2024-05-20 10:53:56,150 | angr.project | Address is already hooked, during hook(0x500030, <SimProcedure InitializeCriticalSection>). Not re-hooking.
# WARNING | 2024-05-20 10:53:56,150 | angr.project | Address is already hooked, during hook(0x500044, <SimProcedure Sleep>). Not re-hooking.
# WARNING | 2024-05-20 10:53:56,220 | angr.project | Address is already hooked, during hook(0x50005c, <SimProcedure __getmainargs>). Not re-hooking.
# WARNING | 2024-05-20 10:53:56,220 | angr.project | Address is already hooked, during hook(0x601014, <SimProcedure KiUserExceptionDispatcher>). Not re-hooking.
# INFO - 2024-05-20 10:53:56,220 - WindowsSimProcedure - No hooks for: {'__mb_cur_max': 5242976, '__set_app_type': 5242988, '_cexit': 5242992, '_fpreset': 5243000, '_iob': 5243008, '_pctype': 5243020, '_setmode': 5243024, 'setlocale': 5243068, 'signal': 5243072, '_fmode': 6295576, '_commode': 6295580, '_acmdln': 6295584, '_wcmdln': 6295588}
# INFO - 2024-05-20 10:53:56,220 - WindowsSimProcedure - custom_hook_static_windows
# WARNING | 2024-05-20 10:53:56,220 | angr.project | Address 0x400000 not hooked
# INFO - 2024-05-20 10:53:56,221 - WindowsSimProcedure - custom_hook_windows_symbols
# WARNING | 2024-05-20 10:53:56,225 | angr.project | Address is already hooked, during hook(0x500000, <SimProcedure DeleteCriticalSection>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,226 | angr.project | Address is already hooked, during hook(0x500000, <SimProcedure DeleteCriticalSection>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,226 | angr.project | Address is already hooked, during hook(0x500004, <SimProcedure EnterCriticalSection>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,226 | angr.project | Address is already hooked, during hook(0x500004, <SimProcedure EnterCriticalSection>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,234 | angr.project | Address is already hooked, during hook(0x500038, <SimProcedure LeaveCriticalSection>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,234 | angr.project | Address is already hooked, during hook(0x500038, <SimProcedure LeaveCriticalSection>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,240 | angr.project | Address is already hooked, during hook(0x500044, <SimProcedure Sleep>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,240 | angr.project | Address is already hooked, during hook(0x500044, <SimProcedure Sleep>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,246 | angr.project | Address is already hooked, during hook(0x500038, <SimProcedure LeaveCriticalSection>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,246 | angr.project | Address is already hooked, during hook(0x500038, <SimProcedure LeaveCriticalSection>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,247 | angr.project | Address is already hooked, during hook(0x500000, <SimProcedure DeleteCriticalSection>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,247 | angr.project | Address is already hooked, during hook(0x500000, <SimProcedure DeleteCriticalSection>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,251 | angr.project | Address is already hooked, during hook(0x500030, <SimProcedure InitializeCriticalSection>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,251 | angr.project | Address is already hooked, during hook(0x500030, <SimProcedure InitializeCriticalSection>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,256 | angr.project | Address is already hooked, during hook(0x500004, <SimProcedure EnterCriticalSection>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,256 | angr.project | Address is already hooked, during hook(0x500004, <SimProcedure EnterCriticalSection>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,259 | angr.project | Address is already hooked, during hook(0x500030, <SimProcedure InitializeCriticalSection>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,259 | angr.project | Address is already hooked, during hook(0x500030, <SimProcedure InitializeCriticalSection>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,261 | angr.project | Address is already hooked, during hook(0x500044, <SimProcedure Sleep>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,261 | angr.project | Address is already hooked, during hook(0x500044, <SimProcedure Sleep>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,261 | angr.project | Address is already hooked, during hook(0x500064, <SimProcedure __p__environ>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,261 | angr.project | Address is already hooked, during hook(0x500064, <SimProcedure __p__environ>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,263 | angr.project | Address is already hooked, during hook(0x500064, <SimProcedure __p__environ>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,263 | angr.project | Address is already hooked, during hook(0x500064, <SimProcedure __p__environ>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,264 | angr.project | Address is already hooked, during hook(0x500088, <SimProcedure _onexit>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,264 | angr.project | Address is already hooked, during hook(0x500088, <SimProcedure _onexit>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,264 | angr.project | Address is already hooked, during hook(0x500074, <SimProcedure _errno>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,265 | angr.project | Address is already hooked, during hook(0x500074, <SimProcedure _errno>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,265 | angr.project | Address is already hooked, during hook(0x50007c, <SimProcedure _fullpath>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,266 | angr.project | Address is already hooked, during hook(0x50007c, <SimProcedure _fullpath>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,266 | angr.project | Address is already hooked, during hook(0x500084, <SimProcedure _isctype>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,266 | angr.project | Address is already hooked, during hook(0x500084, <SimProcedure _isctype>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,267 | angr.project | Address is already hooked, during hook(0x5000c4, <SimProcedure strcoll>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,267 | angr.project | Address is already hooked, during hook(0x5000c4, <SimProcedure strcoll>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,269 | angr.project | Address is already hooked, during hook(0x500088, <SimProcedure _onexit>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,269 | angr.project | Address is already hooked, during hook(0x500088, <SimProcedure _onexit>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,270 | angr.project | Address is already hooked, during hook(0x500058, <SimProcedure _stricoll>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,270 | angr.project | Address is already hooked, during hook(0x500058, <SimProcedure _stricoll>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,271 | angr.project | Address is already hooked, during hook(0x500084, <SimProcedure _isctype>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,271 | angr.project | Address is already hooked, during hook(0x500084, <SimProcedure _isctype>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,271 | angr.project | Address is already hooked, during hook(0x500074, <SimProcedure _errno>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,271 | angr.project | Address is already hooked, during hook(0x500074, <SimProcedure _errno>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,274 | angr.project | Address is already hooked, during hook(0x500098, <SimProcedure atexit>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,274 | angr.project | Address is already hooked, during hook(0x500098, <SimProcedure atexit>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,274 | angr.project | Address is already hooked, during hook(0x500098, <SimProcedure atexit>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,275 | angr.project | Address is already hooked, during hook(0x500098, <SimProcedure atexit>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,276 | angr.project | Address is already hooked, during hook(0x5000b0, <SimProcedure mbstowcs>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,276 | angr.project | Address is already hooked, during hook(0x5000b0, <SimProcedure mbstowcs>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,276 | angr.project | Address is already hooked, during hook(0x500058, <SimProcedure _stricoll>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,277 | angr.project | Address is already hooked, during hook(0x500058, <SimProcedure _stricoll>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,277 | angr.project | Address is already hooked, during hook(0x5000d4, <SimProcedure wcstombs>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,277 | angr.project | Address is already hooked, during hook(0x5000d4, <SimProcedure wcstombs>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,278 | angr.project | Address is already hooked, during hook(0x5000d0, <SimProcedure vfprintf>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,278 | angr.project | Address is already hooked, during hook(0x5000d0, <SimProcedure vfprintf>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,279 | angr.project | Address is already hooked, during hook(0x5000d4, <SimProcedure wcstombs>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,279 | angr.project | Address is already hooked, during hook(0x5000d4, <SimProcedure wcstombs>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,281 | angr.project | Address is already hooked, during hook(0x5000b0, <SimProcedure mbstowcs>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,281 | angr.project | Address is already hooked, during hook(0x5000b0, <SimProcedure mbstowcs>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,282 | angr.project | Address is already hooked, during hook(0x5000c4, <SimProcedure strcoll>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,282 | angr.project | Address is already hooked, during hook(0x5000c4, <SimProcedure strcoll>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,282 | angr.project | Address is already hooked, during hook(0x5000d0, <SimProcedure vfprintf>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,282 | angr.project | Address is already hooked, during hook(0x5000d0, <SimProcedure vfprintf>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,283 | angr.project | Address is already hooked, during hook(0x50007c, <SimProcedure _fullpath>). Re-hooking.
# WARNING | 2024-05-20 10:53:56,283 | angr.project | Address is already hooked, during hook(0x50007c, <SimProcedure _fullpath>). Re-hooking.
# INFO - 2024-05-20 10:53:56,304 - SemaSCDG - .text
# INFO - 2024-05-20 10:53:56,304 - SemaSCDG - {'vaddr': 4198400, 'memsize': 11476, 'is_readable': True, 'is_writable': False, 'is_executable': True}
# INFO - 2024-05-20 10:53:56,304 - SemaSCDG - .data
# INFO - 2024-05-20 10:53:56,304 - SemaSCDG - {'vaddr': 4210688, 'memsize': 28, 'is_readable': True, 'is_writable': True, 'is_executable': False}
# INFO - 2024-05-20 10:53:56,304 - SemaSCDG - .rdata
# INFO - 2024-05-20 10:53:56,304 - SemaSCDG - {'vaddr': 4214784, 'memsize': 768, 'is_readable': True, 'is_writable': False, 'is_executable': False}
# INFO - 2024-05-20 10:53:56,304 - SemaSCDG - /4
# INFO - 2024-05-20 10:53:56,304 - SemaSCDG - {'vaddr': 4218880, 'memsize': 2472, 'is_readable': True, 'is_writable': False, 'is_executable': False}
# INFO - 2024-05-20 10:53:56,304 - SemaSCDG - .bss
# INFO - 2024-05-20 10:53:56,304 - SemaSCDG - {'vaddr': 4222976, 'memsize': 112, 'is_readable': True, 'is_writable': True, 'is_executable': False}
# INFO - 2024-05-20 10:53:56,304 - SemaSCDG - .idata
# INFO - 2024-05-20 10:53:56,304 - SemaSCDG - {'vaddr': 4227072, 'memsize': 1612, 'is_readable': True, 'is_writable': True, 'is_executable': False}
# INFO - 2024-05-20 10:53:56,304 - SemaSCDG - .CRT
# INFO - 2024-05-20 10:53:56,304 - SemaSCDG - {'vaddr': 4231168, 'memsize': 24, 'is_readable': True, 'is_writable': True, 'is_executable': False}
# INFO - 2024-05-20 10:53:56,304 - SemaSCDG - .tls
# INFO - 2024-05-20 10:53:56,304 - SemaSCDG - {'vaddr': 4235264, 'memsize': 32, 'is_readable': True, 'is_writable': True, 'is_executable': False}
# INFO - 2024-05-20 10:53:56,304 - SemaSCDG - /14
# INFO - 2024-05-20 10:53:56,304 - SemaSCDG - {'vaddr': 4239360, 'memsize': 88, 'is_readable': True, 'is_writable': False, 'is_executable': False}
# INFO - 2024-05-20 10:53:56,304 - SemaSCDG - /29
# INFO - 2024-05-20 10:53:56,304 - SemaSCDG - {'vaddr': 4243456, 'memsize': 13945, 'is_readable': True, 'is_writable': False, 'is_executable': False}
# INFO - 2024-05-20 10:53:56,304 - SemaSCDG - /41
# INFO - 2024-05-20 10:53:56,304 - SemaSCDG - {'vaddr': 4259840, 'memsize': 534, 'is_readable': True, 'is_writable': False, 'is_executable': False}
# INFO - 2024-05-20 10:53:56,304 - SemaSCDG - /55
# INFO - 2024-05-20 10:53:56,304 - SemaSCDG - {'vaddr': 4263936, 'memsize': 739, 'is_readable': True, 'is_writable': False, 'is_executable': False}
# INFO - 2024-05-20 10:53:56,304 - SemaSCDG - /67
# INFO - 2024-05-20 10:53:56,304 - SemaSCDG - {'vaddr': 4268032, 'memsize': 56, 'is_readable': True, 'is_writable': False, 'is_executable': False}
# INFO - 2024-05-20 10:53:56,305 - SemaSCDG - [<PE Object Example_SEMA_code1.exe, maps [0x400000:0x412037]>]
# INFO - 2024-05-20 10:53:56,305 - SemaSCDG - <ExternObject Object cle##externs, maps [0x500000:0x5000d8]>
# INFO - 2024-05-20 10:53:56,305 - SemaSCDG - <generator object Loader.symbols at 0x7d7b88756f80>
# INFO - 2024-05-20 10:53:56,305 - SemaSCDG -
# ------------------------------
# Start -State of simulation manager :
#  <SimulationManager with 1 active>
# ------------------------------
# INFO    | 2024-05-20 10:53:56,306 | angr.sim_manager | Stepping active of <SimulationManager with 1 active>
# WARNING | 2024-05-20 10:53:56,310 | angr.engines.vex.lifter | Self-modifying code is not always correctly optimized by PyVEX. To guarantee correctness, VEX optimizations have been disabled.
# INFO    | 2024-05-20 10:53:56,328 | angr.engines.engine | Ticked state: <IRSB from 0x401460: 1 sat>
# INFO    | 2024-05-20 10:53:56,329 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:53:56,329 | angr.sim_manager | Stepping active of <SimulationManager with 1 active>
# INFO    | 2024-05-20 10:53:56,334 | angr.engines.engine | Ticked state: <IRSB from 0x401ad0: 1 sat 1 unsat>
# INFO    | 2024-05-20 10:53:56,335 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:53:56,335 | angr.sim_manager | Stepping active of <SimulationManager with 1 active>
# INFO    | 2024-05-20 10:53:56,338 | angr.engines.engine | Ticked state: <IRSB from 0x401ae0: 1 sat>
# INFO    | 2024-05-20 10:53:56,339 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:53:56,339 | angr.sim_manager | Stepping active of <SimulationManager with 1 active>
# INFO    | 2024-05-20 10:53:56,346 | angr.engines.engine | Ticked state: <IRSB from 0x401a80: 1 sat 1 unsat>
# INFO    | 2024-05-20 10:53:56,346 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:53:56,347 | angr.sim_manager | Stepping active of <SimulationManager with 1 active>
# INFO    | 2024-05-20 10:53:56,349 | angr.engines.engine | Ticked state: <IRSB from 0x401ab0: 1 sat>
# INFO    | 2024-05-20 10:53:56,350 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:53:56,350 | angr.sim_manager | Stepping active of <SimulationManager with 1 active>
# INFO    | 2024-05-20 10:53:56,357 | angr.engines.engine | Ticked state: <IRSB from 0x401ab6: 1 sat 1 unsat>
# INFO    | 2024-05-20 10:53:56,357 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:53:56,357 | angr.sim_manager | Stepping active of <SimulationManager with 1 active>
# INFO    | 2024-05-20 10:53:56,364 | angr.engines.engine | Ticked state: <IRSB from 0x401ab4: 1 sat 1 unsat>
# INFO    | 2024-05-20 10:53:56,364 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:53:56,364 | angr.sim_manager | Stepping active of <SimulationManager with 1 active>
# INFO    | 2024-05-20 10:53:56,366 | angr.engines.engine | Ticked state: <IRSB from 0x401ac4: 1 sat>
# INFO    | 2024-05-20 10:53:56,366 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:53:56,367 | angr.sim_manager | Stepping active of <SimulationManager with 1 active>
# INFO    | 2024-05-20 10:53:56,372 | angr.engines.engine | Ticked state: <IRSB from 0x401a8f: 1 sat 1 unsat>
# INFO    | 2024-05-20 10:53:56,372 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:53:56,372 | angr.sim_manager | Stepping active of <SimulationManager with 1 active>
# INFO    | 2024-05-20 10:53:56,376 | angr.engines.engine | Ticked state: <IRSB from 0x401a93: 1 sat>
# INFO    | 2024-05-20 10:53:56,376 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:53:56,376 | angr.sim_manager | Stepping active of <SimulationManager with 1 active>
# INFO    | 2024-05-20 10:53:56,380 | angr.engines.engine | Ticked state: <IRSB from 0x403cb0: 1 sat>
# INFO    | 2024-05-20 10:53:56,380 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:53:56,381 | angr.sim_manager | Stepping active of <SimulationManager with 1 active>
# INFO    | 2024-05-20 10:53:56,387 | angr.engines.engine | Ticked state: <IRSB from 0x401340: 1 sat>
# INFO    | 2024-05-20 10:53:56,388 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:53:56,388 | angr.sim_manager | Stepping active of <SimulationManager with 1 active>
# INFO    | 2024-05-20 10:53:56,390 | angr.engines.engine | Ticked state: <IRSB from 0x403c50: 1 sat>
# INFO    | 2024-05-20 10:53:56,390 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:53:56,390 | angr.sim_manager | Stepping active of <SimulationManager with 1 active>
# INFO - 2024-05-20 10:53:56,411 - SyscallToSCDG - Syscall found:  GetModuleHandleA[<BV32 0x405000>]
# INFO    | 2024-05-20 10:53:56,416 | angr.engines.engine | Ticked state: <SimProcedure GetModuleHandleA from 0x500024: 1 sat>
# INFO    | 2024-05-20 10:53:56,416 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:53:56,417 | angr.sim_manager | Stepping active of <SimulationManager with 1 active>
# INFO    | 2024-05-20 10:53:56,422 | angr.engines.engine | Ticked state: <IRSB from 0x401354: 1 sat 1 unsat>
# INFO    | 2024-05-20 10:53:56,423 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:53:56,423 | angr.sim_manager | Stepping active of <SimulationManager with 1 active>
# INFO    | 2024-05-20 10:53:56,426 | angr.engines.engine | Ticked state: <IRSB from 0x40135f: 1 sat>
# INFO    | 2024-05-20 10:53:56,427 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:53:56,427 | angr.sim_manager | Stepping active of <SimulationManager with 1 active>
# INFO    | 2024-05-20 10:53:56,429 | angr.engines.engine | Ticked state: <IRSB from 0x403c20: 1 sat>
# INFO    | 2024-05-20 10:53:56,430 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:53:56,430 | angr.sim_manager | Stepping active of <SimulationManager with 1 active>
# INFO - 2024-05-20 10:53:56,449 - SyscallToSCDG - Syscall found:  LoadLibraryA[<BV32 0x405000>]
# INFO    | 2024-05-20 10:53:56,453 | angr.engines.engine | Ticked state: <SimProcedure LoadLibraryA from 0x50003c: 1 sat>
# INFO    | 2024-05-20 10:53:56,453 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:53:56,454 | angr.sim_manager | Stepping active of <SimulationManager with 1 active>
# INFO    | 2024-05-20 10:53:56,459 | angr.engines.engine | Ticked state: <IRSB from 0x40136d: 1 sat>
# INFO    | 2024-05-20 10:53:56,459 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:53:56,460 | angr.sim_manager | Stepping active of <SimulationManager with 1 active>
# INFO    | 2024-05-20 10:53:56,462 | angr.engines.engine | Ticked state: <IRSB from 0x403c48: 1 sat>
# INFO    | 2024-05-20 10:53:56,462 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:53:56,462 | angr.sim_manager | Stepping active of <SimulationManager with 1 active>
# WARNING | 2024-05-20 10:53:56,712 | angr.project | Address is already hooked, during hook(0x50005c, <SimProcedure __getmainargs>). Not re-hooking.
# WARNING | 2024-05-20 10:53:56,713 | angr.project | Address is already hooked, during hook(0x601014, <SimProcedure KiUserExceptionDispatcher>). Not re-hooking.
# INFO - 2024-05-20 10:53:56,715 - SyscallToSCDG - Syscall found:  GetProcAddress[<BV32 0x601028>, <BV32 0x405013>]
# INFO    | 2024-05-20 10:53:56,772 | angr.engines.engine | Ticked state: <SimProcedure GetProcAddress from 0x500028: 1 sat>
# INFO    | 2024-05-20 10:53:56,772 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:53:56,772 | angr.sim_manager | Stepping active of <SimulationManager with 1 active>
# INFO    | 2024-05-20 10:53:56,777 | angr.engines.engine | Ticked state: <IRSB from 0x401385: 1 sat>
# INFO    | 2024-05-20 10:53:56,778 | angr.sim_manager | Stepping active of <SimulationManager with 1 active>
# INFO    | 2024-05-20 10:53:56,781 | angr.engines.engine | Ticked state: <IRSB from 0x403c48: 1 sat>
# INFO    | 2024-05-20 10:53:56,781 | angr.sim_manager | Stepping active of <SimulationManager with 1 active>
# WARNING | 2024-05-20 10:53:57,020 | angr.project | Address is already hooked, during hook(0x50005c, <SimProcedure __getmainargs>). Not re-hooking.
# WARNING | 2024-05-20 10:53:57,021 | angr.project | Address is already hooked, during hook(0x601014, <SimProcedure KiUserExceptionDispatcher>). Not re-hooking.
# INFO - 2024-05-20 10:53:57,023 - SyscallToSCDG - Syscall found:  GetProcAddress[<BV32 0x601028>, <BV32 0x405029>]
# INFO    | 2024-05-20 10:53:57,050 | angr.engines.engine | Ticked state: <SimProcedure GetProcAddress from 0x500028: 1 sat>
# INFO    | 2024-05-20 10:53:57,050 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:53:57,050 | angr.sim_manager | Stepping active of <SimulationManager with 1 active>
# INFO    | 2024-05-20 10:53:57,071 | angr.engines.engine | Ticked state: <IRSB from 0x40139a: 2 sat>
# INFO    | 2024-05-20 10:53:57,071 | SemaExplorerCDFS | A new block of execution have been executed with changes in sim_manager.
# INFO    | 2024-05-20 10:53:57,072 | SemaExplorerCDFS | Currently, simulation manager is :
# <SimulationManager with 2 active>
# INFO    | 2024-05-20 10:53:57,072 | SemaExplorerCDFS | pause stash len :0
# INFO    | 2024-05-20 10:53:57,072 | SemaExplorerCDFS | fork_stack : 1 0x4013b7 || 0x4013a6
# INFO    | 2024-05-20 10:53:57,072 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:53:57,072 | angr.sim_manager | Stepping active of <SimulationManager with 2 active>
# INFO    | 2024-05-20 10:53:57,078 | angr.engines.engine | Ticked state: <IRSB from 0x4013b7: 1 sat 1 unsat>
# WARNING | 2024-05-20 10:53:57,287 | angr.engines.successors | Exit state has over 256 possible solutions. Likely unconstrained; skipping. <BV32 retval_GetProcAddress_98303_32>
# INFO    | 2024-05-20 10:53:57,287 | angr.engines.engine | Ticked state: <IRSB from 0x4013a6: 1 unconstrained>
# INFO    | 2024-05-20 10:53:57,288 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:53:57,288 | SemaExplorerCDFS | End of the trace number 0 unconstrained
# INFO    | 2024-05-20 10:53:57,288 | angr.sim_manager | Stepping active of <SimulationManager with 1 active, 1 unconstrained>
# INFO    | 2024-05-20 10:53:57,292 | angr.engines.engine | Ticked state: <IRSB from 0x4013fa: 1 sat>
# INFO    | 2024-05-20 10:53:57,292 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:53:57,292 | angr.sim_manager | Stepping active of <SimulationManager with 1 active, 1 unconstrained>
# INFO    | 2024-05-20 10:53:57,294 | angr.engines.engine | Ticked state: <IRSB from 0x401320: 1 sat>
# INFO    | 2024-05-20 10:53:57,294 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:53:57,294 | angr.sim_manager | Stepping active of <SimulationManager with 1 active, 1 unconstrained>
# INFO - 2024-05-20 10:53:57,296 - SyscallToSCDG - Syscall found:  atexit[<BV32 0x401430>]
# INFO    | 2024-05-20 10:53:57,317 | angr.engines.engine | Ticked state: <SimProcedure atexit from 0x500098: 1 sat>
# INFO    | 2024-05-20 10:53:57,317 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:53:57,317 | angr.sim_manager | Stepping active of <SimulationManager with 1 active, 1 unconstrained>
# INFO    | 2024-05-20 10:53:57,323 | angr.engines.engine | Ticked state: <IRSB from 0x401406: 1 sat>
# INFO    | 2024-05-20 10:53:57,323 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:53:57,323 | angr.sim_manager | Stepping active of <SimulationManager with 1 active, 1 unconstrained>
# INFO    | 2024-05-20 10:53:57,328 | angr.engines.engine | Ticked state: <IRSB from 0x401a9a: 1 sat 1 unsat>
# INFO    | 2024-05-20 10:53:57,329 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:53:57,329 | angr.sim_manager | Stepping active of <SimulationManager with 1 active, 1 unconstrained>
# INFO    | 2024-05-20 10:53:57,332 | angr.engines.engine | Ticked state: <IRSB from 0x401a9f: 1 sat>
# INFO    | 2024-05-20 10:53:57,332 | angr.sim_manager | Stepping active of <SimulationManager with 1 active, 1 unconstrained>
# INFO    | 2024-05-20 10:53:57,335 | angr.engines.engine | Ticked state: <IRSB from 0x401320: 1 sat>
# INFO    | 2024-05-20 10:53:57,335 | angr.sim_manager | Stepping active of <SimulationManager with 1 active, 1 unconstrained>
# INFO - 2024-05-20 10:53:57,336 - SyscallToSCDG - Syscall found:  atexit[<BV32 0x401a50>]
# INFO    | 2024-05-20 10:53:57,357 | angr.engines.engine | Ticked state: <SimProcedure atexit from 0x500098: 1 sat>
# INFO    | 2024-05-20 10:53:57,357 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:53:57,357 | angr.sim_manager | Stepping active of <SimulationManager with 1 active, 1 unconstrained>
# INFO    | 2024-05-20 10:53:57,362 | angr.engines.engine | Ticked state: <IRSB from 0x401aab: 1 sat>
# INFO    | 2024-05-20 10:53:57,362 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:53:57,362 | angr.sim_manager | Stepping active of <SimulationManager with 1 active, 1 unconstrained>
# INFO    | 2024-05-20 10:53:57,365 | angr.engines.engine | Ticked state: <IRSB from 0x401476: 1 sat>
# INFO    | 2024-05-20 10:53:57,365 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:53:57,365 | angr.sim_manager | Stepping active of <SimulationManager with 1 active, 1 unconstrained>
# INFO    | 2024-05-20 10:53:57,367 | angr.engines.engine | Ticked state: <IRSB from 0x403c40: 1 sat>
# INFO    | 2024-05-20 10:53:57,367 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:53:57,367 | angr.sim_manager | Stepping active of <SimulationManager with 1 active, 1 unconstrained>
# INFO - 2024-05-20 10:53:57,369 - SyscallToSCDG - Syscall found:  GetTickCount[]
# INFO    | 2024-05-20 10:53:57,370 | angr.engines.engine | Ticked state: <SimProcedure GetTickCount from 0x50002c: 1 sat>
# INFO    | 2024-05-20 10:53:57,370 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:53:57,370 | angr.sim_manager | Stepping active of <SimulationManager with 1 active, 1 unconstrained>
# INFO    | 2024-05-20 10:53:57,375 | angr.engines.engine | Ticked state: <IRSB from 0x40147b: 1 sat>
# INFO    | 2024-05-20 10:53:57,375 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:53:57,376 | angr.sim_manager | Stepping active of <SimulationManager with 1 active, 1 unconstrained>
# INFO    | 2024-05-20 10:53:57,378 | angr.engines.engine | Ticked state: <IRSB from 0x403c10: 1 sat>
# INFO    | 2024-05-20 10:53:57,378 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:53:57,378 | angr.sim_manager | Stepping active of <SimulationManager with 1 active, 1 unconstrained>
# INFO - 2024-05-20 10:53:57,380 - SyscallToSCDG - Syscall found:  Sleep[<BV32 0x1388>]
# INFO    | 2024-05-20 10:53:57,381 | angr.engines.engine | Ticked state: <SimProcedure Sleep from 0x500044: 1 sat>
# INFO    | 2024-05-20 10:53:57,382 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:53:57,382 | angr.sim_manager | Stepping active of <SimulationManager with 1 active, 1 unconstrained>
# INFO    | 2024-05-20 10:53:57,386 | angr.engines.engine | Ticked state: <IRSB from 0x401491: 1 sat>
# INFO    | 2024-05-20 10:53:57,386 | angr.sim_manager | Stepping active of <SimulationManager with 1 active, 1 unconstrained>
# INFO    | 2024-05-20 10:53:57,388 | angr.engines.engine | Ticked state: <IRSB from 0x403c40: 1 sat>
# INFO    | 2024-05-20 10:53:57,388 | angr.sim_manager | Stepping active of <SimulationManager with 1 active, 1 unconstrained>
# INFO - 2024-05-20 10:53:57,390 - SyscallToSCDG - Syscall found:  GetTickCount[]
# INFO    | 2024-05-20 10:53:57,391 | angr.engines.engine | Ticked state: <SimProcedure GetTickCount from 0x50002c: 1 sat>
# INFO    | 2024-05-20 10:53:57,391 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:53:57,391 | angr.sim_manager | Stepping active of <SimulationManager with 1 active, 1 unconstrained>
# INFO    | 2024-05-20 10:53:57,447 | angr.engines.engine | Ticked state: <IRSB from 0x401499: 1 sat 1 unsat>
# INFO    | 2024-05-20 10:53:57,448 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:53:57,448 | angr.sim_manager | Stepping active of <SimulationManager with 1 active, 1 unconstrained>
# INFO    | 2024-05-20 10:53:57,467 | angr.engines.engine | Ticked state: <IRSB from 0x4014b4: 2 sat>
# INFO    | 2024-05-20 10:53:57,467 | SemaExplorerCDFS | A new block of execution have been executed with changes in sim_manager.
# INFO    | 2024-05-20 10:53:57,467 | SemaExplorerCDFS | Currently, simulation manager is :
# <SimulationManager with 2 active, 1 unconstrained>
# INFO    | 2024-05-20 10:53:57,467 | SemaExplorerCDFS | pause stash len :0
# INFO    | 2024-05-20 10:53:57,467 | SemaExplorerCDFS | fork_stack : 1 0x4014b9 || 0x4014c0
# INFO    | 2024-05-20 10:53:57,468 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:53:57,468 | angr.sim_manager | Stepping active of <SimulationManager with 2 active, 1 unconstrained>
# INFO    | 2024-05-20 10:53:57,503 | angr.engines.engine | Ticked state: <IRSB from 0x4014b9: 2 sat>
# INFO    | 2024-05-20 10:53:57,506 | angr.engines.engine | Ticked state: <IRSB from 0x4014c0: 1 sat>
# INFO    | 2024-05-20 10:53:57,508 | SemaExplorerCDFS | A new block of execution have been executed with changes in sim_manager.
# INFO    | 2024-05-20 10:53:57,508 | SemaExplorerCDFS | Currently, simulation manager is :
# <SimulationManager with 3 active, 1 unconstrained>
# INFO    | 2024-05-20 10:53:57,508 | SemaExplorerCDFS | pause stash len :0
# INFO    | 2024-05-20 10:53:57,508 | SemaExplorerCDFS | fork_stack : 1 0x4014c9 || 0x4014c0
# INFO    | 2024-05-20 10:53:57,508 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:53:57,509 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:53:57,509 | angr.sim_manager | Stepping active of <SimulationManager with 3 active, 1 unconstrained>
# INFO    | 2024-05-20 10:53:57,512 | angr.engines.engine | Ticked state: <IRSB from 0x403c30: 1 sat>
# INFO    | 2024-05-20 10:53:57,517 | angr.engines.engine | Ticked state: <IRSB from 0x4014c9: 1 sat>
# INFO    | 2024-05-20 10:53:57,520 | angr.engines.engine | Ticked state: <IRSB from 0x4014c0: 1 sat>
# INFO    | 2024-05-20 10:53:57,521 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:53:57,521 | angr.sim_manager | Stepping active of <SimulationManager with 3 active, 1 unconstrained>
# INFO    | 2024-05-20 10:53:57,524 | angr.engines.engine | Ticked state: <IRSB from 0x403bf0: 1 sat>
# INFO - 2024-05-20 10:53:57,526 - SyscallToSCDG - Syscall found:  IsDebuggerPresent[]
# INFO    | 2024-05-20 10:53:57,527 | angr.engines.engine | Ticked state: <SimProcedure IsDebuggerPresent from 0x500034: 1 sat>
# INFO    | 2024-05-20 10:53:57,529 | angr.engines.engine | Ticked state: <IRSB from 0x403c30: 1 sat>
# INFO    | 2024-05-20 10:53:57,529 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:53:57,529 | angr.sim_manager | Stepping active of <SimulationManager with 3 active, 1 unconstrained>
# INFO    | 2024-05-20 10:53:57,535 | angr.engines.engine | Ticked state: <IRSB from 0x4014c5: 1 sat 1 unsat>
# INFO - 2024-05-20 10:53:57,537 - SyscallToSCDG - Syscall found:  MessageBoxA[<BV32 0x0>, <BV32 0x405065>, <BV32 0x405064>, <BV32 0x0>]
# INFO    | 2024-05-20 10:53:57,564 | angr.engines.engine | Ticked state: <SimProcedure MessageBoxA (stub) from 0x5000d8: 1 sat>
# INFO - 2024-05-20 10:53:57,565 - SyscallToSCDG - Syscall found:  IsDebuggerPresent[]
# INFO    | 2024-05-20 10:53:57,566 | angr.engines.engine | Ticked state: <SimProcedure IsDebuggerPresent from 0x500034: 1 sat>
# INFO    | 2024-05-20 10:53:57,567 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:53:57,567 | angr.sim_manager | Stepping active of <SimulationManager with 3 active, 1 unconstrained>
# INFO    | 2024-05-20 10:53:57,570 | angr.engines.engine | Ticked state: <IRSB from 0x4014ed: 1 sat>
# INFO    | 2024-05-20 10:53:57,579 | angr.engines.engine | Ticked state: <IRSB from 0x4014f5: 1 sat>
# INFO    | 2024-05-20 10:53:57,584 | angr.engines.engine | Ticked state: <IRSB from 0x4014c5: 1 sat 1 unsat>
# INFO    | 2024-05-20 10:53:57,584 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:53:57,584 | angr.sim_manager | Stepping active of <SimulationManager with 3 active, 1 unconstrained>
# INFO    | 2024-05-20 10:53:57,587 | angr.engines.engine | Ticked state: <IRSB from 0x403c20: 1 sat>
# INFO    | 2024-05-20 10:53:57,590 | angr.engines.engine | Ticked state: <IRSB from 0x40158f: 1 sat>
# INFO    | 2024-05-20 10:53:57,596 | angr.engines.engine | Ticked state: <IRSB from 0x4014f5: 1 sat>
# INFO    | 2024-05-20 10:53:57,597 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:53:57,597 | angr.sim_manager | Stepping active of <SimulationManager with 3 active, 1 unconstrained>
# WARNING | 2024-05-20 10:53:57,838 | angr.project | Address is already hooked, during hook(0x50005c, <SimProcedure __getmainargs>). Not re-hooking.
# WARNING | 2024-05-20 10:53:57,838 | angr.project | Address is already hooked, during hook(0x601014, <SimProcedure KiUserExceptionDispatcher>). Not re-hooking.
# INFO - 2024-05-20 10:53:57,840 - SyscallToSCDG - Syscall found:  LoadLibraryA[<BV32 0x405073>]
# INFO    | 2024-05-20 10:53:57,843 | angr.engines.engine | Ticked state: <SimProcedure LoadLibraryA from 0x50003c: 1 sat>
# INFO    | 2024-05-20 10:53:57,845 | angr.engines.engine | Ticked state: <IRSB from 0x403b98: 1 sat>
# INFO    | 2024-05-20 10:53:57,847 | angr.engines.engine | Ticked state: <IRSB from 0x403c20: 1 sat>
# INFO    | 2024-05-20 10:53:57,847 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:53:57,847 | angr.sim_manager | Stepping active of <SimulationManager with 3 active, 1 unconstrained>
# INFO - 2024-05-20 10:53:57,850 - SyscallToSCDG - Syscall found:  exit[<BV32 0x0>]
# INFO    | 2024-05-20 10:53:57,850 | angr.engines.engine | Ticked state: <SimProcedure exit from 0x5000a0: 1 sat>
# INFO    | 2024-05-20 10:53:57,856 | angr.engines.engine | Ticked state: <IRSB from 0x401524: 1 sat>
# INFO - 2024-05-20 10:53:57,873 - SyscallToSCDG - Syscall found:  LoadLibraryA[<BV32 0x405073>]
# INFO    | 2024-05-20 10:53:57,876 | angr.engines.engine | Ticked state: <SimProcedure LoadLibraryA from 0x50003c: 1 sat>
# INFO    | 2024-05-20 10:53:57,877 | angr.sim_manager | Stepping active of <SimulationManager with 3 active, 1 unconstrained>
# INFO    | 2024-05-20 10:53:57,878 | angr.engines.engine | Ticked state: <SimProcedure PathTerminator from 0x5000a0: empty>
# INFO    | 2024-05-20 10:53:57,881 | angr.engines.engine | Ticked state: <IRSB from 0x403c48: 1 sat>
# INFO    | 2024-05-20 10:53:57,886 | angr.engines.engine | Ticked state: <IRSB from 0x401524: 1 sat>
# INFO    | 2024-05-20 10:53:57,887 | SemaExplorerCDFS | A new block of execution have been executed with changes in sim_manager.
# INFO    | 2024-05-20 10:53:57,887 | SemaExplorerCDFS | Currently, simulation manager is :
# <SimulationManager with 2 active, 1 deadended, 1 unconstrained>
# INFO    | 2024-05-20 10:53:57,887 | SemaExplorerCDFS | pause stash len :0
# INFO    | 2024-05-20 10:53:57,887 | angr.sim_manager | Stepping active of <SimulationManager with 2 active, 1 deadended, 1 unconstrained>
# INFO - 2024-05-20 10:53:57,905 - SyscallToSCDG - Syscall found:  GetProcAddress[<BV32 0x601034>, <BV32 0x40507e>]
# INFO    | 2024-05-20 10:53:57,907 | angr.engines.engine | Ticked state: <SimProcedure GetProcAddress from 0x500028: 1 sat>
# INFO    | 2024-05-20 10:53:57,909 | angr.engines.engine | Ticked state: <IRSB from 0x403c48: 1 sat>
# INFO    | 2024-05-20 10:53:57,910 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:53:57,910 | angr.sim_manager | Stepping active of <SimulationManager with 2 active, 1 deadended, 1 unconstrained>
# INFO    | 2024-05-20 10:53:57,918 | angr.engines.engine | Ticked state: <IRSB from 0x40153d: 1 sat>
# INFO - 2024-05-20 10:53:57,935 - SyscallToSCDG - Syscall found:  GetProcAddress[<BV32 0x601034>, <BV32 0x40507e>]
# INFO    | 2024-05-20 10:53:57,938 | angr.engines.engine | Ticked state: <SimProcedure GetProcAddress from 0x500028: 1 sat>
# INFO    | 2024-05-20 10:53:57,938 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:53:57,939 | angr.sim_manager | Stepping active of <SimulationManager with 2 active, 1 deadended, 1 unconstrained>
# INFO - 2024-05-20 10:53:57,942 - SyscallToSCDG - Syscall found:  strcat['', "I'm "]
# INFO    | 2024-05-20 10:53:57,946 | angr.engines.engine | Ticked state: <SimProcedure strcat from 0x601038: 1 sat>
# INFO    | 2024-05-20 10:53:57,953 | angr.engines.engine | Ticked state: <IRSB from 0x40153d: 1 sat>
# INFO    | 2024-05-20 10:53:57,953 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:53:57,953 | angr.sim_manager | Stepping active of <SimulationManager with 2 active, 1 deadended, 1 unconstrained>
# INFO    | 2024-05-20 10:53:57,959 | angr.engines.engine | Ticked state: <IRSB from 0x401556: 1 sat>
# INFO - 2024-05-20 10:53:57,962 - SyscallToSCDG - Syscall found:  strcat['', "I'm "]
# INFO    | 2024-05-20 10:53:57,967 | angr.engines.engine | Ticked state: <SimProcedure strcat from 0x601038: 1 sat>
# INFO    | 2024-05-20 10:53:57,967 | angr.sim_manager | Stepping active of <SimulationManager with 2 active, 1 deadended, 1 unconstrained>
# INFO - 2024-05-20 10:53:57,972 - SyscallToSCDG - Syscall found:  strcat["I'm ", 'evil !!']
# INFO    | 2024-05-20 10:53:57,973 | angr.engines.engine | Ticked state: <SimProcedure strcat from 0x601038: 1 sat>
# INFO    | 2024-05-20 10:53:57,978 | angr.engines.engine | Ticked state: <IRSB from 0x401556: 1 sat>
# INFO    | 2024-05-20 10:53:57,978 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:53:57,978 | angr.sim_manager | Stepping active of <SimulationManager with 2 active, 1 deadended, 1 unconstrained>
# INFO    | 2024-05-20 10:53:57,985 | angr.engines.engine | Ticked state: <IRSB from 0x401569: 1 sat>
# INFO - 2024-05-20 10:53:57,989 - SyscallToSCDG - Syscall found:  strcat["I'm ", 'evil !!']
# INFO    | 2024-05-20 10:53:57,990 | angr.engines.engine | Ticked state: <SimProcedure strcat from 0x601038: 1 sat>
# INFO    | 2024-05-20 10:53:57,991 | angr.sim_manager | Stepping active of <SimulationManager with 2 active, 1 deadended, 1 unconstrained>
# INFO    | 2024-05-20 10:53:57,993 | angr.engines.engine | Ticked state: <IRSB from 0x403bf0: 1 sat>
# INFO    | 2024-05-20 10:53:57,999 | angr.engines.engine | Ticked state: <IRSB from 0x401569: 1 sat>
# INFO    | 2024-05-20 10:53:57,999 | angr.sim_manager | Stepping active of <SimulationManager with 2 active, 1 deadended, 1 unconstrained>
# INFO - 2024-05-20 10:53:58,001 - SyscallToSCDG - Syscall found:  MessageBoxA[<BV32 0x0>, <BV32 0x7ffefe34>, <BV32 0x405064>, <BV32 0x0>]
# INFO    | 2024-05-20 10:53:58,024 | angr.engines.engine | Ticked state: <SimProcedure MessageBoxA (stub) from 0x5000d8: 1 sat>
# INFO    | 2024-05-20 10:53:58,026 | angr.engines.engine | Ticked state: <IRSB from 0x403bf0: 1 sat>
# INFO    | 2024-05-20 10:53:58,027 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:53:58,027 | angr.sim_manager | Stepping active of <SimulationManager with 2 active, 1 deadended, 1 unconstrained>
# INFO    | 2024-05-20 10:53:58,031 | angr.engines.engine | Ticked state: <IRSB from 0x40158c: 1 sat>
# INFO - 2024-05-20 10:53:58,035 - SyscallToSCDG - Syscall found:  MessageBoxA[<BV32 0x0>, <BV32 0x7ffefe34>, <BV32 0x405064>, <BV32 0x0>]
# INFO    | 2024-05-20 10:53:58,057 | angr.engines.engine | Ticked state: <SimProcedure MessageBoxA (stub) from 0x5000d8: 1 sat>
# INFO    | 2024-05-20 10:53:58,057 | angr.sim_manager | Stepping active of <SimulationManager with 2 active, 1 deadended, 1 unconstrained>
# INFO    | 2024-05-20 10:53:58,060 | angr.engines.engine | Ticked state: <IRSB from 0x403b98: 1 sat>
# INFO    | 2024-05-20 10:53:58,064 | angr.engines.engine | Ticked state: <IRSB from 0x40158c: 1 sat>
# INFO    | 2024-05-20 10:53:58,065 | angr.sim_manager | Stepping active of <SimulationManager with 2 active, 1 deadended, 1 unconstrained>
# INFO - 2024-05-20 10:53:58,067 - SyscallToSCDG - Syscall found:  exit[<BV32 0x0>]
# INFO    | 2024-05-20 10:53:58,067 | angr.engines.engine | Ticked state: <SimProcedure exit from 0x5000a0: 1 sat>
# INFO    | 2024-05-20 10:53:58,070 | angr.engines.engine | Ticked state: <IRSB from 0x403b98: 1 sat>
# INFO    | 2024-05-20 10:53:58,070 | angr.sim_manager | Stepping active of <SimulationManager with 2 active, 1 deadended, 1 unconstrained>
# INFO    | 2024-05-20 10:53:58,071 | angr.engines.engine | Ticked state: <SimProcedure PathTerminator from 0x5000a0: empty>
# INFO - 2024-05-20 10:53:58,073 - SyscallToSCDG - Syscall found:  exit[<BV32 0x0>]
# INFO    | 2024-05-20 10:53:58,073 | angr.engines.engine | Ticked state: <SimProcedure exit from 0x5000a0: 1 sat>
# INFO    | 2024-05-20 10:53:58,073 | SemaExplorerCDFS | A new block of execution have been executed with changes in sim_manager.
# INFO    | 2024-05-20 10:53:58,073 | SemaExplorerCDFS | Currently, simulation manager is :
# <SimulationManager with 1 active, 2 deadended, 1 unconstrained>
# INFO    | 2024-05-20 10:53:58,073 | SemaExplorerCDFS | pause stash len :0
# INFO    | 2024-05-20 10:53:58,074 | angr.sim_manager | Stepping active of <SimulationManager with 1 active, 2 deadended, 1 unconstrained>
# INFO    | 2024-05-20 10:53:58,075 | angr.engines.engine | Ticked state: <SimProcedure PathTerminator from 0x5000a0: empty>
# INFO    | 2024-05-20 10:53:58,075 | SemaExplorerCDFS | A new block of execution have been executed with changes in sim_manager.
# INFO    | 2024-05-20 10:53:58,075 | SemaExplorerCDFS | Currently, simulation manager is :
# <SimulationManager with 3 deadended, 1 unconstrained>
# INFO    | 2024-05-20 10:53:58,075 | SemaExplorerCDFS | pause stash len :0
# INFO    | 2024-05-20 10:53:58,075 | SemaExplorerCDFS | len(simgr.active) <= 0 or deadended >= self.max_end_state)
# INFO - 2024-05-20 10:53:58,075 - SemaSCDG -
# ------------------------------
# End - State of simulation manager :
#  <SimulationManager with 3 deadended, 1 unconstrained>
# ------------------------------
# INFO - 2024-05-20 10:53:58,075 - SemaSCDG - Total execution time: 13.275230169296265
# INFO - 2024-05-20 10:53:58,076 - SemaSCDG - .text
# INFO - 2024-05-20 10:53:58,076 - SemaSCDG - {'vaddr': 4198400, 'memsize': 11476, 'is_readable': True, 'is_writable': False, 'is_executable': True}
# INFO - 2024-05-20 10:53:58,076 - SemaSCDG - .data
# INFO - 2024-05-20 10:53:58,076 - SemaSCDG - {'vaddr': 4210688, 'memsize': 28, 'is_readable': True, 'is_writable': True, 'is_executable': False}
# INFO - 2024-05-20 10:53:58,076 - SemaSCDG - .rdata
# INFO - 2024-05-20 10:53:58,076 - SemaSCDG - {'vaddr': 4214784, 'memsize': 768, 'is_readable': True, 'is_writable': False, 'is_executable': False}
# INFO - 2024-05-20 10:53:58,076 - SemaSCDG - /4
# INFO - 2024-05-20 10:53:58,076 - SemaSCDG - {'vaddr': 4218880, 'memsize': 2472, 'is_readable': True, 'is_writable': False, 'is_executable': False}
# INFO - 2024-05-20 10:53:58,076 - SemaSCDG - .bss
# INFO - 2024-05-20 10:53:58,076 - SemaSCDG - {'vaddr': 4222976, 'memsize': 112, 'is_readable': True, 'is_writable': True, 'is_executable': False}
# INFO - 2024-05-20 10:53:58,076 - SemaSCDG - .idata
# INFO - 2024-05-20 10:53:58,076 - SemaSCDG - {'vaddr': 4227072, 'memsize': 1612, 'is_readable': True, 'is_writable': True, 'is_executable': False}
# INFO - 2024-05-20 10:53:58,076 - SemaSCDG - .CRT
# INFO - 2024-05-20 10:53:58,076 - SemaSCDG - {'vaddr': 4231168, 'memsize': 24, 'is_readable': True, 'is_writable': True, 'is_executable': False}
# INFO - 2024-05-20 10:53:58,076 - SemaSCDG - .tls
# INFO - 2024-05-20 10:53:58,076 - SemaSCDG - {'vaddr': 4235264, 'memsize': 32, 'is_readable': True, 'is_writable': True, 'is_executable': False}
# INFO - 2024-05-20 10:53:58,076 - SemaSCDG - /14
# INFO - 2024-05-20 10:53:58,076 - SemaSCDG - {'vaddr': 4239360, 'memsize': 88, 'is_readable': True, 'is_writable': False, 'is_executable': False}
# INFO - 2024-05-20 10:53:58,076 - SemaSCDG - /29
# INFO - 2024-05-20 10:53:58,076 - SemaSCDG - {'vaddr': 4243456, 'memsize': 13945, 'is_readable': True, 'is_writable': False, 'is_executable': False}
# INFO - 2024-05-20 10:53:58,076 - SemaSCDG - /41
# INFO - 2024-05-20 10:53:58,076 - SemaSCDG - {'vaddr': 4259840, 'memsize': 534, 'is_readable': True, 'is_writable': False, 'is_executable': False}
# INFO - 2024-05-20 10:53:58,076 - SemaSCDG - /55
# INFO - 2024-05-20 10:53:58,076 - SemaSCDG - {'vaddr': 4263936, 'memsize': 739, 'is_readable': True, 'is_writable': False, 'is_executable': False}
# INFO - 2024-05-20 10:53:58,076 - SemaSCDG - /67
# INFO - 2024-05-20 10:53:58,076 - SemaSCDG - {'vaddr': 4268032, 'memsize': 56, 'is_readable': True, 'is_writable': False, 'is_executable': False}
# INFO - 2024-05-20 10:53:58,078 - GraphBuilder - Output dir :database/SCDG/runs/Tutorial_output/Binaryfamily/Example_SEMA_code1.exe
# INFO - 2024-05-20 10:53:58,078 - GraphBuilder - Using SCDG 1 over 4
# INFO - 2024-05-20 10:53:58,078 - GraphBuilder - Using SCDG 2 over 4
# INFO - 2024-05-20 10:53:58,079 - GraphBuilder - Using SCDG 3 over 4
# INFO - 2024-05-20 10:53:58,079 - GraphBuilder - Using SCDG 4 over 4

# %% [markdown]
# We could observe the JSON file obtained thanks to SEMA-SCDG in database/runs/Tutorial_output.
# Interesting trace from this JSON is represented below where you could find the calls which will print "I'm evil".
#
# {"status": "deadendend", "trace":
#
#         [{"name": "main", "args": ["Example_SEMA_code1.exe"], "addr": 4199520, "ret": "symbolic", "addr_func": 4199520},
#         {"name": "GetModuleHandleA", "args": ["libgcc_s_dw2-1.dll"], "addr_func": "5242916", "addr": 4199247, "ret": 6295592},
#         {"name": "LoadLibraryA", "args": ["libgcc_s_dw2-1.dll"], "addr_func": "5242940", "addr": 4199272, "ret": 6295592},
#         {"name": "GetProcAddress", "args": [6295592, "__register_frame_info"], "addr_func": "5242920", "addr": 4199296, "ret": "<BV32 retval_GetProcAddress_32767_32>"},
#         {"name": "GetProcAddress", "args": [6295592, "__deregister_frame_info"], "addr_func": "5242920", "addr": 4199317, "ret": "<BV32 retval_GetProcAddress_32768_32>"},
#         {"name": "atexit", "args": [4199472], "addr_func": "5243032", "addr": 4199425, "ret": "<BV32 retval_atexit_32769_32>"},
#         {"name": "atexit", "args": [4201040], "addr_func": "5243032", "addr": 4201126, "ret": "<BV32 retval_atexit_32770_32>"},
#         {"name": "GetTickCount", "args": [], "addr_func": "5242924", "addr": 4199542, "ret": "<BV32 retval_GetTickCount_32771_32{UNINITIALIZED}>"},
#         {"name": "Sleep", "args": [5000], "addr_func": "5242948", "addr": 4199564, "ret": "None"},
#         {"name": "GetTickCount", "args": [], "addr_func": "5242924", "addr": 4199572, "ret": "<BV32 retval_GetTickCount_32772_32{UNINITIALIZED}>"},
#         {"name": "IsDebuggerPresent", "args": [], "addr_func": "5242932", "addr": 4199616, "ret": "<BV32 retval_IsDebuggerPresent_32773_32>"},
#         {"name": "LoadLibraryA", "args": ["msvcrt.dll"], "addr_func": "5242940", "addr": 4199711, "ret": 6295604},
#         {"name": "GetProcAddress", "args": [6295604, "strcat"], "addr_func": "5242920", "addr": 4199736, "ret": 6295608},
#         {"name": "strcat", "args": ["", "I'm "], "addr_func": "6295608", "addr": 4199764, "ret": "I'm "},
#         {"name": "strcat", "args": ["I'm ", "evil !!"], "addr_func": "6295608", "addr": 4199783, "ret": "I'm evil !!"},
#         {"name": "MessageBoxA", "args": [0, "I'm evil !!", "", 0], "addr_func": "5243096", "addr": 4199815, "ret": 1},
#         {"name": "exit", "args": [], "addr_func": "5243040", "addr": 4199830, "ret": "None"}]}

# %% [markdown]
# Similarly, we apply SEMA-SCDG on the second code example :

# %%
import configparser
config = configparser.ConfigParser()
config.read("Tutorial/config_tutorial.ini")
config.set('SCDG_arg', "binary_path", "Tutorial/DATA/Example_SEMA_code2.exe")

with open("Tutorial/config_tutorial.ini", 'w') as configfile:
        config.write(configfile)

# !python3 SemaSCDG.py Tutorial/config_tutorial.ini

# Restore previous value
config = configparser.ConfigParser()
config.read("Tutorial/config_tutorial.ini")
config.set('SCDG_arg', "binary_path", "Tutorial/DATA/Example_SEMA_code1.exe")

with open("Tutorial/config_tutorial.ini", 'w') as configfile:
        config.write(configfile)
# Out:
# INFO - 2024-05-20 10:54:50,475 - SemaSCDG - Results wil be saved into : database/SCDG/runs/Tutorial_output/
# INFO - 2024-05-20 10:54:50,476 - SemaSCDG - You decide to analyse a single binary: Tutorial/DATA/Example_SEMA_code2.exe
# INFO - 2024-05-20 10:54:50,478 - SemaSCDG -
# ------------------------------------------------------------
# --- Building SCDG of Binaryfamily/Example_SEMA_code2.exe ---
# ------------------------------------------------------------
# INFO    | 2024-05-20 10:54:50,478 | angr.project | Loading binary Tutorial/DATA/Example_SEMA_code2.exe
# WARNING | 2024-05-20 10:54:50,487 | angr.project | Disabling IRSB translation cache because support for self-modifying code is enabled.
# INFO    | 2024-05-20 10:54:52,014 | angr.project | Using builtin SimProcedure for unresolved DeleteCriticalSection from kernel32.dll
# INFO    | 2024-05-20 10:54:52,014 | angr.project | Using builtin SimProcedure for unresolved EnterCriticalSection from kernel32.dll
# INFO    | 2024-05-20 10:54:52,015 | angr.project | Using builtin SimProcedure for unresolved ExitProcess from kernel32.dll
# INFO    | 2024-05-20 10:54:52,015 | angr.project | Using builtin SimProcedure for unresolved FindClose from kernel32.dll
# INFO    | 2024-05-20 10:54:52,015 | angr.project | Using builtin SimProcedure for unresolved FindFirstFileA from kernel32.dll
# INFO    | 2024-05-20 10:54:52,015 | angr.project | Using builtin SimProcedure for unresolved FindNextFileA from kernel32.dll
# INFO    | 2024-05-20 10:54:52,015 | angr.project | Using builtin SimProcedure for unresolved FreeLibrary from kernel32.dll
# INFO    | 2024-05-20 10:54:52,016 | angr.project | Using builtin SimProcedure for unresolved GetCommandLineA from kernel32.dll
# INFO    | 2024-05-20 10:54:52,016 | angr.project | Using builtin SimProcedure for unresolved GetLastError from kernel32.dll
# INFO    | 2024-05-20 10:54:52,016 | angr.project | Using builtin SimProcedure for unresolved GetModuleHandleA from kernel32.dll
# INFO    | 2024-05-20 10:54:52,016 | angr.project | Using builtin SimProcedure for unresolved GetProcAddress from kernel32.dll
# INFO    | 2024-05-20 10:54:52,016 | angr.project | Using builtin SimProcedure for unresolved GetTickCount from kernel32.dll
# INFO    | 2024-05-20 10:54:52,016 | angr.project | Using builtin SimProcedure for unresolved InitializeCriticalSection from kernel32.dll
# INFO    | 2024-05-20 10:54:52,017 | angr.project | Using builtin SimProcedure for unresolved IsDebuggerPresent from kernel32.dll
# INFO    | 2024-05-20 10:54:52,017 | angr.project | Using builtin SimProcedure for unresolved LeaveCriticalSection from kernel32.dll
# INFO    | 2024-05-20 10:54:52,017 | angr.project | Using builtin SimProcedure for unresolved LoadLibraryA from kernel32.dll
# INFO    | 2024-05-20 10:54:52,017 | angr.project | Using builtin SimProcedure for unresolved SetUnhandledExceptionFilter from kernel32.dll
# INFO    | 2024-05-20 10:54:52,018 | angr.project | Using builtin SimProcedure for unresolved Sleep from kernel32.dll
# INFO    | 2024-05-20 10:54:52,018 | angr.project | Using builtin SimProcedure for unresolved TlsGetValue from kernel32.dll
# INFO    | 2024-05-20 10:54:52,018 | angr.project | Using builtin SimProcedure for unresolved VirtualProtect from kernel32.dll
# INFO    | 2024-05-20 10:54:52,018 | angr.project | Using builtin SimProcedure for unresolved VirtualQuery from kernel32.dll
# INFO    | 2024-05-20 10:54:52,018 | angr.project | Using builtin SimProcedure for unresolved _strdup from msvcrt.dll
# INFO    | 2024-05-20 10:54:52,018 | angr.project | Using builtin SimProcedure for unresolved _stricoll from msvcrt.dll
# INFO    | 2024-05-20 10:54:52,019 | angr.project | Using builtin SimProcedure for unresolved __getmainargs from msvcrt.dll
# INFO    | 2024-05-20 10:54:52,019 | angr.project | Using builtin SimProcedure for unresolved __mb_cur_max from msvcrt.dll
# INFO    | 2024-05-20 10:54:52,019 | angr.project | Using builtin SimProcedure for unresolved __p__environ from msvcrt.dll
# INFO    | 2024-05-20 10:54:52,019 | angr.project | Using builtin SimProcedure for unresolved __p__fmode from msvcrt.dll
# INFO    | 2024-05-20 10:54:52,019 | angr.project | Using builtin SimProcedure for unresolved __set_app_type from msvcrt.dll
# INFO    | 2024-05-20 10:54:52,019 | angr.project | Using builtin SimProcedure for unresolved _cexit from msvcrt.dll
# INFO    | 2024-05-20 10:54:52,019 | angr.project | Using builtin SimProcedure for unresolved _errno from msvcrt.dll
# INFO    | 2024-05-20 10:54:52,019 | angr.project | Using builtin SimProcedure for unresolved _fpreset from msvcrt.dll
# INFO    | 2024-05-20 10:54:52,019 | angr.project | Using builtin SimProcedure for unresolved _fullpath from msvcrt.dll
# INFO    | 2024-05-20 10:54:52,020 | angr.project | Using builtin SimProcedure for unresolved _iob from msvcrt.dll
# INFO    | 2024-05-20 10:54:52,020 | angr.project | Using builtin SimProcedure for unresolved _isctype from msvcrt.dll
# INFO    | 2024-05-20 10:54:52,020 | angr.project | Using builtin SimProcedure for unresolved _onexit from msvcrt.dll
# INFO    | 2024-05-20 10:54:52,020 | angr.project | Using builtin SimProcedure for unresolved _pctype from msvcrt.dll
# INFO    | 2024-05-20 10:54:52,020 | angr.project | Using builtin SimProcedure for unresolved _setmode from msvcrt.dll
# INFO    | 2024-05-20 10:54:52,020 | angr.project | Using builtin SimProcedure for unresolved abort from msvcrt.dll
# INFO    | 2024-05-20 10:54:52,020 | angr.project | Using builtin SimProcedure for unresolved atexit from msvcrt.dll
# INFO    | 2024-05-20 10:54:52,020 | angr.project | Using builtin SimProcedure for unresolved calloc from msvcrt.dll
# INFO    | 2024-05-20 10:54:52,020 | angr.project | Using builtin SimProcedure for unresolved exit from msvcrt.dll
# INFO    | 2024-05-20 10:54:52,021 | angr.project | Using builtin SimProcedure for unresolved free from msvcrt.dll
# INFO    | 2024-05-20 10:54:52,021 | angr.project | Using builtin SimProcedure for unresolved fwrite from msvcrt.dll
# INFO    | 2024-05-20 10:54:52,021 | angr.project | Using builtin SimProcedure for unresolved malloc from msvcrt.dll
# INFO    | 2024-05-20 10:54:52,021 | angr.project | Using builtin SimProcedure for unresolved mbstowcs from msvcrt.dll
# INFO    | 2024-05-20 10:54:52,021 | angr.project | Using builtin SimProcedure for unresolved memcpy from msvcrt.dll
# INFO    | 2024-05-20 10:54:52,021 | angr.project | Using builtin SimProcedure for unresolved realloc from msvcrt.dll
# INFO    | 2024-05-20 10:54:52,021 | angr.project | Using builtin SimProcedure for unresolved setlocale from msvcrt.dll
# INFO    | 2024-05-20 10:54:52,022 | angr.project | Using builtin SimProcedure for unresolved signal from msvcrt.dll
# INFO    | 2024-05-20 10:54:52,022 | angr.project | Using builtin SimProcedure for unresolved strcat from msvcrt.dll
# INFO    | 2024-05-20 10:54:52,022 | angr.project | Using builtin SimProcedure for unresolved strcoll from msvcrt.dll
# INFO    | 2024-05-20 10:54:52,022 | angr.project | Using builtin SimProcedure for unresolved strcpy from msvcrt.dll
# INFO    | 2024-05-20 10:54:52,022 | angr.project | Using builtin SimProcedure for unresolved strlen from msvcrt.dll
# INFO    | 2024-05-20 10:54:52,023 | angr.project | Using builtin SimProcedure for unresolved tolower from msvcrt.dll
# INFO    | 2024-05-20 10:54:52,023 | angr.project | Using builtin SimProcedure for unresolved vfprintf from msvcrt.dll
# INFO    | 2024-05-20 10:54:52,023 | angr.project | Using builtin SimProcedure for unresolved wcstombs from msvcrt.dll
# INFO    | 2024-05-20 10:54:52,023 | angr.project | Using builtin SimProcedure for unresolved MessageBoxA from user32.dll
# INFO - 2024-05-20 10:54:52,025 - SemaSCDG - Libraries used are :
#  {'kernel32.dll', 'user32.dll', 'msvcrt.dll'}
# INFO - 2024-05-20 10:54:52,025 - SemaSCDG - OS recognized as : windows
# INFO - 2024-05-20 10:54:52,025 - SemaSCDG - CPU architecture recognized as : <Arch X86 (LE)>
# INFO - 2024-05-20 10:54:52,025 - SemaSCDG - Entry point of the binary recognized as : 0x4012e0
# INFO - 2024-05-20 10:54:52,025 - SemaSCDG - Min/Max addresses of the binary recognized as : <Loaded Example_SEMA_code2.exe, maps [0x400000:0x70141a]>
# INFO - 2024-05-20 10:54:52,025 - SemaSCDG - Stack executable ?  False
# INFO - 2024-05-20 10:54:52,025 - SemaSCDG - Binary position-independent ?  False
# INFO - 2024-05-20 10:54:52,025 - SemaSCDG - Exploration method:  CDFS
# INFO - 2024-05-20 10:54:52,062 - SemaSCDG - System call table loaded
# WARN: Relocs has not been applied. Please use `-e bin.relocs.apply=true` or `-e bin.cache=true` next time
# INFO - 2024-05-20 10:54:52,315 - SemaSCDG - Entry_state address = 4199520
# INFO - 2024-05-20 10:55:01,078 - WindowsSimProcedure - Was in angr :kernel32.dll
# WARNING | 2024-05-20 10:55:01,171 | angr.project | Address is already hooked, during hook(0x500038, <SimProcedure LeaveCriticalSection>). Not re-hooking.
# WARNING | 2024-05-20 10:55:01,171 | angr.project | Address is already hooked, during hook(0x500000, <SimProcedure DeleteCriticalSection>). Not re-hooking.
# WARNING | 2024-05-20 10:55:01,172 | angr.project | Address is already hooked, during hook(0x500004, <SimProcedure EnterCriticalSection>). Not re-hooking.
# WARNING | 2024-05-20 10:55:01,172 | angr.project | Address is already hooked, during hook(0x500030, <SimProcedure InitializeCriticalSection>). Not re-hooking.
# WARNING | 2024-05-20 10:55:01,172 | angr.project | Address is already hooked, during hook(0x500044, <SimProcedure Sleep>). Not re-hooking.
# INFO - 2024-05-20 10:55:01,764 - WindowsSimProcedure - Was in angr :user32.dll
# WARNING - 2024-05-20 10:55:01,767 - WindowsSimProcedure - Procedure wsprintfA in DLL user32.dll has 3 arguments in json and 2 arguments in angr prototype. Taking number of arguments from json.
# WARNING - 2024-05-20 10:55:01,767 - WindowsSimProcedure - Procedure wsprintfW in DLL user32.dll has 3 arguments in json and 2 arguments in angr prototype. Taking number of arguments from json.
# WARNING | 2024-05-20 10:55:01,818 | angr.project | Address is already hooked, during hook(0x5000e0, <SimProcedure MessageBoxA>). Not re-hooking.
# INFO - 2024-05-20 10:55:01,856 - WindowsSimProcedure - Was in angr :msvcrt.dll
# WARNING | 2024-05-20 10:55:01,902 | angr.project | Address is already hooked, during hook(0x500064, <SimProcedure __p__environ>). Not re-hooking.
# WARNING | 2024-05-20 10:55:01,903 | angr.project | Address is already hooked, during hook(0x500088, <SimProcedure _onexit>). Not re-hooking.
# WARNING | 2024-05-20 10:55:01,903 | angr.project | Address is already hooked, during hook(0x5000c8, <SimProcedure strcoll>). Not re-hooking.
# WARNING | 2024-05-20 10:55:01,903 | angr.project | Address is already hooked, during hook(0x500084, <SimProcedure _isctype>). Not re-hooking.
# WARNING | 2024-05-20 10:55:01,903 | angr.project | Address is already hooked, during hook(0x500074, <SimProcedure _errno>). Not re-hooking.
# WARNING | 2024-05-20 10:55:01,903 | angr.project | Address is already hooked, during hook(0x500098, <SimProcedure atexit>). Not re-hooking.
# WARNING | 2024-05-20 10:55:01,904 | angr.project | Address is already hooked, during hook(0x500058, <SimProcedure _stricoll>). Not re-hooking.
# WARNING | 2024-05-20 10:55:01,904 | angr.project | Address is already hooked, during hook(0x5000dc, <SimProcedure wcstombs>). Not re-hooking.
# WARNING | 2024-05-20 10:55:01,904 | angr.project | Address is already hooked, during hook(0x5000b0, <SimProcedure mbstowcs>). Not re-hooking.
# WARNING | 2024-05-20 10:55:01,904 | angr.project | Address is already hooked, during hook(0x5000d8, <SimProcedure vfprintf>). Not re-hooking.
# WARNING | 2024-05-20 10:55:01,904 | angr.project | Address is already hooked, during hook(0x50007c, <SimProcedure _fullpath>). Not re-hooking.
# WARNING | 2024-05-20 10:55:01,934 | angr.project | Address is already hooked, during hook(0x50005c, <SimProcedure __getmainargs>). Not re-hooking.
# WARNING | 2024-05-20 10:55:01,935 | angr.project | Address is already hooked, during hook(0x601014, <SimProcedure KiUserExceptionDispatcher>). Not re-hooking.
# INFO - 2024-05-20 10:55:01,935 - WindowsSimProcedure - No hooks for: {'__mb_cur_max': 5242976, '__set_app_type': 5242988, '_cexit': 5242992, '_fpreset': 5243000, '_iob': 5243008, '_pctype': 5243020, '_setmode': 5243024, 'setlocale': 5243068, 'signal': 5243072, '_fmode': 6295576, '_commode': 6295580, '_acmdln': 6295584, '_wcmdln': 6295588}
# INFO - 2024-05-20 10:55:01,935 - WindowsSimProcedure - custom_hook_static_windows
# WARNING | 2024-05-20 10:55:01,935 | angr.project | Address 0x400000 not hooked
# INFO - 2024-05-20 10:55:01,935 - WindowsSimProcedure - custom_hook_windows_symbols
# WARNING | 2024-05-20 10:55:01,941 | angr.project | Address is already hooked, during hook(0x500000, <SimProcedure DeleteCriticalSection>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,941 | angr.project | Address is already hooked, during hook(0x500000, <SimProcedure DeleteCriticalSection>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,941 | angr.project | Address is already hooked, during hook(0x500004, <SimProcedure EnterCriticalSection>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,942 | angr.project | Address is already hooked, during hook(0x500004, <SimProcedure EnterCriticalSection>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,950 | angr.project | Address is already hooked, during hook(0x500038, <SimProcedure LeaveCriticalSection>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,950 | angr.project | Address is already hooked, during hook(0x500038, <SimProcedure LeaveCriticalSection>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,956 | angr.project | Address is already hooked, during hook(0x500044, <SimProcedure Sleep>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,956 | angr.project | Address is already hooked, during hook(0x500044, <SimProcedure Sleep>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,963 | angr.project | Address is already hooked, during hook(0x500038, <SimProcedure LeaveCriticalSection>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,963 | angr.project | Address is already hooked, during hook(0x500038, <SimProcedure LeaveCriticalSection>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,964 | angr.project | Address is already hooked, during hook(0x500000, <SimProcedure DeleteCriticalSection>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,964 | angr.project | Address is already hooked, during hook(0x500000, <SimProcedure DeleteCriticalSection>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,968 | angr.project | Address is already hooked, during hook(0x500030, <SimProcedure InitializeCriticalSection>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,968 | angr.project | Address is already hooked, during hook(0x500030, <SimProcedure InitializeCriticalSection>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,973 | angr.project | Address is already hooked, during hook(0x500004, <SimProcedure EnterCriticalSection>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,974 | angr.project | Address is already hooked, during hook(0x500004, <SimProcedure EnterCriticalSection>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,976 | angr.project | Address is already hooked, during hook(0x500030, <SimProcedure InitializeCriticalSection>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,977 | angr.project | Address is already hooked, during hook(0x500030, <SimProcedure InitializeCriticalSection>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,978 | angr.project | Address is already hooked, during hook(0x500044, <SimProcedure Sleep>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,978 | angr.project | Address is already hooked, during hook(0x500044, <SimProcedure Sleep>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,979 | angr.project | Address is already hooked, during hook(0x500064, <SimProcedure __p__environ>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,979 | angr.project | Address is already hooked, during hook(0x500064, <SimProcedure __p__environ>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,980 | angr.project | Address is already hooked, during hook(0x500064, <SimProcedure __p__environ>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,980 | angr.project | Address is already hooked, during hook(0x500064, <SimProcedure __p__environ>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,982 | angr.project | Address is already hooked, during hook(0x500088, <SimProcedure _onexit>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,982 | angr.project | Address is already hooked, during hook(0x500088, <SimProcedure _onexit>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,982 | angr.project | Address is already hooked, during hook(0x500074, <SimProcedure _errno>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,983 | angr.project | Address is already hooked, during hook(0x500074, <SimProcedure _errno>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,983 | angr.project | Address is already hooked, during hook(0x50007c, <SimProcedure _fullpath>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,984 | angr.project | Address is already hooked, during hook(0x50007c, <SimProcedure _fullpath>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,984 | angr.project | Address is already hooked, during hook(0x500084, <SimProcedure _isctype>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,985 | angr.project | Address is already hooked, during hook(0x500084, <SimProcedure _isctype>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,985 | angr.project | Address is already hooked, during hook(0x5000c8, <SimProcedure strcoll>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,986 | angr.project | Address is already hooked, during hook(0x5000c8, <SimProcedure strcoll>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,987 | angr.project | Address is already hooked, during hook(0x500088, <SimProcedure _onexit>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,987 | angr.project | Address is already hooked, during hook(0x500088, <SimProcedure _onexit>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,988 | angr.project | Address is already hooked, during hook(0x500058, <SimProcedure _stricoll>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,989 | angr.project | Address is already hooked, during hook(0x500058, <SimProcedure _stricoll>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,989 | angr.project | Address is already hooked, during hook(0x500084, <SimProcedure _isctype>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,989 | angr.project | Address is already hooked, during hook(0x500084, <SimProcedure _isctype>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,990 | angr.project | Address is already hooked, during hook(0x500074, <SimProcedure _errno>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,990 | angr.project | Address is already hooked, during hook(0x500074, <SimProcedure _errno>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,993 | angr.project | Address is already hooked, during hook(0x500098, <SimProcedure atexit>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,993 | angr.project | Address is already hooked, during hook(0x500098, <SimProcedure atexit>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,993 | angr.project | Address is already hooked, during hook(0x500098, <SimProcedure atexit>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,993 | angr.project | Address is already hooked, during hook(0x500098, <SimProcedure atexit>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,995 | angr.project | Address is already hooked, during hook(0x5000b0, <SimProcedure mbstowcs>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,995 | angr.project | Address is already hooked, during hook(0x5000b0, <SimProcedure mbstowcs>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,995 | angr.project | Address is already hooked, during hook(0x500058, <SimProcedure _stricoll>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,995 | angr.project | Address is already hooked, during hook(0x500058, <SimProcedure _stricoll>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,996 | angr.project | Address is already hooked, during hook(0x5000dc, <SimProcedure wcstombs>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,996 | angr.project | Address is already hooked, during hook(0x5000dc, <SimProcedure wcstombs>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,997 | angr.project | Address is already hooked, during hook(0x5000d8, <SimProcedure vfprintf>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,997 | angr.project | Address is already hooked, during hook(0x5000d8, <SimProcedure vfprintf>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,998 | angr.project | Address is already hooked, during hook(0x5000dc, <SimProcedure wcstombs>). Re-hooking.
# WARNING | 2024-05-20 10:55:01,999 | angr.project | Address is already hooked, during hook(0x5000dc, <SimProcedure wcstombs>). Re-hooking.
# WARNING | 2024-05-20 10:55:02,000 | angr.project | Address is already hooked, during hook(0x5000b0, <SimProcedure mbstowcs>). Re-hooking.
# WARNING | 2024-05-20 10:55:02,000 | angr.project | Address is already hooked, during hook(0x5000b0, <SimProcedure mbstowcs>). Re-hooking.
# WARNING | 2024-05-20 10:55:02,001 | angr.project | Address is already hooked, during hook(0x5000c8, <SimProcedure strcoll>). Re-hooking.
# WARNING | 2024-05-20 10:55:02,001 | angr.project | Address is already hooked, during hook(0x5000c8, <SimProcedure strcoll>). Re-hooking.
# WARNING | 2024-05-20 10:55:02,002 | angr.project | Address is already hooked, during hook(0x5000d8, <SimProcedure vfprintf>). Re-hooking.
# WARNING | 2024-05-20 10:55:02,002 | angr.project | Address is already hooked, during hook(0x5000d8, <SimProcedure vfprintf>). Re-hooking.
# WARNING | 2024-05-20 10:55:02,003 | angr.project | Address is already hooked, during hook(0x50007c, <SimProcedure _fullpath>). Re-hooking.
# WARNING | 2024-05-20 10:55:02,003 | angr.project | Address is already hooked, during hook(0x50007c, <SimProcedure _fullpath>). Re-hooking.
# INFO - 2024-05-20 10:55:02,025 - SemaSCDG - .text
# INFO - 2024-05-20 10:55:02,025 - SemaSCDG - {'vaddr': 4198400, 'memsize': 11556, 'is_readable': True, 'is_writable': False, 'is_executable': True}
# INFO - 2024-05-20 10:55:02,025 - SemaSCDG - .data
# INFO - 2024-05-20 10:55:02,025 - SemaSCDG - {'vaddr': 4210688, 'memsize': 28, 'is_readable': True, 'is_writable': True, 'is_executable': False}
# INFO - 2024-05-20 10:55:02,025 - SemaSCDG - .rdata
# INFO - 2024-05-20 10:55:02,025 - SemaSCDG - {'vaddr': 4214784, 'memsize': 768, 'is_readable': True, 'is_writable': False, 'is_executable': False}
# INFO - 2024-05-20 10:55:02,025 - SemaSCDG - /4
# INFO - 2024-05-20 10:55:02,025 - SemaSCDG - {'vaddr': 4218880, 'memsize': 2472, 'is_readable': True, 'is_writable': False, 'is_executable': False}
# INFO - 2024-05-20 10:55:02,025 - SemaSCDG - .bss
# INFO - 2024-05-20 10:55:02,025 - SemaSCDG - {'vaddr': 4222976, 'memsize': 112, 'is_readable': True, 'is_writable': True, 'is_executable': False}
# INFO - 2024-05-20 10:55:02,025 - SemaSCDG - .idata
# INFO - 2024-05-20 10:55:02,025 - SemaSCDG - {'vaddr': 4227072, 'memsize': 1656, 'is_readable': True, 'is_writable': True, 'is_executable': False}
# INFO - 2024-05-20 10:55:02,025 - SemaSCDG - .CRT
# INFO - 2024-05-20 10:55:02,025 - SemaSCDG - {'vaddr': 4231168, 'memsize': 24, 'is_readable': True, 'is_writable': True, 'is_executable': False}
# INFO - 2024-05-20 10:55:02,025 - SemaSCDG - .tls
# INFO - 2024-05-20 10:55:02,025 - SemaSCDG - {'vaddr': 4235264, 'memsize': 32, 'is_readable': True, 'is_writable': True, 'is_executable': False}
# INFO - 2024-05-20 10:55:02,025 - SemaSCDG - /14
# INFO - 2024-05-20 10:55:02,026 - SemaSCDG - {'vaddr': 4239360, 'memsize': 88, 'is_readable': True, 'is_writable': False, 'is_executable': False}
# INFO - 2024-05-20 10:55:02,026 - SemaSCDG - /29
# INFO - 2024-05-20 10:55:02,026 - SemaSCDG - {'vaddr': 4243456, 'memsize': 13989, 'is_readable': True, 'is_writable': False, 'is_executable': False}
# INFO - 2024-05-20 10:55:02,026 - SemaSCDG - /41
# INFO - 2024-05-20 10:55:02,026 - SemaSCDG - {'vaddr': 4259840, 'memsize': 534, 'is_readable': True, 'is_writable': False, 'is_executable': False}
# INFO - 2024-05-20 10:55:02,026 - SemaSCDG - /55
# INFO - 2024-05-20 10:55:02,026 - SemaSCDG - {'vaddr': 4263936, 'memsize': 746, 'is_readable': True, 'is_writable': False, 'is_executable': False}
# INFO - 2024-05-20 10:55:02,026 - SemaSCDG - /67
# INFO - 2024-05-20 10:55:02,026 - SemaSCDG - {'vaddr': 4268032, 'memsize': 56, 'is_readable': True, 'is_writable': False, 'is_executable': False}
# INFO - 2024-05-20 10:55:02,026 - SemaSCDG - [<PE Object Example_SEMA_code2.exe, maps [0x400000:0x412037]>]
# INFO - 2024-05-20 10:55:02,026 - SemaSCDG - <ExternObject Object cle##externs, maps [0x500000:0x5000e0]>
# INFO - 2024-05-20 10:55:02,026 - SemaSCDG - <generator object Loader.symbols at 0x7836cb482f80>
# INFO - 2024-05-20 10:55:02,027 - SemaSCDG -
# ------------------------------
# Start -State of simulation manager :
#  <SimulationManager with 1 active>
# ------------------------------
# INFO    | 2024-05-20 10:55:02,027 | angr.sim_manager | Stepping active of <SimulationManager with 1 active>
# WARNING | 2024-05-20 10:55:02,031 | angr.engines.vex.lifter | Self-modifying code is not always correctly optimized by PyVEX. To guarantee correctness, VEX optimizations have been disabled.
# INFO    | 2024-05-20 10:55:02,050 | angr.engines.engine | Ticked state: <IRSB from 0x401460: 1 sat>
# INFO    | 2024-05-20 10:55:02,051 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:02,051 | angr.sim_manager | Stepping active of <SimulationManager with 1 active>
# INFO    | 2024-05-20 10:55:02,057 | angr.engines.engine | Ticked state: <IRSB from 0x401b10: 1 sat 1 unsat>
# INFO    | 2024-05-20 10:55:02,058 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:02,058 | angr.sim_manager | Stepping active of <SimulationManager with 1 active>
# INFO    | 2024-05-20 10:55:02,062 | angr.engines.engine | Ticked state: <IRSB from 0x401b20: 1 sat>
# INFO    | 2024-05-20 10:55:02,062 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:02,062 | angr.sim_manager | Stepping active of <SimulationManager with 1 active>
# INFO    | 2024-05-20 10:55:02,071 | angr.engines.engine | Ticked state: <IRSB from 0x401ac0: 1 sat 1 unsat>
# INFO    | 2024-05-20 10:55:02,071 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:02,071 | angr.sim_manager | Stepping active of <SimulationManager with 1 active>
# INFO    | 2024-05-20 10:55:02,075 | angr.engines.engine | Ticked state: <IRSB from 0x401af0: 1 sat>
# INFO    | 2024-05-20 10:55:02,075 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:02,075 | angr.sim_manager | Stepping active of <SimulationManager with 1 active>
# INFO    | 2024-05-20 10:55:02,082 | angr.engines.engine | Ticked state: <IRSB from 0x401af6: 1 sat 1 unsat>
# INFO    | 2024-05-20 10:55:02,083 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:02,083 | angr.sim_manager | Stepping active of <SimulationManager with 1 active>
# INFO    | 2024-05-20 10:55:02,090 | angr.engines.engine | Ticked state: <IRSB from 0x401af4: 1 sat 1 unsat>
# INFO    | 2024-05-20 10:55:02,090 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:02,091 | angr.sim_manager | Stepping active of <SimulationManager with 1 active>
# INFO    | 2024-05-20 10:55:02,093 | angr.engines.engine | Ticked state: <IRSB from 0x401b04: 1 sat>
# INFO    | 2024-05-20 10:55:02,093 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:02,093 | angr.sim_manager | Stepping active of <SimulationManager with 1 active>
# INFO    | 2024-05-20 10:55:02,099 | angr.engines.engine | Ticked state: <IRSB from 0x401acf: 1 sat 1 unsat>
# INFO    | 2024-05-20 10:55:02,099 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:02,099 | angr.sim_manager | Stepping active of <SimulationManager with 1 active>
# INFO    | 2024-05-20 10:55:02,103 | angr.engines.engine | Ticked state: <IRSB from 0x401ad3: 1 sat>
# INFO    | 2024-05-20 10:55:02,104 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:02,104 | angr.sim_manager | Stepping active of <SimulationManager with 1 active>
# INFO    | 2024-05-20 10:55:02,108 | angr.engines.engine | Ticked state: <IRSB from 0x403d00: 1 sat>
# INFO    | 2024-05-20 10:55:02,108 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:02,109 | angr.sim_manager | Stepping active of <SimulationManager with 1 active>
# INFO    | 2024-05-20 10:55:02,116 | angr.engines.engine | Ticked state: <IRSB from 0x401340: 1 sat>
# INFO    | 2024-05-20 10:55:02,117 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:02,117 | angr.sim_manager | Stepping active of <SimulationManager with 1 active>
# INFO    | 2024-05-20 10:55:02,120 | angr.engines.engine | Ticked state: <IRSB from 0x403ca0: 1 sat>
# INFO    | 2024-05-20 10:55:02,121 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:02,121 | angr.sim_manager | Stepping active of <SimulationManager with 1 active>
# INFO - 2024-05-20 10:55:02,143 - SyscallToSCDG - Syscall found:  GetModuleHandleA[<BV32 0x405000>]
# INFO    | 2024-05-20 10:55:02,148 | angr.engines.engine | Ticked state: <SimProcedure GetModuleHandleA from 0x500024: 1 sat>
# INFO    | 2024-05-20 10:55:02,149 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:02,149 | angr.sim_manager | Stepping active of <SimulationManager with 1 active>
# INFO    | 2024-05-20 10:55:02,156 | angr.engines.engine | Ticked state: <IRSB from 0x401354: 1 sat 1 unsat>
# INFO    | 2024-05-20 10:55:02,157 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:02,157 | angr.sim_manager | Stepping active of <SimulationManager with 1 active>
# INFO    | 2024-05-20 10:55:02,161 | angr.engines.engine | Ticked state: <IRSB from 0x40135f: 1 sat>
# INFO    | 2024-05-20 10:55:02,161 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:02,161 | angr.sim_manager | Stepping active of <SimulationManager with 1 active>
# INFO    | 2024-05-20 10:55:02,163 | angr.engines.engine | Ticked state: <IRSB from 0x403c70: 1 sat>
# INFO    | 2024-05-20 10:55:02,164 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:02,164 | angr.sim_manager | Stepping active of <SimulationManager with 1 active>
# INFO - 2024-05-20 10:55:02,185 - SyscallToSCDG - Syscall found:  LoadLibraryA[<BV32 0x405000>]
# INFO    | 2024-05-20 10:55:02,190 | angr.engines.engine | Ticked state: <SimProcedure LoadLibraryA from 0x50003c: 1 sat>
# INFO    | 2024-05-20 10:55:02,190 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:02,191 | angr.sim_manager | Stepping active of <SimulationManager with 1 active>
# INFO    | 2024-05-20 10:55:02,196 | angr.engines.engine | Ticked state: <IRSB from 0x40136d: 1 sat>
# INFO    | 2024-05-20 10:55:02,196 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:02,196 | angr.sim_manager | Stepping active of <SimulationManager with 1 active>
# INFO    | 2024-05-20 10:55:02,199 | angr.engines.engine | Ticked state: <IRSB from 0x403c98: 1 sat>
# INFO    | 2024-05-20 10:55:02,200 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:02,200 | angr.sim_manager | Stepping active of <SimulationManager with 1 active>
# WARNING | 2024-05-20 10:55:02,432 | angr.project | Address is already hooked, during hook(0x50005c, <SimProcedure __getmainargs>). Not re-hooking.
# WARNING | 2024-05-20 10:55:02,432 | angr.project | Address is already hooked, during hook(0x601014, <SimProcedure KiUserExceptionDispatcher>). Not re-hooking.
# INFO - 2024-05-20 10:55:02,434 - SyscallToSCDG - Syscall found:  GetProcAddress[<BV32 0x601028>, <BV32 0x405013>]
# INFO    | 2024-05-20 10:55:02,483 | angr.engines.engine | Ticked state: <SimProcedure GetProcAddress from 0x500028: 1 sat>
# INFO    | 2024-05-20 10:55:02,484 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:02,484 | angr.sim_manager | Stepping active of <SimulationManager with 1 active>
# INFO    | 2024-05-20 10:55:02,489 | angr.engines.engine | Ticked state: <IRSB from 0x401385: 1 sat>
# INFO    | 2024-05-20 10:55:02,489 | angr.sim_manager | Stepping active of <SimulationManager with 1 active>
# INFO    | 2024-05-20 10:55:02,491 | angr.engines.engine | Ticked state: <IRSB from 0x403c98: 1 sat>
# INFO    | 2024-05-20 10:55:02,492 | angr.sim_manager | Stepping active of <SimulationManager with 1 active>
# WARNING | 2024-05-20 10:55:02,732 | angr.project | Address is already hooked, during hook(0x50005c, <SimProcedure __getmainargs>). Not re-hooking.
# WARNING | 2024-05-20 10:55:02,732 | angr.project | Address is already hooked, during hook(0x601014, <SimProcedure KiUserExceptionDispatcher>). Not re-hooking.
# INFO - 2024-05-20 10:55:02,735 - SyscallToSCDG - Syscall found:  GetProcAddress[<BV32 0x601028>, <BV32 0x405029>]
# INFO    | 2024-05-20 10:55:02,761 | angr.engines.engine | Ticked state: <SimProcedure GetProcAddress from 0x500028: 1 sat>
# INFO    | 2024-05-20 10:55:02,761 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:02,761 | angr.sim_manager | Stepping active of <SimulationManager with 1 active>
# INFO    | 2024-05-20 10:55:02,784 | angr.engines.engine | Ticked state: <IRSB from 0x40139a: 2 sat>
# INFO    | 2024-05-20 10:55:02,784 | SemaExplorerCDFS | A new block of execution have been executed with changes in sim_manager.
# INFO    | 2024-05-20 10:55:02,784 | SemaExplorerCDFS | Currently, simulation manager is :
# <SimulationManager with 2 active>
# INFO    | 2024-05-20 10:55:02,784 | SemaExplorerCDFS | pause stash len :0
# INFO    | 2024-05-20 10:55:02,785 | SemaExplorerCDFS | fork_stack : 1 0x4013b7 || 0x4013a6
# INFO    | 2024-05-20 10:55:02,785 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:02,785 | angr.sim_manager | Stepping active of <SimulationManager with 2 active>
# INFO    | 2024-05-20 10:55:02,791 | angr.engines.engine | Ticked state: <IRSB from 0x4013b7: 1 sat 1 unsat>
# WARNING | 2024-05-20 10:55:02,996 | angr.engines.successors | Exit state has over 256 possible solutions. Likely unconstrained; skipping. <BV32 retval_GetProcAddress_98303_32>
# INFO    | 2024-05-20 10:55:02,996 | angr.engines.engine | Ticked state: <IRSB from 0x4013a6: 1 unconstrained>
# INFO    | 2024-05-20 10:55:02,997 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:02,997 | SemaExplorerCDFS | End of the trace number 0 unconstrained
# INFO    | 2024-05-20 10:55:02,997 | angr.sim_manager | Stepping active of <SimulationManager with 1 active, 1 unconstrained>
# INFO    | 2024-05-20 10:55:03,000 | angr.engines.engine | Ticked state: <IRSB from 0x4013fa: 1 sat>
# INFO    | 2024-05-20 10:55:03,001 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:03,001 | angr.sim_manager | Stepping active of <SimulationManager with 1 active, 1 unconstrained>
# INFO    | 2024-05-20 10:55:03,003 | angr.engines.engine | Ticked state: <IRSB from 0x401320: 1 sat>
# INFO    | 2024-05-20 10:55:03,003 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:03,003 | angr.sim_manager | Stepping active of <SimulationManager with 1 active, 1 unconstrained>
# INFO - 2024-05-20 10:55:03,005 - SyscallToSCDG - Syscall found:  atexit[<BV32 0x401430>]
# INFO    | 2024-05-20 10:55:03,028 | angr.engines.engine | Ticked state: <SimProcedure atexit from 0x500098: 1 sat>
# INFO    | 2024-05-20 10:55:03,028 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:03,029 | angr.sim_manager | Stepping active of <SimulationManager with 1 active, 1 unconstrained>
# INFO    | 2024-05-20 10:55:03,035 | angr.engines.engine | Ticked state: <IRSB from 0x401406: 1 sat>
# INFO    | 2024-05-20 10:55:03,035 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:03,035 | angr.sim_manager | Stepping active of <SimulationManager with 1 active, 1 unconstrained>
# INFO    | 2024-05-20 10:55:03,040 | angr.engines.engine | Ticked state: <IRSB from 0x401ada: 1 sat 1 unsat>
# INFO    | 2024-05-20 10:55:03,041 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:03,041 | angr.sim_manager | Stepping active of <SimulationManager with 1 active, 1 unconstrained>
# INFO    | 2024-05-20 10:55:03,044 | angr.engines.engine | Ticked state: <IRSB from 0x401adf: 1 sat>
# INFO    | 2024-05-20 10:55:03,045 | angr.sim_manager | Stepping active of <SimulationManager with 1 active, 1 unconstrained>
# INFO    | 2024-05-20 10:55:03,047 | angr.engines.engine | Ticked state: <IRSB from 0x401320: 1 sat>
# INFO    | 2024-05-20 10:55:03,047 | angr.sim_manager | Stepping active of <SimulationManager with 1 active, 1 unconstrained>
# INFO - 2024-05-20 10:55:03,049 - SyscallToSCDG - Syscall found:  atexit[<BV32 0x401a90>]
# INFO    | 2024-05-20 10:55:03,072 | angr.engines.engine | Ticked state: <SimProcedure atexit from 0x500098: 1 sat>
# INFO    | 2024-05-20 10:55:03,072 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:03,072 | angr.sim_manager | Stepping active of <SimulationManager with 1 active, 1 unconstrained>
# INFO    | 2024-05-20 10:55:03,077 | angr.engines.engine | Ticked state: <IRSB from 0x401aeb: 1 sat>
# INFO    | 2024-05-20 10:55:03,077 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:03,078 | angr.sim_manager | Stepping active of <SimulationManager with 1 active, 1 unconstrained>
# INFO    | 2024-05-20 10:55:03,081 | angr.engines.engine | Ticked state: <IRSB from 0x401476: 1 sat>
# INFO    | 2024-05-20 10:55:03,081 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:03,081 | angr.sim_manager | Stepping active of <SimulationManager with 1 active, 1 unconstrained>
# INFO    | 2024-05-20 10:55:03,084 | angr.engines.engine | Ticked state: <IRSB from 0x403c90: 1 sat>
# INFO    | 2024-05-20 10:55:03,085 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:03,085 | angr.sim_manager | Stepping active of <SimulationManager with 1 active, 1 unconstrained>
# INFO - 2024-05-20 10:55:03,087 - SyscallToSCDG - Syscall found:  GetTickCount[]
# INFO    | 2024-05-20 10:55:03,088 | angr.engines.engine | Ticked state: <SimProcedure GetTickCount from 0x50002c: 1 sat>
# INFO    | 2024-05-20 10:55:03,088 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:03,089 | angr.sim_manager | Stepping active of <SimulationManager with 1 active, 1 unconstrained>
# INFO    | 2024-05-20 10:55:03,093 | angr.engines.engine | Ticked state: <IRSB from 0x40147b: 1 sat>
# INFO    | 2024-05-20 10:55:03,094 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:03,094 | angr.sim_manager | Stepping active of <SimulationManager with 1 active, 1 unconstrained>
# INFO    | 2024-05-20 10:55:03,096 | angr.engines.engine | Ticked state: <IRSB from 0x403c60: 1 sat>
# INFO    | 2024-05-20 10:55:03,096 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:03,097 | angr.sim_manager | Stepping active of <SimulationManager with 1 active, 1 unconstrained>
# INFO - 2024-05-20 10:55:03,099 - SyscallToSCDG - Syscall found:  Sleep[<BV32 0x1388>]
# INFO    | 2024-05-20 10:55:03,100 | angr.engines.engine | Ticked state: <SimProcedure Sleep from 0x500044: 1 sat>
# INFO    | 2024-05-20 10:55:03,100 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:03,100 | angr.sim_manager | Stepping active of <SimulationManager with 1 active, 1 unconstrained>
# INFO    | 2024-05-20 10:55:03,105 | angr.engines.engine | Ticked state: <IRSB from 0x401491: 1 sat>
# INFO    | 2024-05-20 10:55:03,105 | angr.sim_manager | Stepping active of <SimulationManager with 1 active, 1 unconstrained>
# INFO    | 2024-05-20 10:55:03,107 | angr.engines.engine | Ticked state: <IRSB from 0x403c90: 1 sat>
# INFO    | 2024-05-20 10:55:03,108 | angr.sim_manager | Stepping active of <SimulationManager with 1 active, 1 unconstrained>
# INFO - 2024-05-20 10:55:03,109 - SyscallToSCDG - Syscall found:  GetTickCount[]
# INFO    | 2024-05-20 10:55:03,110 | angr.engines.engine | Ticked state: <SimProcedure GetTickCount from 0x50002c: 1 sat>
# INFO    | 2024-05-20 10:55:03,110 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:03,110 | angr.sim_manager | Stepping active of <SimulationManager with 1 active, 1 unconstrained>
# INFO    | 2024-05-20 10:55:03,168 | angr.engines.engine | Ticked state: <IRSB from 0x401499: 1 sat 1 unsat>
# INFO    | 2024-05-20 10:55:03,169 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:03,169 | angr.sim_manager | Stepping active of <SimulationManager with 1 active, 1 unconstrained>
# INFO    | 2024-05-20 10:55:03,189 | angr.engines.engine | Ticked state: <IRSB from 0x4014b4: 2 sat>
# INFO    | 2024-05-20 10:55:03,189 | SemaExplorerCDFS | A new block of execution have been executed with changes in sim_manager.
# INFO    | 2024-05-20 10:55:03,189 | SemaExplorerCDFS | Currently, simulation manager is :
# <SimulationManager with 2 active, 1 unconstrained>
# INFO    | 2024-05-20 10:55:03,190 | SemaExplorerCDFS | pause stash len :0
# INFO    | 2024-05-20 10:55:03,190 | SemaExplorerCDFS | fork_stack : 1 0x4014b9 || 0x4014c0
# INFO    | 2024-05-20 10:55:03,190 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:03,190 | angr.sim_manager | Stepping active of <SimulationManager with 2 active, 1 unconstrained>
# INFO    | 2024-05-20 10:55:03,215 | angr.engines.engine | Ticked state: <IRSB from 0x4014b9: 2 sat>
# INFO    | 2024-05-20 10:55:03,219 | angr.engines.engine | Ticked state: <IRSB from 0x4014c0: 1 sat>
# INFO    | 2024-05-20 10:55:03,220 | SemaExplorerCDFS | A new block of execution have been executed with changes in sim_manager.
# INFO    | 2024-05-20 10:55:03,221 | SemaExplorerCDFS | Currently, simulation manager is :
# <SimulationManager with 3 active, 1 unconstrained>
# INFO    | 2024-05-20 10:55:03,221 | SemaExplorerCDFS | pause stash len :0
# INFO    | 2024-05-20 10:55:03,221 | SemaExplorerCDFS | fork_stack : 1 0x4014c9 || 0x4014c0
# INFO    | 2024-05-20 10:55:03,221 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:03,221 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:03,222 | angr.sim_manager | Stepping active of <SimulationManager with 3 active, 1 unconstrained>
# INFO    | 2024-05-20 10:55:03,224 | angr.engines.engine | Ticked state: <IRSB from 0x403c80: 1 sat>
# INFO    | 2024-05-20 10:55:03,229 | angr.engines.engine | Ticked state: <IRSB from 0x4014c9: 1 sat>
# INFO    | 2024-05-20 10:55:03,233 | angr.engines.engine | Ticked state: <IRSB from 0x4014c0: 1 sat>
# INFO    | 2024-05-20 10:55:03,233 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:03,234 | angr.sim_manager | Stepping active of <SimulationManager with 3 active, 1 unconstrained>
# INFO    | 2024-05-20 10:55:03,237 | angr.engines.engine | Ticked state: <IRSB from 0x403c40: 1 sat>
# INFO - 2024-05-20 10:55:03,238 - SyscallToSCDG - Syscall found:  IsDebuggerPresent[]
# INFO    | 2024-05-20 10:55:03,239 | angr.engines.engine | Ticked state: <SimProcedure IsDebuggerPresent from 0x500034: 1 sat>
# INFO    | 2024-05-20 10:55:03,242 | angr.engines.engine | Ticked state: <IRSB from 0x403c80: 1 sat>
# INFO    | 2024-05-20 10:55:03,242 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:03,242 | angr.sim_manager | Stepping active of <SimulationManager with 3 active, 1 unconstrained>
# INFO    | 2024-05-20 10:55:03,247 | angr.engines.engine | Ticked state: <IRSB from 0x4014c5: 1 sat 1 unsat>
# INFO - 2024-05-20 10:55:03,250 - SyscallToSCDG - Syscall found:  MessageBoxA[<BV32 0x0>, <BV32 0x405065>, <BV32 0x405064>, <BV32 0x0>]
# INFO    | 2024-05-20 10:55:03,279 | angr.engines.engine | Ticked state: <SimProcedure MessageBoxA (stub) from 0x5000e0: 1 sat>
# INFO - 2024-05-20 10:55:03,281 - SyscallToSCDG - Syscall found:  IsDebuggerPresent[]
# INFO    | 2024-05-20 10:55:03,283 | angr.engines.engine | Ticked state: <SimProcedure IsDebuggerPresent from 0x500034: 1 sat>
# INFO    | 2024-05-20 10:55:03,283 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:03,283 | angr.sim_manager | Stepping active of <SimulationManager with 3 active, 1 unconstrained>
# INFO    | 2024-05-20 10:55:03,287 | angr.engines.engine | Ticked state: <IRSB from 0x4014ed: 1 sat>
# INFO    | 2024-05-20 10:55:03,299 | angr.engines.engine | Ticked state: <IRSB from 0x4014f5: 1 sat>
# INFO    | 2024-05-20 10:55:03,304 | angr.engines.engine | Ticked state: <IRSB from 0x4014c5: 1 sat 1 unsat>
# INFO    | 2024-05-20 10:55:03,304 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:03,305 | angr.sim_manager | Stepping active of <SimulationManager with 3 active, 1 unconstrained>
# INFO    | 2024-05-20 10:55:03,307 | angr.engines.engine | Ticked state: <IRSB from 0x403b90: 1 sat>
# INFO    | 2024-05-20 10:55:03,310 | angr.engines.engine | Ticked state: <IRSB from 0x4015d4: 1 sat>
# INFO    | 2024-05-20 10:55:03,321 | angr.engines.engine | Ticked state: <IRSB from 0x4014f5: 1 sat>
# INFO    | 2024-05-20 10:55:03,321 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:03,321 | angr.sim_manager | Stepping active of <SimulationManager with 3 active, 1 unconstrained>
# INFO    | 2024-05-20 10:55:03,324 | angr.engines.engine | Ticked state: <IRSB from 0x403be8: 1 sat>
# INFO - 2024-05-20 10:55:03,327 - SyscallToSCDG - Syscall found:  strlen[<BV32 0x405077>]
# INFO - 2024-05-20 10:55:03,328 - SyscallToSCDG - Syscall found:  memcpy[<BV32 0x7ffefe36>, <BV32 0x405077>, <BV32 0x4>]
# INFO - 2024-05-20 10:55:03,328 - SyscallToSCDG - Syscall found:  strncpy[<BV32 0x7ffefe36>, <BV32 0x405077>, <BV32 0x4>]
# INFO - 2024-05-20 10:55:03,328 - SyscallToSCDG - Syscall found:  strcpy[<BV32 0x7ffefe36>, <BV32 0x405077>]
# INFO    | 2024-05-20 10:55:03,330 | angr.engines.engine | Ticked state: <SimProcedure strcpy from 0x5000cc: 1 sat>
# INFO    | 2024-05-20 10:55:03,333 | angr.engines.engine | Ticked state: <IRSB from 0x403b90: 1 sat>
# INFO    | 2024-05-20 10:55:03,334 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:03,334 | angr.sim_manager | Stepping active of <SimulationManager with 3 active, 1 unconstrained>
# INFO    | 2024-05-20 10:55:03,340 | angr.engines.engine | Ticked state: <IRSB from 0x40154c: 1 sat>
# INFO - 2024-05-20 10:55:03,342 - SyscallToSCDG - Syscall found:  exit[<BV32 0x0>]
# INFO    | 2024-05-20 10:55:03,342 | angr.engines.engine | Ticked state: <SimProcedure exit from 0x5000a0: 1 sat>
# INFO - 2024-05-20 10:55:03,345 - SyscallToSCDG - Syscall found:  strlen[<BV32 0x405077>]
# INFO - 2024-05-20 10:55:03,347 - SyscallToSCDG - Syscall found:  memcpy[<BV32 0x7ffefe36>, <BV32 0x405077>, <BV32 0x4>]
# INFO - 2024-05-20 10:55:03,347 - SyscallToSCDG - Syscall found:  strncpy[<BV32 0x7ffefe36>, <BV32 0x405077>, <BV32 0x4>]
# INFO - 2024-05-20 10:55:03,347 - SyscallToSCDG - Syscall found:  strcpy[<BV32 0x7ffefe36>, <BV32 0x405077>]
# INFO    | 2024-05-20 10:55:03,349 | angr.engines.engine | Ticked state: <SimProcedure strcpy from 0x5000cc: 1 sat>
# INFO    | 2024-05-20 10:55:03,350 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:03,350 | angr.sim_manager | Stepping active of <SimulationManager with 3 active, 1 unconstrained>
# INFO    | 2024-05-20 10:55:03,351 | angr.engines.engine | Ticked state: <SimProcedure PathTerminator from 0x5000a0: empty>
# INFO    | 2024-05-20 10:55:03,353 | angr.engines.engine | Ticked state: <IRSB from 0x403ba0: 1 sat>
# INFO    | 2024-05-20 10:55:03,358 | angr.engines.engine | Ticked state: <IRSB from 0x40154c: 1 sat>
# INFO    | 2024-05-20 10:55:03,358 | SemaExplorerCDFS | A new block of execution have been executed with changes in sim_manager.
# INFO    | 2024-05-20 10:55:03,359 | SemaExplorerCDFS | Currently, simulation manager is :
# <SimulationManager with 2 active, 1 deadended, 1 unconstrained>
# INFO    | 2024-05-20 10:55:03,359 | SemaExplorerCDFS | pause stash len :0
# INFO    | 2024-05-20 10:55:03,359 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:03,359 | angr.sim_manager | Stepping active of <SimulationManager with 2 active, 1 deadended, 1 unconstrained>
# INFO - 2024-05-20 10:55:03,363 - SyscallToSCDG - Syscall found:  strcat['str', 'cat']
# INFO    | 2024-05-20 10:55:03,367 | angr.engines.engine | Ticked state: <SimProcedure strcat from 0x5000c4: 1 sat>
# INFO    | 2024-05-20 10:55:03,370 | angr.engines.engine | Ticked state: <IRSB from 0x403ba0: 1 sat>
# INFO    | 2024-05-20 10:55:03,371 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:03,371 | angr.sim_manager | Stepping active of <SimulationManager with 2 active, 1 deadended, 1 unconstrained>
# INFO    | 2024-05-20 10:55:03,374 | angr.engines.engine | Ticked state: <IRSB from 0x40155e: 1 sat>
# INFO - 2024-05-20 10:55:03,378 - SyscallToSCDG - Syscall found:  strcat['str', 'cat']
# INFO    | 2024-05-20 10:55:03,383 | angr.engines.engine | Ticked state: <SimProcedure strcat from 0x5000c4: 1 sat>
# INFO    | 2024-05-20 10:55:03,384 | angr.sim_manager | Stepping active of <SimulationManager with 2 active, 1 deadended, 1 unconstrained>
# INFO    | 2024-05-20 10:55:03,386 | angr.engines.engine | Ticked state: <IRSB from 0x403c70: 1 sat>
# INFO    | 2024-05-20 10:55:03,389 | angr.engines.engine | Ticked state: <IRSB from 0x40155e: 1 sat>
# INFO    | 2024-05-20 10:55:03,390 | angr.sim_manager | Stepping active of <SimulationManager with 2 active, 1 deadended, 1 unconstrained>
# WARNING | 2024-05-20 10:55:03,635 | angr.project | Address is already hooked, during hook(0x50005c, <SimProcedure __getmainargs>). Not re-hooking.
# WARNING | 2024-05-20 10:55:03,635 | angr.project | Address is already hooked, during hook(0x601014, <SimProcedure KiUserExceptionDispatcher>). Not re-hooking.
# INFO - 2024-05-20 10:55:03,637 - SyscallToSCDG - Syscall found:  LoadLibraryA[<BV32 0x40507b>]
# INFO    | 2024-05-20 10:55:03,640 | angr.engines.engine | Ticked state: <SimProcedure LoadLibraryA from 0x50003c: 1 sat>
# INFO    | 2024-05-20 10:55:03,643 | angr.engines.engine | Ticked state: <IRSB from 0x403c70: 1 sat>
# INFO    | 2024-05-20 10:55:03,643 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:03,643 | angr.sim_manager | Stepping active of <SimulationManager with 2 active, 1 deadended, 1 unconstrained>
# INFO    | 2024-05-20 10:55:03,650 | angr.engines.engine | Ticked state: <IRSB from 0x40156a: 1 sat>
# INFO - 2024-05-20 10:55:03,670 - SyscallToSCDG - Syscall found:  LoadLibraryA[<BV32 0x40507b>]
# INFO    | 2024-05-20 10:55:03,674 | angr.engines.engine | Ticked state: <SimProcedure LoadLibraryA from 0x50003c: 1 sat>
# INFO    | 2024-05-20 10:55:03,674 | angr.sim_manager | Stepping active of <SimulationManager with 2 active, 1 deadended, 1 unconstrained>
# INFO    | 2024-05-20 10:55:03,676 | angr.engines.engine | Ticked state: <IRSB from 0x403c98: 1 sat>
# INFO    | 2024-05-20 10:55:03,683 | angr.engines.engine | Ticked state: <IRSB from 0x40156a: 1 sat>
# INFO    | 2024-05-20 10:55:03,684 | angr.sim_manager | Stepping active of <SimulationManager with 2 active, 1 deadended, 1 unconstrained>
# INFO - 2024-05-20 10:55:03,704 - SyscallToSCDG - Syscall found:  GetProcAddress[<BV32 0x601034>, <BV32 0x7ffefe36>]
# INFO    | 2024-05-20 10:55:03,707 | angr.engines.engine | Ticked state: <SimProcedure GetProcAddress from 0x500028: 1 sat>
# INFO    | 2024-05-20 10:55:03,709 | angr.engines.engine | Ticked state: <IRSB from 0x403c98: 1 sat>
# INFO    | 2024-05-20 10:55:03,709 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:03,709 | angr.sim_manager | Stepping active of <SimulationManager with 2 active, 1 deadended, 1 unconstrained>
# INFO    | 2024-05-20 10:55:03,717 | angr.engines.engine | Ticked state: <IRSB from 0x401582: 1 sat>
# INFO - 2024-05-20 10:55:03,736 - SyscallToSCDG - Syscall found:  GetProcAddress[<BV32 0x601034>, <BV32 0x7ffefe36>]
# INFO    | 2024-05-20 10:55:03,738 | angr.engines.engine | Ticked state: <SimProcedure GetProcAddress from 0x500028: 1 sat>
# INFO    | 2024-05-20 10:55:03,739 | angr.sim_manager | Stepping active of <SimulationManager with 2 active, 1 deadended, 1 unconstrained>
# INFO - 2024-05-20 10:55:03,742 - SyscallToSCDG - Syscall found:  strcat['', "I'm "]
# INFO    | 2024-05-20 10:55:03,743 | angr.engines.engine | Ticked state: <SimProcedure strcat from 0x5000c4: 1 sat>
# INFO    | 2024-05-20 10:55:03,751 | angr.engines.engine | Ticked state: <IRSB from 0x401582: 1 sat>
# INFO    | 2024-05-20 10:55:03,751 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:03,751 | angr.sim_manager | Stepping active of <SimulationManager with 2 active, 1 deadended, 1 unconstrained>
# INFO    | 2024-05-20 10:55:03,757 | angr.engines.engine | Ticked state: <IRSB from 0x40159b: 1 sat>
# INFO - 2024-05-20 10:55:03,760 - SyscallToSCDG - Syscall found:  strcat['', "I'm "]
# INFO    | 2024-05-20 10:55:03,761 | angr.engines.engine | Ticked state: <SimProcedure strcat from 0x5000c4: 1 sat>
# INFO    | 2024-05-20 10:55:03,761 | angr.sim_manager | Stepping active of <SimulationManager with 2 active, 1 deadended, 1 unconstrained>
# INFO - 2024-05-20 10:55:03,766 - SyscallToSCDG - Syscall found:  strcat["I'm ", 'evil !!']
# INFO    | 2024-05-20 10:55:03,767 | angr.engines.engine | Ticked state: <SimProcedure strcat from 0x5000c4: 1 sat>
# INFO    | 2024-05-20 10:55:03,772 | angr.engines.engine | Ticked state: <IRSB from 0x40159b: 1 sat>
# INFO    | 2024-05-20 10:55:03,772 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:03,773 | angr.sim_manager | Stepping active of <SimulationManager with 2 active, 1 deadended, 1 unconstrained>
# INFO    | 2024-05-20 10:55:03,778 | angr.engines.engine | Ticked state: <IRSB from 0x4015ae: 1 sat>
# INFO - 2024-05-20 10:55:03,784 - SyscallToSCDG - Syscall found:  strcat["I'm ", 'evil !!']
# INFO    | 2024-05-20 10:55:03,785 | angr.engines.engine | Ticked state: <SimProcedure strcat from 0x5000c4: 1 sat>
# INFO    | 2024-05-20 10:55:03,786 | angr.sim_manager | Stepping active of <SimulationManager with 2 active, 1 deadended, 1 unconstrained>
# INFO    | 2024-05-20 10:55:03,788 | angr.engines.engine | Ticked state: <IRSB from 0x403c40: 1 sat>
# INFO    | 2024-05-20 10:55:03,794 | angr.engines.engine | Ticked state: <IRSB from 0x4015ae: 1 sat>
# INFO    | 2024-05-20 10:55:03,794 | angr.sim_manager | Stepping active of <SimulationManager with 2 active, 1 deadended, 1 unconstrained>
# INFO - 2024-05-20 10:55:03,796 - SyscallToSCDG - Syscall found:  MessageBoxA[<BV32 0x0>, <BV32 0x7ffefe22>, <BV32 0x405064>, <BV32 0x0>]
# INFO    | 2024-05-20 10:55:03,819 | angr.engines.engine | Ticked state: <SimProcedure MessageBoxA (stub) from 0x5000e0: 1 sat>
# INFO    | 2024-05-20 10:55:03,821 | angr.engines.engine | Ticked state: <IRSB from 0x403c40: 1 sat>
# INFO    | 2024-05-20 10:55:03,821 | SemaExplorerCDFS | Hey new addr !
# INFO    | 2024-05-20 10:55:03,821 | angr.sim_manager | Stepping active of <SimulationManager with 2 active, 1 deadended, 1 unconstrained>
# INFO    | 2024-05-20 10:55:03,825 | angr.engines.engine | Ticked state: <IRSB from 0x4015d1: 1 sat>
# INFO - 2024-05-20 10:55:03,827 - SyscallToSCDG - Syscall found:  MessageBoxA[<BV32 0x0>, <BV32 0x7ffefe22>, <BV32 0x405064>, <BV32 0x0>]
# INFO    | 2024-05-20 10:55:03,850 | angr.engines.engine | Ticked state: <SimProcedure MessageBoxA (stub) from 0x5000e0: 1 sat>
# INFO    | 2024-05-20 10:55:03,850 | angr.sim_manager | Stepping active of <SimulationManager with 2 active, 1 deadended, 1 unconstrained>
# INFO    | 2024-05-20 10:55:03,853 | angr.engines.engine | Ticked state: <IRSB from 0x403be8: 1 sat>
# INFO    | 2024-05-20 10:55:03,857 | angr.engines.engine | Ticked state: <IRSB from 0x4015d1: 1 sat>
# INFO    | 2024-05-20 10:55:03,857 | angr.sim_manager | Stepping active of <SimulationManager with 2 active, 1 deadended, 1 unconstrained>
# INFO - 2024-05-20 10:55:03,859 - SyscallToSCDG - Syscall found:  exit[<BV32 0x0>]
# INFO    | 2024-05-20 10:55:03,860 | angr.engines.engine | Ticked state: <SimProcedure exit from 0x5000a0: 1 sat>
# INFO    | 2024-05-20 10:55:03,862 | angr.engines.engine | Ticked state: <IRSB from 0x403be8: 1 sat>
# INFO    | 2024-05-20 10:55:03,862 | angr.sim_manager | Stepping active of <SimulationManager with 2 active, 1 deadended, 1 unconstrained>
# INFO    | 2024-05-20 10:55:03,863 | angr.engines.engine | Ticked state: <SimProcedure PathTerminator from 0x5000a0: empty>
# INFO - 2024-05-20 10:55:03,865 - SyscallToSCDG - Syscall found:  exit[<BV32 0x0>]
# INFO    | 2024-05-20 10:55:03,865 | angr.engines.engine | Ticked state: <SimProcedure exit from 0x5000a0: 1 sat>
# INFO    | 2024-05-20 10:55:03,866 | SemaExplorerCDFS | A new block of execution have been executed with changes in sim_manager.
# INFO    | 2024-05-20 10:55:03,866 | SemaExplorerCDFS | Currently, simulation manager is :
# <SimulationManager with 1 active, 2 deadended, 1 unconstrained>
# INFO    | 2024-05-20 10:55:03,866 | SemaExplorerCDFS | pause stash len :0
# INFO    | 2024-05-20 10:55:03,866 | angr.sim_manager | Stepping active of <SimulationManager with 1 active, 2 deadended, 1 unconstrained>
# INFO    | 2024-05-20 10:55:03,867 | angr.engines.engine | Ticked state: <SimProcedure PathTerminator from 0x5000a0: empty>
# INFO    | 2024-05-20 10:55:03,867 | SemaExplorerCDFS | A new block of execution have been executed with changes in sim_manager.
# INFO    | 2024-05-20 10:55:03,867 | SemaExplorerCDFS | Currently, simulation manager is :
# <SimulationManager with 3 deadended, 1 unconstrained>
# INFO    | 2024-05-20 10:55:03,867 | SemaExplorerCDFS | pause stash len :0
# INFO    | 2024-05-20 10:55:03,868 | SemaExplorerCDFS | len(simgr.active) <= 0 or deadended >= self.max_end_state)
# INFO - 2024-05-20 10:55:03,868 - SemaSCDG -
# ------------------------------
# End - State of simulation manager :
#  <SimulationManager with 3 deadended, 1 unconstrained>
# ------------------------------
# INFO - 2024-05-20 10:55:03,868 - SemaSCDG - Total execution time: 13.391910314559937
# INFO - 2024-05-20 10:55:03,868 - SemaSCDG - .text
# INFO - 2024-05-20 10:55:03,868 - SemaSCDG - {'vaddr': 4198400, 'memsize': 11556, 'is_readable': True, 'is_writable': False, 'is_executable': True}
# INFO - 2024-05-20 10:55:03,868 - SemaSCDG - .data
# INFO - 2024-05-20 10:55:03,868 - SemaSCDG - {'vaddr': 4210688, 'memsize': 28, 'is_readable': True, 'is_writable': True, 'is_executable': False}
# INFO - 2024-05-20 10:55:03,868 - SemaSCDG - .rdata
# INFO - 2024-05-20 10:55:03,868 - SemaSCDG - {'vaddr': 4214784, 'memsize': 768, 'is_readable': True, 'is_writable': False, 'is_executable': False}
# INFO - 2024-05-20 10:55:03,868 - SemaSCDG - /4
# INFO - 2024-05-20 10:55:03,868 - SemaSCDG - {'vaddr': 4218880, 'memsize': 2472, 'is_readable': True, 'is_writable': False, 'is_executable': False}
# INFO - 2024-05-20 10:55:03,868 - SemaSCDG - .bss
# INFO - 2024-05-20 10:55:03,868 - SemaSCDG - {'vaddr': 4222976, 'memsize': 112, 'is_readable': True, 'is_writable': True, 'is_executable': False}
# INFO - 2024-05-20 10:55:03,868 - SemaSCDG - .idata
# INFO - 2024-05-20 10:55:03,868 - SemaSCDG - {'vaddr': 4227072, 'memsize': 1656, 'is_readable': True, 'is_writable': True, 'is_executable': False}
# INFO - 2024-05-20 10:55:03,868 - SemaSCDG - .CRT
# INFO - 2024-05-20 10:55:03,868 - SemaSCDG - {'vaddr': 4231168, 'memsize': 24, 'is_readable': True, 'is_writable': True, 'is_executable': False}
# INFO - 2024-05-20 10:55:03,868 - SemaSCDG - .tls
# INFO - 2024-05-20 10:55:03,868 - SemaSCDG - {'vaddr': 4235264, 'memsize': 32, 'is_readable': True, 'is_writable': True, 'is_executable': False}
# INFO - 2024-05-20 10:55:03,868 - SemaSCDG - /14
# INFO - 2024-05-20 10:55:03,868 - SemaSCDG - {'vaddr': 4239360, 'memsize': 88, 'is_readable': True, 'is_writable': False, 'is_executable': False}
# INFO - 2024-05-20 10:55:03,868 - SemaSCDG - /29
# INFO - 2024-05-20 10:55:03,868 - SemaSCDG - {'vaddr': 4243456, 'memsize': 13989, 'is_readable': True, 'is_writable': False, 'is_executable': False}
# INFO - 2024-05-20 10:55:03,868 - SemaSCDG - /41
# INFO - 2024-05-20 10:55:03,869 - SemaSCDG - {'vaddr': 4259840, 'memsize': 534, 'is_readable': True, 'is_writable': False, 'is_executable': False}
# INFO - 2024-05-20 10:55:03,869 - SemaSCDG - /55
# INFO - 2024-05-20 10:55:03,869 - SemaSCDG - {'vaddr': 4263936, 'memsize': 746, 'is_readable': True, 'is_writable': False, 'is_executable': False}
# INFO - 2024-05-20 10:55:03,869 - SemaSCDG - /67
# INFO - 2024-05-20 10:55:03,869 - SemaSCDG - {'vaddr': 4268032, 'memsize': 56, 'is_readable': True, 'is_writable': False, 'is_executable': False}
# INFO - 2024-05-20 10:55:03,870 - GraphBuilder - Output dir :database/SCDG/runs/Tutorial_output/Binaryfamily/Example_SEMA_code2.exe
# INFO - 2024-05-20 10:55:03,871 - GraphBuilder - Using SCDG 1 over 4
# INFO - 2024-05-20 10:55:03,871 - GraphBuilder - Using SCDG 2 over 4
# INFO - 2024-05-20 10:55:03,871 - GraphBuilder - Using SCDG 3 over 4
# INFO - 2024-05-20 10:55:03,872 - GraphBuilder - Using SCDG 4 over 4

# %% [markdown]
# We observe the same kind of behavior in the JSON file :
#
# {"status": "deadendend", "trace":
#
#         [{"name": "main", "args": ["Example_SEMA_code2.exe"], "addr": 4199520, "ret": "symbolic", "addr_func": 4199520},
#         {"name": "GetModuleHandleA", "args": ["libgcc_s_dw2-1.dll"], "addr_func": "5242916", "addr": 4199247, "ret": 6295592},
#         {"name": "LoadLibraryA", "args": ["libgcc_s_dw2-1.dll"], "addr_func": "5242940", "addr": 4199272, "ret": 6295592},
#         {"name": "GetProcAddress", "args": [6295592, "__register_frame_info"], "addr_func": "5242920", "addr": 4199296, "ret": "<BV32 retval_GetProcAddress_32767_32>"},
#         {"name": "GetProcAddress", "args": [6295592, "__deregister_frame_info"], "addr_func": "5242920", "addr": 4199317, "ret": "<BV32 retval_GetProcAddress_32768_32>"},
#         {"name": "atexit", "args": [4199472], "addr_func": "5243032", "addr": 4199425, "ret": "<BV32 retval_atexit_32769_32>"},
#         {"name": "atexit", "args": [4201104], "addr_func": "5243032", "addr": 4201190, "ret": "<BV32 retval_atexit_32770_32>"},
#         {"name": "GetTickCount", "args": [], "addr_func": "5242924", "addr": 4199542, "ret": "<BV32 retval_GetTickCount_32771_32{UNINITIALIZED}>"},
#         {"name": "Sleep", "args": [5000], "addr_func": "5242948", "addr": 4199564, "ret": "None"},
#         {"name": "GetTickCount", "args": [], "addr_func": "5242924", "addr": 4199572, "ret": "<BV32 retval_GetTickCount_32772_32{UNINITIALIZED}>"},
#         {"name": "IsDebuggerPresent", "args": [], "addr_func": "5242932", "addr": 4199616, "ret": "<BV32 retval_IsDebuggerPresent_32775_32>"},
#         {"name": "strcpy", "args": [], "addr_func": "5243084", "addr": 4199751, "ret": 2147417750},
#         {"name": "strcat", "args": ["str", "cat"], "addr_func": "5243076", "addr": 4199769, "ret": "strcat"}, {"name": "LoadLibraryA", "args": ["msvcrt.dll"], "addr_func": "5242940", "addr": 4199781, "ret": 6295604},
#         {"name": "GetProcAddress", "args": [6295604, "strcat"], "addr_func": "5242920", "addr": 4199805, "ret": 5243076},
#         {"name": "strcat", "args": ["", "I'm "], "addr_func": "5243076", "addr": 4199833, "ret": "I'm "},
#         {"name": "strcat", "args": ["I'm ", "evil !!"], "addr_func": "5243076", "addr": 4199852, "ret": "I'm evil !!"},
#         {"name": "MessageBoxA", "args": [0, "I'm evil !!", "", 0], "addr_func": "5243104", "addr": 4199884, "ret": 1},
#         {"name": "exit", "args": [], "addr_func": "5243040", "addr": 4199899, "ret": "None"}]}

# %% [markdown]
# To have a better view of what's happening we represent the main behavior observed in the SCDG in the following image :
# ![Example_SEMA_SCDG2.png](attachment:Example_SEMA_SCDG2.png)
